# %%
file_name = '1687191017509_organization_daos_with_platform_links.csv'

# %%
import pandas as pd
df = pd.read_csv(file_name)
df.head()
# Out:
#                          organizationId                                 daoId
# 0  8a5c300e-4220-4c18-8dc5-213c61c2861a  1576e095-8ce4-4d3d-856b-02231ae0e098  \
# 1  d11f1261-975b-49b5-a801-25af19bf941d  5086dcb7-5c89-45ca-90dd-755c5e44be65
# 2  fe4cd05c-f6cb-461a-add9-bcdb1365fc0e  836bdad7-fe04-4abd-bc92-802b9ebe0b32
# 3  fe4cd05c-f6cb-461a-add9-bcdb1365fc0e  a062909e-5661-43f0-a07b-fd5a5a935387
# 4  ab71e343-c8c1-4a7e-92e0-39378e392422  04c03441-eaaf-4049-99bd-91f8ad69da07
#
#                                     name  platformTitle  platformId
# 0  CB DAO ONE onchain: Aragon governance         Aragon           4  \
# 1                          Futera United       Snapshot          11
# 2                              BadgerDAO       Snapshot          11
# 3                             Badger DAO         Aragon           4
# 4                                   dOrg  Safe/Snapshot          12
#
#                                 website    mostRecentProposalDate
# 0                                   NaN  2022-01-31T08:22:46.000Z  \
# 1     https://snapshot.org/#/futera.eth  2023-06-17T12:14:07.000Z
# 2  https://snapshot.org/#/badgerdao.eth  2023-06-15T03:01:54.000Z
# 3                                   NaN  2022-07-06T15:58:29.000Z
# 4       https://snapshot.org/#/dorg.eth  2023-06-16T16:26:04.000Z
#
#             aum
# 0  3.139965e+04
# 1           NaN
# 2           NaN
# 3  7.724702e+06
# 4  1.353414e+05

# %%
df.platformTitle.value_counts()
# Out:
# platformTitle
# Snapshot            209
# Aragon               27
# Substrate            18
# Governor             12
# Safe/Snapshot         9
# Moloch / Daohaus      8
# Realms                6
# DAOstack              4
# AssetsOnly            4
# OpenLaw               1
# Name: count, dtype: int64

# %%
# number of DAOs by organization boxplot
df.organizationId.value_counts().plot.box()
# i.e., the number of voting pages that each organization has
# Out:
# <Axes: >

# %%
# number of DAOs by platform boxplot
df.platformTitle.value_counts().plot.box()
# label outliers
df.platformTitle.value_counts().sort_values(ascending=False)
# Out:
# platformTitle
# Snapshot            209
# Aragon               27
# Substrate            18
# Governor             12
# Safe/Snapshot         9
# Moloch / Daohaus      8
# Realms                6
# DAOstack              4
# AssetsOnly            4
# OpenLaw               1
# Name: count, dtype: int64

# %%
# mean number of DAOs by organization
df.organizationId.value_counts().describe()
# Out:
# count    100.000000
# mean       2.980000
# std        5.183462
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max       35.000000
# Name: count, dtype: float64

# %%
df[df.platformTitle == 'Snapshot'].website.notna().value_counts()
# Out:
# website
# True     208
# False      1
# Name: count, dtype: int64

# %%
# let's check the urls for each type of platform
df[df.platformTitle == 'Snapshot'].website
# Out:
# 1                https://snapshot.org/#/futera.eth
# 2             https://snapshot.org/#/badgerdao.eth
# 7                https://snapshot.org/#/pizzap.eth
# 8                   https://snapshot.org/#/yam.eth
# 12               https://snapshot.org/#/r-wave.eth
#                           ...
# 282                                            NaN
# 286          https://snapshot.org/#/aavegotchi.eth
# 289            https://snapshot.org/#/cakevote.eth
# 290    https://snapshot.org/#/officialoceandao.eth
# 291          https://snapshot.org/#/metacartel.eth
# Name: website, Length: 209, dtype: object

# %%
df[df.platformTitle == 'Aragon'].website.notna().value_counts()
# Out:
# website
# True     14
# False    13
# Name: count, dtype: int64

# %%
# let's check the urls for each type of platform
df[df.platformTitle == 'Aragon'].website
# Out:
# 0                                                    NaN
# 3                                                    NaN
# 22                                                   NaN
# 32                                                   NaN
# 39                                                   NaN
# 45                 https://mainnet.aragon.org/#/mstable/
# 58     https://mainnet.aragon.org/#/brightiddev.arago...
# 59                                                   NaN
# 65                                      https://nftx.org
# 85                                                   NaN
# 89                                 https://piedao.org/#/
# 91     https://client.aragon.org/#/0x1c26fde2ce92cd1d...
# 97                  https://mainnet.lido.fi/#/lido-dao/
# 209    https://client.aragon.org/#/0xf47917b108ca4b82...
# 233      https://mainnet.aragon.org/#/aira/organization/
# 234                                                  NaN
# 239                 https://mainnet.aragon.org/#/lexdao/
# 244                                                  NaN
# 264     https://mainnet.aragon.org/#/budget.aragonid.eth
# 265      https://mainnet.aragon.org/#/trust.aragonid.eth
# 268    https://mainnet.aragon.org/#/associationops.ar...
# 269                                                  NaN
# 270                                                  NaN
# 283    https://mainnet.aragon.org/#/marsdao.aragonid.eth
# 287                                                  NaN
# 288                                                  NaN
# 297    https://mainnet.aragon.org/#/0x117d1F8CB4Bf6e7...
# Name: website, dtype: object

# %%
df[df.platformTitle == 'Substrate'].website.notna().value_counts()
# Out:
# website
# False    18
# Name: count, dtype: int64

# %%
# let's check the urls for each type of platform
df[df.platformTitle == 'Substrate']
# urls are not available for these...
# Out:
#                            organizationId
# 29   b4ada401-a5d3-4b3e-9d81-b184f0284701  \
# 30   b4ada401-a5d3-4b3e-9d81-b184f0284701
# 31   b4ada401-a5d3-4b3e-9d81-b184f0284701
# 204  c84cd1ca-1b59-4ac7-ba68-0f3763e60998
# 205  c84cd1ca-1b59-4ac7-ba68-0f3763e60998
# 206  c84cd1ca-1b59-4ac7-ba68-0f3763e60998
# 210  8af61b96-27ac-4da6-9a21-a894889e3a6e
# 211  8af61b96-27ac-4da6-9a21-a894889e3a6e
# 212  8af61b96-27ac-4da6-9a21-a894889e3a6e
# 213  2707fc6e-bf61-437c-83ce-adbbb92fac2c
# 214  2707fc6e-bf61-437c-83ce-adbbb92fac2c
# 215  2707fc6e-bf61-437c-83ce-adbbb92fac2c
# 249  37b8ab4b-dd9b-4cc6-a1f2-f98e4bc7d911
# 250  37b8ab4b-dd9b-4cc6-a1f2-f98e4bc7d911
# 251  37b8ab4b-dd9b-4cc6-a1f2-f98e4bc7d911
# 294  c0f3aa7a-35b8-41ac-9e78-e2263ea29657
# 295  c0f3aa7a-35b8-41ac-9e78-e2263ea29657
# 296  c0f3aa7a-35b8-41ac-9e78-e2263ea29657
#
#                                     daoId                           name
# 29   c26dd884-0efd-4723-af3b-a49e432efd53            Moonriver Democracy  \
# 30   d1875aa4-95ca-44e3-b7b7-e1fce5a61599  Moonriver Technical Committee
# 31   f82d7cab-f4a7-4828-ac5a-d5dc8a81b991              Moonriver Council
# 204  674afc91-287e-4229-b0c9-1520d9a83fda               Polkadot Council
# 205  14f7b0f6-c7d8-428c-b304-d0346df0f210   Polkadot Technical Committee
# 206  b25e40f3-d472-4dd6-ab26-5f487508e966             Polkadot Democracy
# 210  6b6a7c8c-73ef-4394-9a1d-dd19bb504fae                Acala Democracy
# 211  f2062a17-2385-45e5-9499-8cfb577615f5      Acala Technical Committee
# 212  08a30755-6d73-4b1a-b7c9-a5a3ca343a18                  Acala Council
# 213  6612483a-bcd7-47ec-afd0-4f098225a33a                Bifrost Council
# 214  fe98dcea-0496-430b-9e39-adba444feb04    Bifrost Technical Committee
# 215  987c0f83-d810-4408-9dbe-2de55c4b3fe7              Bifrost Democracy
# 249  67785e63-1fc6-498c-b5e0-575d4e549c54                 Kusama Council
# 250  8bc4f20f-9757-4029-aedd-0c3470497b21               Kusama Democracy
# 251  edb484b7-141e-49fa-be32-5c64652cfe5b     Kusama Technical Committee
# 294  63d889a6-647c-40ea-bd80-983e5615ee4b             Moonbeam Democracy
# 295  8cc6ef03-b9e3-43fc-8199-1d62127c73bd   Moonbeam Technical Committee
# 296  2a0eb14f-ec06-4e3c-bc56-8a7c200f8ed7               Moonbeam Council
#
#     platformTitle  platformId website    mostRecentProposalDate           aum
# 29      Substrate          15     NaN  2022-11-09T12:56:06.190Z  8.423495e+05
# 30      Substrate          15     NaN  2022-11-04T16:11:48.173Z           NaN
# 31      Substrate          15     NaN  2022-11-04T16:08:48.188Z           NaN
# 204     Substrate          15     NaN  2022-10-17T17:04:42.010Z           NaN
# 205     Substrate          15     NaN  2022-10-10T18:04:36.008Z           NaN
# 206     Substrate          15     NaN  2021-11-11T16:32:24.002Z  1.826764e+08
# 210     Substrate          15     NaN  2022-12-08T15:44:24.300Z  1.576496e+05
# 211     Substrate          15     NaN  2022-12-07T09:28:00.334Z           NaN
# 212     Substrate          15     NaN  2022-12-07T07:18:00.246Z           NaN
# 213     Substrate          15     NaN  2022-12-08T09:45:00.521Z           NaN
# 214     Substrate          15     NaN  2022-12-07T03:03:36.186Z           NaN
# 215     Substrate          15     NaN  2022-12-06T03:20:00.427Z  1.057262e+02
# 249     Substrate          15     NaN  2022-11-23T16:21:42.028Z           NaN
# 250     Substrate          15     NaN  2022-11-22T22:03:24.020Z  6.418551e+06
# 251     Substrate          15     NaN  2022-11-22T12:18:30.019Z           NaN
# 294     Substrate          15     NaN  2022-11-09T12:56:06.190Z  2.086944e+06
# 295     Substrate          15     NaN  2022-11-04T16:11:48.173Z           NaN
# 296     Substrate          15     NaN  2022-11-04T16:08:48.188Z           NaN

# %%
df[df.platformTitle == 'Governor'].website.notna().value_counts()
# Out:
# website
# True     7
# False    5
# Name: count, dtype: int64

# %%
# let's check the urls for each type of platform
df[df.platformTitle == 'Governor']
# some urls, but not organized...
# Out:
#                            organizationId
# 9    5c76f492-c718-4c2e-b633-c9dbac1cc331  \
# 10   dfb0c1b7-334a-45a8-88ba-dacdbc8e3842
# 19   37aba1a5-2f93-4c15-9171-5df14ac4e237
# 25   89cd885e-e653-445f-b59b-a539111b756a
# 27   89cd885e-e653-445f-b59b-a539111b756a
# 28   89cd885e-e653-445f-b59b-a539111b756a
# 34   52bf381b-79a8-4498-8504-41961beda494
# 56   79f898dc-e5e0-4c03-b790-5c49a152297f
# 109  aca77a4e-ecb1-4eb3-a722-979977a52eb4
# 255  73d1964a-125b-4a7f-8482-a76a1b60e23e
# 274  996e1469-01d7-4e94-b18a-c7c970b8c1ec
# 276  fe6aa70f-4877-4f6d-9c18-9a8cafc1fe28
#
#                                     daoId
# 9    d88c6ed5-6ee0-478f-b225-dcdd37b7cafa  \
# 10   28793324-298d-4636-a99d-fc2b248475e4
# 19   f291b357-6413-411b-8ae5-15b8a463fdfc
# 25   733fb812-863e-4d30-9269-d0d04fa015e7
# 27   dffc95c0-d176-4851-a7ff-a6684677e65c
# 28   fd149482-9685-4fa6-8840-370170f5fc8b
# 34   a3382dd2-bb02-4aef-845d-f65229ec9e3e
# 56   5969fbc7-decd-46e2-8778-c144d5e0ced3
# 109  6ccc01bb-6a94-41c8-895f-109638e43fb6
# 255  d542ed0b-b83e-477f-b52b-885ed2e6a950
# 274  37cc4ab5-dd44-445f-a2b0-feda03ad609d
# 276  4f466e08-9125-40fd-ba15-77552dec7c65
#
#                                      name platformTitle  platformId
# 9                             Yam Finance      Governor           6  \
# 10   Rari Foundation: on-chain governance      Governor           6
# 19                              Nouns DAO      Governor           6
# 25            Origin Dollar: Old Governor      Governor           6
# 27       Origin Protocol: OETH Governor 2      Governor           6
# 28     Origin Dollar: On-chain Governance      Governor           6
# 34                               Compound      Governor           6
# 56                           Frax Finance      Governor           6
# 109                               Gitcoin      Governor           6
# 255                               LILNOUN      Governor           6
# 274                                   Fei      Governor           6
# 276                               Uniswap      Governor           6
#
#                        website    mostRecentProposalDate           aum
# 9       https://yam.finance/#/  2020-11-16T22:48:29.000Z  2.437691e+06
# 10                         NaN  2023-05-10T21:08:23.000Z           NaN
# 19          https://nouns.wtf/  2023-06-06T21:15:11.000Z  4.961853e+07
# 25                         NaN                       NaN           NaN
# 27                         NaN                       NaN           NaN
# 28                         NaN                       NaN           NaN
# 34   https://compound.finance/  2023-05-28T19:21:23.000Z           NaN
# 56                         NaN  2022-08-31T21:55:24.000Z           NaN
# 109        https://gitcoin.co/  2023-05-25T15:21:59.000Z  6.303045e+07
# 255      https://lilnouns.wtf/  2023-05-29T00:58:47.000Z  4.580598e+05
# 274          https://fei.money  2021-10-04T04:24:43.000Z           NaN
# 276       https://uniswap.org/  2023-05-09T21:24:59.000Z  1.898706e+09

# %%
df.platformTitle.value_counts().sort_values(ascending=False)
# Out:
# platformTitle
# Snapshot            209
# Aragon               27
# Substrate            18
# Governor             12
# Safe/Snapshot         9
# Moloch / Daohaus      8
# Realms                6
# DAOstack              4
# AssetsOnly            4
# OpenLaw               1
# Name: count, dtype: int64

# %% [markdown]
# ### API access potential by platform type
#
# * **Snapshot**: easy, urls are nicely formatted and Snapshot has a solid API
# * **Aragon**: about half are null, the other half are sometimes Aragon links, but not always. Need to look into API
# * **Substrate**: all nulls, maybe we can match manually, but we need to see if there's an API
# * **Governor**: half nulls, random links

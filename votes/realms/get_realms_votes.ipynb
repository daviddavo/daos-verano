# %%
# glob get all of the json files in ../realms_node/output_votes_2023_6_12
# read them into dfs and concat them into one df

import glob
import pandas as pd

files = glob.glob('../../realms_node/output_votes_2023_6_12/*.json')
len(files)
# Out:
# 7493

# %%
df = pd.concat([pd.read_json(f) for f in files], ignore_index=True)
df.shape
# Out:
# (32481, 3)

# %%
df.head()
# Out:
#                                          pubkey  \
# 0  ATe67y1ut66fZw8ikZzV91UHiMVk2mN5RzqdYf9euWfB
# 1  HFhP5bFDBq6sP54RrkxCir75793686LFCCqbrFRAzgAM
# 2  7Cw6ukhy4wuUnFwgqDAA7m7VkVV5QWiGtDRwVmadx5aZ
# 3  91z2tkWCnEBo7SyoHogqnnRQURQgi1LEKevwwpa5s3UV
# 4  9w6Rh4Tb1BdD3mjHkp99Xf15Vn3LwNvDcaMcZ8o6FDtP
#
#                                              account  \
# 0  {'accountType': 12, 'proposal': 'gb7rhEc4QEucA...
# 1  {'accountType': 12, 'proposal': 'Bc7C6bycdbTSp...
# 2  {'accountType': 12, 'proposal': 'Bc7C6bycdbTSp...
# 3  {'accountType': 12, 'proposal': 'Bc7C6bycdbTSp...
# 4  {'accountType': 12, 'proposal': 'Bc7C6bycdbTSp...
#
#                                           owner
# 0  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 1  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 2  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 3  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 4  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw

# %%
# expand account column
df = pd.concat([df.drop(['account'], axis=1), df['account'].apply(pd.Series)], axis=1)
df.head()
# Out:
#                                          pubkey  \
# 0  ATe67y1ut66fZw8ikZzV91UHiMVk2mN5RzqdYf9euWfB
# 1  HFhP5bFDBq6sP54RrkxCir75793686LFCCqbrFRAzgAM
# 2  7Cw6ukhy4wuUnFwgqDAA7m7VkVV5QWiGtDRwVmadx5aZ
# 3  91z2tkWCnEBo7SyoHogqnnRQURQgi1LEKevwwpa5s3UV
# 4  9w6Rh4Tb1BdD3mjHkp99Xf15Vn3LwNvDcaMcZ8o6FDtP
#
#                                           owner  accountType  \
# 0  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 1  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 2  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 3  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 4  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
#
#                                        proposal  \
# 0   gb7rhEc4QEucAiHaM1zvs93MnDCbWfv5nJLNdereKoX
# 1  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 2  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 3  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 4  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
#
#                             governingTokenOwner  isRelinquished voterWeight  \
# 0  FspfkJieTyVVRrhHiKqkWcVeRwXdrag1p4SzMVNssRrJ            True           1
# 1   96ZVN79M5QKsJcvXkxuEx9wYWoCYZHtuP1Y8EJhrJyw           False           1
# 2   SQ2t2hU2g5nofFt3D5MhNfaey7QSjEHe5pBEFCPP2F7           False           1
# 3  568F8CYYDE9BuKPqw5MzYFqwafDSWagPQMz8XQi19RXq           False           1
# 4  5H1RddHVDfnr9LZ9iP3apPQLcXbN9uFWJUjzU9N9iFB2            True           1
#
#                                                 vote voteWeight
# 0  {'voteType': 0, 'approveChoices': [{'rank': 0,...        NaN
# 1  {'voteType': 0, 'approveChoices': [{'rank': 0,...        NaN
# 2  {'voteType': 0, 'approveChoices': [{'rank': 0,...        NaN
# 3  {'voteType': 0, 'approveChoices': [{'rank': 0,...        NaN
# 4  {'voteType': 0, 'approveChoices': [{'rank': 0,...        NaN

# %%
df.shape
# Out:
# (32481, 9)

# %%
# keep only where isRelinquished is False
df = df[df['isRelinquished'] == False]
df.shape
# Out:
# (22552, 9)

# %%
# count number of unique values in each column except 'vote' and 'voteWeight'
df[['pubkey', 'owner', 'accountType', 'proposal', 'governingTokenOwner',
       'isRelinquished', 'voterWeight']].nunique()
# Out:
# pubkey                 22552
# owner                      1
# accountType                2
# proposal                6386
# governingTokenOwner     4187
# isRelinquished             1
# voterWeight             1076
# dtype: int64

# %%
# expand the 'vote' column
df = pd.concat([df.drop(['vote'], axis=1), df['vote'].apply(pd.Series)], axis=1)
df.head()
# Out:
#                                          pubkey  \
# 1  HFhP5bFDBq6sP54RrkxCir75793686LFCCqbrFRAzgAM
# 2  7Cw6ukhy4wuUnFwgqDAA7m7VkVV5QWiGtDRwVmadx5aZ
# 3  91z2tkWCnEBo7SyoHogqnnRQURQgi1LEKevwwpa5s3UV
# 5  C2E43Xunhb4xPwcqrb5fvg9MXktJbvUNHGdLiXNKHrci
# 6  AvywQhmbye96npitAKK41ETVWHLqXvDarGpVqGfEcTMG
#
#                                           owner  accountType  \
# 1  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 2  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 3  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 5  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 6  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
#
#                                        proposal  \
# 1  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 2  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 3  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 5  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 6  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
#
#                             governingTokenOwner  isRelinquished voterWeight  \
# 1   96ZVN79M5QKsJcvXkxuEx9wYWoCYZHtuP1Y8EJhrJyw           False           1
# 2   SQ2t2hU2g5nofFt3D5MhNfaey7QSjEHe5pBEFCPP2F7           False           1
# 3  568F8CYYDE9BuKPqw5MzYFqwafDSWagPQMz8XQi19RXq           False           1
# 5  5qAnY8pqRa4ZyLDmXv8t9eChN52EtZs63SiCPY9KdWJh           False           1
# 6  8oETCEBmvajGi3G2tLfm4gesigxuE1z7eyLgArRgbU56           False           1
#
#   voteWeight  voteType                          approveChoices deny veto   0
# 1        NaN       0.0  [{'rank': 0, 'weightPercentage': 100}]  NaN  NaN NaN
# 2        NaN       0.0  [{'rank': 0, 'weightPercentage': 100}]  NaN  NaN NaN
# 3        NaN       0.0  [{'rank': 0, 'weightPercentage': 100}]  NaN  NaN NaN
# 5        NaN       0.0  [{'rank': 0, 'weightPercentage': 100}]  NaN  NaN NaN
# 6        NaN       0.0  [{'rank': 0, 'weightPercentage': 100}]  NaN  NaN NaN

# %%
df['voterWeight'].describe()
# Out:
# count     21510
# unique     1076
# top           1
# freq      10482
# Name: voterWeight, dtype: object

# %%
# make voter weight into a float
df['voterWeight'] = df['voterWeight'].astype(float)

# %%
# voteWeight describe
df['voteWeight'].describe()
# Out:
# count                         1042
# unique                         129
# top       {'yes': '1000000000000'}
# freq                           389
# Name: voteWeight, dtype: object

# %%
df['approveChoices'].value_counts()
# Out:
# [{'rank': 0, 'weightPercentage': 100}]    20929
# Name: approveChoices, dtype: int64

# %%
# isRelinquished val counts
df['isRelinquished'].value_counts()
# Out:
# False    22552
# Name: isRelinquished, dtype: int64

# %%
# vote types val counts
df['voteType'].value_counts()
# Out:
# 0.0    20929
# 1.0      572
# 3.0        9
# Name: voteType, dtype: int64

# %%
df[df['voteType'] == 1]
# Out:
#                                              pubkey  \
# 21     6APMtS9TKsa896hnkSUfH1xomxMsN9Phka1EmMXR17WY
# 117    3bCAGfXgtrWkJ9qUncHeP3PJjEXbc9ZUhjy99xC8ZuCj
# 153    5HgkKoffJro4r1su5YZdVD4WWvpT8CkToLtxtmXsjbUN
# 154    DgyswWDLBDPAx56NFjhcUrJkqWoAPAcnCenhVUBTUs3v
# 197    CqN7HVnSgMzrVVLnVzXipZMcPHvNsLjdMnNRr4qfXP7t
# ...                                             ...
# 32281  GJdcaokX9TNGEyFTLoEw9bWjJLiPr7bHiTRae8xaHecX
# 32282  7WEpgKwqx86FT1nFZqsKWTUoj3zkxg1q5w3YNqxPpuS1
# 32284  94s3W4XyWHRrmyFS221aLRMZGjNMTprArbAybW6NJTAV
# 32285  3kZ2h61FbrxYjYFF1bJSsf1FiUm2bUqCMToqKt5y3TPq
# 32287  HwRdPvnmyHrrRAGs5H3vbmcr97HMUXZCj4U3xbusMLzv
#
#                                               owner  accountType  \
# 21     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 117    GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 153    GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 154    GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 197    GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# ...                                             ...          ...
# 32281  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 32282  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 32284  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 32285  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 32287  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
#
#                                            proposal  \
# 21     8gynPCCcsfmKP26CCptSWRVUzL3UKmJRWsUYsm4KV46G
# 117    Dm9f1r5Fuv9x9bHKP3yA58WvVgAEbb3y7QEJZrdhCcdd
# 153    6chU6kDq1CsphWFHCgdxAHRMgYMWDd6Hy1CCf6BHUs3g
# 154    6chU6kDq1CsphWFHCgdxAHRMgYMWDd6Hy1CCf6BHUs3g
# 197    GDaMkrXrqmKYBzw1h3BdV6zJxKsM9f3Q6eAM2RFKDSE9
# ...                                             ...
# 32281  EpdKrrNtaGzzY76YVekMfTM8bFJuAci8n58NXvUjcKQe
# 32282  EpdKrrNtaGzzY76YVekMfTM8bFJuAci8n58NXvUjcKQe
# 32284  5YuqC1N6Hf8ZQ8TEmn8QdHcxRzKRRuHhN3dZHxWdJbg6
# 32285  5YuqC1N6Hf8ZQ8TEmn8QdHcxRzKRRuHhN3dZHxWdJbg6
# 32287  5YuqC1N6Hf8ZQ8TEmn8QdHcxRzKRRuHhN3dZHxWdJbg6
#
#                                 governingTokenOwner  isRelinquished  \
# 21     3DvJWcHhtdhNLWMeBCh2Rma5chxyDWxoMmVvBFLihMZe           False
# 117    7zP1BjWppJNpVj1ioxpKE9SaejxSismd8J7d3ortEcNn           False
# 153    Fywb7YDCXxtD7pNKThJ36CAtVe23dEeEPf7HqKzJs1VG           False
# 154    GPXiHb4tKGX9zntTmcLipujndnN8ZB6bVSHjLHagMbyc           False
# 197    GDRpHEHSrx8VvCJVzR75UKFp7CCYPT11fRrKZYYGFok2           False
# ...                                             ...             ...
# 32281  98Bs3j1m8YNe9U8f4T6Cjutru7EofCRkqdbWwwyvh6KU           False
# 32282  EJtd6WCbJtbNThqSESBoAQnZ1dL6DJJvQysVouiuZUS3           False
# 32284  5b6tq8bVS6EXZUTy5jchR3rgYZ966Bq7N5W6x212E1gy           False
# 32285  6z9R221EcjwupbkjaHbaKtxP8BV9CXSax24mkC1n6rbf           False
# 32287  98Bs3j1m8YNe9U8f4T6Cjutru7EofCRkqdbWwwyvh6KU           False
#
#         voterWeight voteWeight  voteType approveChoices  deny   veto   0
# 21     1.000000e+00        NaN       1.0            NaN  True  False NaN
# 117    1.000000e+06        NaN       1.0            NaN  True  False NaN
# 153    3.333420e+10        NaN       1.0            NaN  True  False NaN
# 154    7.229752e+10        NaN       1.0            NaN  True  False NaN
# 197    1.393064e+13        NaN       1.0            NaN  True  False NaN
# ...             ...        ...       ...            ...   ...    ...  ..
# 32281  1.000000e+06        NaN       1.0            NaN  True  False NaN
# 32282  2.000000e+06        NaN       1.0            NaN  True  False NaN
# 32284  1.000000e+06        NaN       1.0            NaN  True  False NaN
# 32285  2.000000e+06        NaN       1.0            NaN  True  False NaN
# 32287  1.000000e+06        NaN       1.0            NaN  True  False NaN
#
# [572 rows x 13 columns]

# %%
df[df['voteType'] == 3]
# Out:
#                                              pubkey  \
# 7163   FjWsdvy6hcA7ZJWghbd6NUdhUZxj7heZcUBXPJaM6r5C
# 8973   C2XviZ873H9hEUT3mNpvKuaPCi5iAcGJfkYQQDXEHo83
# 11381  BZGrnWbFxQ1eSJjirCPj54VpeTf3wtqtMwpk3hjunA3R
# 13588  4J4BbHnsTisZ4ScAZNTvPVPA17VeqzVGz1zgmHFpCsnp
# 13589  5vUkxuFkhRd8SNJsMrm7GykEQLusn2Lvew1E7x8AuDVb
# 15502  8YmSKpr5ofkfpcRjSA4ureUyS8buosjhiE3gvt8iUm2L
# 26716  DvYC2CcpeKTDRpUhYj4f7shj4LzcWrLFEA1eshbkkfa3
# 28651  BAu6T5wEVijabTNwWPdD53ASt1kZ4N1YUywYMCRj82WT
# 31299  ADfq68ZLnHDLt6Ggx3esdkJ2TxspbxY8yHjBFBwE3bvs
#
#                                               owner  accountType  \
# 7163   GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 8973   GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 11381  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 13588  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 13589  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 15502  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 26716  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 28651  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 31299  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
#
#                                            proposal  \
# 7163   128MWNwvwjqAtU1ZqvwnrX3HMhY42rFSSvbyYzuSkpMi
# 8973   BBHBLZ3awWLNZjHhRdZgzBCn17iB7YRMyiHhpLP63EJ7
# 11381  FyghM2rET3njNtfhax2LirAGWxCLeXpudY5qy3ubZoFr
# 13588  DMGbSh8nBVqtmaTG7Fhq5CFS7nzbUEwBVAaR8XmRvjXM
# 13589  DMGbSh8nBVqtmaTG7Fhq5CFS7nzbUEwBVAaR8XmRvjXM
# 15502  HqGoDPypXKDe7tpwJQLf25mzYe1djREFSU8RXamrS6cP
# 26716  DoVYMK8wPX5hVgUdmndwrqa3BuUYsX15zCijQBCCcLva
# 28651  CuPbeKMHdn9GePu1sX7XEvn6TzsjkVSjV836carmyJmN
# 31299  BYRFtxF1G6TavnrtZefFkK6sjB5SnEvp96em9Wz9hW6U
#
#                                 governingTokenOwner  isRelinquished  \
# 7163   AJW9c7grTANYwrbzwjKNBekeGuiB2GK6spWwQJTpqYAk           False
# 8973   A8dfe8V1YhUw2wY8fNY4KribVaJj6a3xxGh5quaRJjFS           False
# 11381  7pb4YQPXPEQv3pCfQVKRoCCU3Rq3mEakJZFDhbMHtPBK           False
# 13588  36s2k5Njh3TyAekzvMpJ1bQt218ujZQgQftzqucfsT9h           False
# 13589  4iP8x3kMB3TJGhtpkng17wdHXyo4jj99K1N2Bk6mu3pW           False
# 15502  6z1gWMqqb3Umh5zZAT8sFneBcDaaWeSFtJF199oL9hME           False
# 26716  Fywb7YDCXxtD7pNKThJ36CAtVe23dEeEPf7HqKzJs1VG           False
# 28651  AJW9c7grTANYwrbzwjKNBekeGuiB2GK6spWwQJTpqYAk           False
# 31299  CkbxaunPif9H3Zq24nyY87pKUe64GRteciPL5qXLUdzC           False
#
#        voterWeight voteWeight  voteType approveChoices   deny  veto   0
# 7163           1.0        NaN       3.0            NaN  False  True NaN
# 8973           1.0        NaN       3.0            NaN  False  True NaN
# 11381          1.0        NaN       3.0            NaN  False  True NaN
# 13588          1.0        NaN       3.0            NaN  False  True NaN
# 13589          1.0        NaN       3.0            NaN  False  True NaN
# 15502          1.0        NaN       3.0            NaN  False  True NaN
# 26716          1.0        NaN       3.0            NaN  False  True NaN
# 28651          1.0        NaN       3.0            NaN  False  True NaN
# 31299          2.0        NaN       3.0            NaN  False  True NaN

# %%
# * platform
df['platform'] = 'realms'
# * platform_deployment_id TKTKTK, need to merge w the proposals data
# * proposal rename to proposal_id
df.rename(columns={'proposal': 'proposal_id'}, inplace=True)
# * pubkey to vote_id
df.rename(columns={'pubkey': 'vote_id'}, inplace=True)
# * governingTokenOwner to voter
df.rename(columns={'governingTokenOwner': 'voter'}, inplace=True)
# * date doesn't exist, fill nans
df['date'] = pd.NaT
# * choice
df.rename(columns={'approveChoices': 'choice'}, inplace=True)
# * voterWeight to weight
df.rename(columns={'voterWeight': 'weight'}, inplace=True)

df = df[['platform', 'proposal_id', 'vote_id', 'voter', 'date', 'choice', 'weight']]
df.head()
# Out:
#   platform                                   proposal_id  \
# 1   realms  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 2   realms  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 3   realms  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 5   realms  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 6   realms  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
#
#                                         vote_id  \
# 1  HFhP5bFDBq6sP54RrkxCir75793686LFCCqbrFRAzgAM
# 2  7Cw6ukhy4wuUnFwgqDAA7m7VkVV5QWiGtDRwVmadx5aZ
# 3  91z2tkWCnEBo7SyoHogqnnRQURQgi1LEKevwwpa5s3UV
# 5  C2E43Xunhb4xPwcqrb5fvg9MXktJbvUNHGdLiXNKHrci
# 6  AvywQhmbye96npitAKK41ETVWHLqXvDarGpVqGfEcTMG
#
#                                           voter date  \
# 1   96ZVN79M5QKsJcvXkxuEx9wYWoCYZHtuP1Y8EJhrJyw  NaT
# 2   SQ2t2hU2g5nofFt3D5MhNfaey7QSjEHe5pBEFCPP2F7  NaT
# 3  568F8CYYDE9BuKPqw5MzYFqwafDSWagPQMz8XQi19RXq  NaT
# 5  5qAnY8pqRa4ZyLDmXv8t9eChN52EtZs63SiCPY9KdWJh  NaT
# 6  8oETCEBmvajGi3G2tLfm4gesigxuE1z7eyLgArRgbU56  NaT
#
#                                    choice  weight
# 1  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 2  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 3  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 5  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 6  [{'rank': 0, 'weightPercentage': 100}]     1.0

# %%
proposals_df = pd.read_csv('../../proposals/realms/realms_proposals.csv')
proposals_df.head()
# Out:
#   platform                        platform_deployment_id  \
# 0   realms  7cWnmakdFUUVrJNbY2Mm5riXWBKwb3rPrkTUgPboGcx1
# 1   realms  7cWnmakdFUUVrJNbY2Mm5riXWBKwb3rPrkTUgPboGcx1
# 2   realms  7LznoL3LEjkGPM89NoBGjQ9E7Bh71biS3F8b3DQwUbpt
# 3   realms  Dzpog9qdmW3Tfyxq1NCwC2q4v4PhcpJtTmQmZHsPGtFj
# 4   realms  Dzpog9qdmW3Tfyxq1NCwC2q4v4PhcpJtTmQmZHsPGtFj
#
#                                     proposal_id  author                 date  \
# 0  9KXakky9yScaqfk842xAnN5ukWq7bMig9gNsyPMeAFsL     NaN  2022-05-03 19:58:24
# 1   Z2FNZAc8EKTMQVZEvXXtnUbrMsFvrJXDXSih5rCeiS3     NaN  2022-05-03 19:57:14
# 2  7GPyFfPigUFG7Z4essQwxpX1tWd64Yd164ZCBfsALMKu     NaN  2022-11-02 00:30:14
# 3  A4LsZPHwFmZLLE15stN6PrtRwEKe5SPv1dd2b1NDYqCi     NaN  2022-06-10 22:19:03
# 4  5WHz1rszWGMKbhpmZrJcr1ttQZtBEtxjGGDSuEUpcPPS     NaN  2022-06-17 16:05:39
#
#    votes_count
# 0            3
# 1            2
# 2            1
# 3            2
# 4            5

# %%
proposals_df = proposals_df[['platform_deployment_id', 'proposal_id']]
proposals_df.head()
# Out:
#                          platform_deployment_id  \
# 0  7cWnmakdFUUVrJNbY2Mm5riXWBKwb3rPrkTUgPboGcx1
# 1  7cWnmakdFUUVrJNbY2Mm5riXWBKwb3rPrkTUgPboGcx1
# 2  7LznoL3LEjkGPM89NoBGjQ9E7Bh71biS3F8b3DQwUbpt
# 3  Dzpog9qdmW3Tfyxq1NCwC2q4v4PhcpJtTmQmZHsPGtFj
# 4  Dzpog9qdmW3Tfyxq1NCwC2q4v4PhcpJtTmQmZHsPGtFj
#
#                                     proposal_id
# 0  9KXakky9yScaqfk842xAnN5ukWq7bMig9gNsyPMeAFsL
# 1   Z2FNZAc8EKTMQVZEvXXtnUbrMsFvrJXDXSih5rCeiS3
# 2  7GPyFfPigUFG7Z4essQwxpX1tWd64Yd164ZCBfsALMKu
# 3  A4LsZPHwFmZLLE15stN6PrtRwEKe5SPv1dd2b1NDYqCi
# 4  5WHz1rszWGMKbhpmZrJcr1ttQZtBEtxjGGDSuEUpcPPS

# %%
# merge df <- proposals_df
df = pd.merge(df, proposals_df, on='proposal_id', how='left', validate='m:1')
df.head()
# Out:
#   platform                                   proposal_id  \
# 0   realms  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 1   realms  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 2   realms  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 3   realms  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 4   realms  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
#
#                                         vote_id  \
# 0  HFhP5bFDBq6sP54RrkxCir75793686LFCCqbrFRAzgAM
# 1  7Cw6ukhy4wuUnFwgqDAA7m7VkVV5QWiGtDRwVmadx5aZ
# 2  91z2tkWCnEBo7SyoHogqnnRQURQgi1LEKevwwpa5s3UV
# 3  C2E43Xunhb4xPwcqrb5fvg9MXktJbvUNHGdLiXNKHrci
# 4  AvywQhmbye96npitAKK41ETVWHLqXvDarGpVqGfEcTMG
#
#                                           voter date  \
# 0   96ZVN79M5QKsJcvXkxuEx9wYWoCYZHtuP1Y8EJhrJyw  NaT
# 1   SQ2t2hU2g5nofFt3D5MhNfaey7QSjEHe5pBEFCPP2F7  NaT
# 2  568F8CYYDE9BuKPqw5MzYFqwafDSWagPQMz8XQi19RXq  NaT
# 3  5qAnY8pqRa4ZyLDmXv8t9eChN52EtZs63SiCPY9KdWJh  NaT
# 4  8oETCEBmvajGi3G2tLfm4gesigxuE1z7eyLgArRgbU56  NaT
#
#                                    choice  weight  \
# 0  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 1  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 2  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 3  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 4  [{'rank': 0, 'weightPercentage': 100}]     1.0
#
#                          platform_deployment_id
# 0  84pGFuy1Y27ApK67ApethaPvexeDWA66zNV8gm38TVeQ
# 1  84pGFuy1Y27ApK67ApethaPvexeDWA66zNV8gm38TVeQ
# 2  84pGFuy1Y27ApK67ApethaPvexeDWA66zNV8gm38TVeQ
# 3  84pGFuy1Y27ApK67ApethaPvexeDWA66zNV8gm38TVeQ
# 4  84pGFuy1Y27ApK67ApethaPvexeDWA66zNV8gm38TVeQ

# %%
# how many null values in platform_deployment_id
df['platform_deployment_id'].isnull().sum()
# Out:
# 0

# %%
# reorder cols
df = df[['platform', 'platform_deployment_id', 'proposal_id', 'vote_id', 'voter', 'date', 'choice', 'weight']]
df.head()
# Out:
#   platform                        platform_deployment_id  \
# 0   realms  84pGFuy1Y27ApK67ApethaPvexeDWA66zNV8gm38TVeQ
# 1   realms  84pGFuy1Y27ApK67ApethaPvexeDWA66zNV8gm38TVeQ
# 2   realms  84pGFuy1Y27ApK67ApethaPvexeDWA66zNV8gm38TVeQ
# 3   realms  84pGFuy1Y27ApK67ApethaPvexeDWA66zNV8gm38TVeQ
# 4   realms  84pGFuy1Y27ApK67ApethaPvexeDWA66zNV8gm38TVeQ
#
#                                     proposal_id  \
# 0  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 1  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 2  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 3  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
# 4  Bc7C6bycdbTSpd21NtVqHo2jn3N7GCMYz8PZz3pz6Kob
#
#                                         vote_id  \
# 0  HFhP5bFDBq6sP54RrkxCir75793686LFCCqbrFRAzgAM
# 1  7Cw6ukhy4wuUnFwgqDAA7m7VkVV5QWiGtDRwVmadx5aZ
# 2  91z2tkWCnEBo7SyoHogqnnRQURQgi1LEKevwwpa5s3UV
# 3  C2E43Xunhb4xPwcqrb5fvg9MXktJbvUNHGdLiXNKHrci
# 4  AvywQhmbye96npitAKK41ETVWHLqXvDarGpVqGfEcTMG
#
#                                           voter date  \
# 0   96ZVN79M5QKsJcvXkxuEx9wYWoCYZHtuP1Y8EJhrJyw  NaT
# 1   SQ2t2hU2g5nofFt3D5MhNfaey7QSjEHe5pBEFCPP2F7  NaT
# 2  568F8CYYDE9BuKPqw5MzYFqwafDSWagPQMz8XQi19RXq  NaT
# 3  5qAnY8pqRa4ZyLDmXv8t9eChN52EtZs63SiCPY9KdWJh  NaT
# 4  8oETCEBmvajGi3G2tLfm4gesigxuE1z7eyLgArRgbU56  NaT
#
#                                    choice  weight
# 0  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 1  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 2  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 3  [{'rank': 0, 'weightPercentage': 100}]     1.0
# 4  [{'rank': 0, 'weightPercentage': 100}]     1.0

# %%
# save to csv
df.to_csv('realms_votes.csv', index=False)

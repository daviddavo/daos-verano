# %%
# get all the csvs that end with _deployments.csv in this directory
import glob
csvs = glob.glob('./*/[a-z]*_deployments.csv')
csvs
# Out:
# ['./snapshot/snapshot_deployments.csv',
#  './aragon/aragon_deployments.csv',
#  './daostack/daostack_deployments.csv',
#  './realms/realm_deployments.csv',
#  './tally/tally_deployments.csv',
#  './daohaus/dao_deployments.csv']

# %%
# concat into one dataframe
import pandas as pd
df = pd.concat([pd.read_csv(csv) for csv in csvs])
# reindex
df = df.reset_index(drop=True)
df
# Out:
#        platform                                 platform_id  \
# 0      snapshot                                  odidao.eth
# 1      snapshot                                  olodao.eth
# 2      snapshot                                 onearth.eth
# 3      snapshot                                  opyn11.eth
# 4      snapshot                        partyplanningdao.eth
# ...         ...                                         ...
# 21993   daohaus  0xff07943f171b826b3618982a6213f157fbc5e226
# 21994   daohaus  0xff3f8c0b98454306fb0bda57e5ae38cbfa66cc0d
# 21995   daohaus  0xff4b20d48a1e8f93bf6745de388547e731f96fd0
# 21996   daohaus  0xffb676765d521518ac5c0d4f4067a9db9b72901b
# 21997   daohaus  0xffe8a8ec2477390c6b97074f44326fac24d7f6dd
#
#                      name                                         additional  \
# 0                 ODI DAO                                                NaN
# 1                 YING TG  https://www.partybid.app/buy/0xB74BE402fEfE6bb...
# 2             OnEarth DAO  kevinonearth999, https://imagineonearth.xpandr...
# 3                  opyn11                                                NaN
# 4      Party Planning DAO                                                NaN
# ...                   ...                                                ...
# 21993                 NaN                         network: xdai version: 2.1
# 21994   array.finance CCO                         network: xdai version: 2.1
# 21995           PRIDEdao                          network: xdai version: 2.1
# 21996           EmpanaDAO                         network: xdai version: 2.0
# 21997     Kokonut Network                         network: xdai version: 2.1
#
#                                            website  votes_count  \
# 0                https://snapshot.org/#/odidao.eth          1.0
# 1                https://snapshot.org/#/olodao.eth          6.0
# 2               https://snapshot.org/#/onearth.eth          6.0
# 3                https://snapshot.org/#/opyn11.eth          5.0
# 4      https://snapshot.org/#/partyplanningdao.eth          1.0
# ...                                            ...          ...
# 21993                                          NaN          0.0
# 21994                                          NaN        123.0
# 21995                                          NaN          0.0
# 21996                                          NaN          0.0
# 21997                                          NaN        264.0
#
#        proposals_count
# 0                  6.0
# 1                  1.0
# 2                  3.0
# 3                  1.0
# 4                  1.0
# ...                ...
# 21993              0.0
# 21994            122.0
# 21995              0.0
# 21996              3.0
# 21997             89.0
#
# [21998 rows x 7 columns]

# %%
# save to csv
df.to_csv('all_deployments.csv', index=False)

# %%
# are there duplicate platform and platform id rows?
df[df.duplicated(subset=['platform', 'platform_id'], keep=False)]
# Out:
#        platform     platform_id              name  \
# 17     snapshot     taiyiyi.eth        taiyiyiDAO
# 18     snapshot         tap.eth  Dollar Save Club
# 19     snapshot        tart.eth      ZEENUS DUMMY
# 210    snapshot     losruan.eth              零秒出手
# 1365   snapshot     highjkl.eth          moon dao
# 1927   snapshot     losruan.eth              零秒出手
# 2260   snapshot     taiyiyi.eth        taiyiyiDAO
# 2261   snapshot         tap.eth  Dollar Save Club
# 2262   snapshot        tart.eth      ZEENUS DUMMY
# 2760   snapshot     0xkexue.eth             kexue
# 2761   snapshot       1024c.eth             1024C
# 2762   snapshot       10arb.eth               btc
# 2763   snapshot       12301.eth          12301DAO
# 3321   snapshot  thehuemans.eth              HUES
# 3894   snapshot     0xkexue.eth             kexue
# 3895   snapshot       1024c.eth             1024C
# 3896   snapshot       10arb.eth               btc
# 3897   snapshot       12301.eth          12301DAO
# 6710   snapshot         scc.eth               SCC
# 7476   snapshot     highjkl.eth          moon dao
# 7520   snapshot    peptoshi.eth          Mithical
# 8800   snapshot    peptoshi.eth          Mithical
# 10038  snapshot   canberich.eth               gdf
# 10276  snapshot   canberich.eth               gdf
# 12418  snapshot  thehuemans.eth              HUES
# 13117  snapshot         scc.eth               SCC
#
#                                   additional  \
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 210                                      NaN
# 1365                                     NaN
# 1927                                     NaN
# 2260                                     NaN
# 2261                                     NaN
# 2262                                     NaN
# 2760                                     NaN
# 2761                                     NaN
# 2762                                     NaN
# 2763                                     NaN
# 3321                                 huesnft
# 3894                                     NaN
# 3895                                     NaN
# 3896                                     NaN
# 3897                                     NaN
# 6710                                  sccdao
# 7476                                     NaN
# 7520   Mithical_io, https://www.mithical.io/
# 8800   Mithical_io, https://www.mithical.io/
# 10038                                    NaN
# 10276                                    NaN
# 12418                                huesnft
# 13117                                 sccdao
#
#                                      website  votes_count  proposals_count
# 17        https://snapshot.org/#/taiyiyi.eth          5.0              2.0
# 18            https://snapshot.org/#/tap.eth          9.0              3.0
# 19           https://snapshot.org/#/tart.eth          5.0              7.0
# 210       https://snapshot.org/#/losruan.eth          2.0              4.0
# 1365      https://snapshot.org/#/highjkl.eth          1.0              2.0
# 1927      https://snapshot.org/#/losruan.eth          2.0              4.0
# 2260      https://snapshot.org/#/taiyiyi.eth          5.0              2.0
# 2261          https://snapshot.org/#/tap.eth          9.0              3.0
# 2262         https://snapshot.org/#/tart.eth          5.0              7.0
# 2760      https://snapshot.org/#/0xkexue.eth          0.0              0.0
# 2761        https://snapshot.org/#/1024c.eth          0.0              0.0
# 2762        https://snapshot.org/#/10arb.eth          0.0              0.0
# 2763        https://snapshot.org/#/12301.eth         27.0              4.0
# 3321   https://snapshot.org/#/thehuemans.eth          0.0              1.0
# 3894      https://snapshot.org/#/0xkexue.eth          0.0              0.0
# 3895        https://snapshot.org/#/1024c.eth          0.0              0.0
# 3896        https://snapshot.org/#/10arb.eth          0.0              0.0
# 3897        https://snapshot.org/#/12301.eth         27.0              4.0
# 6710          https://snapshot.org/#/scc.eth          0.0              6.0
# 7476      https://snapshot.org/#/highjkl.eth          1.0              2.0
# 7520     https://snapshot.org/#/peptoshi.eth          0.0              1.0
# 8800     https://snapshot.org/#/peptoshi.eth          0.0              1.0
# 10038   https://snapshot.org/#/canberich.eth          1.0              1.0
# 10276   https://snapshot.org/#/canberich.eth          1.0              1.0
# 12418  https://snapshot.org/#/thehuemans.eth          0.0              1.0
# 13117         https://snapshot.org/#/scc.eth          0.0              6.0

# %%
# remove 'em
df = df.drop_duplicates(subset=['platform', 'platform_id'], keep='first')
df.shape
# Out:
# (21985, 7)

# %%
# what pct have names?
df[df['name'].notnull()].shape[0] / df.shape[0]
# Out:
# 0.857311803502388

# %%
# platform vlaue counts annotated with count
import matplotlib.pyplot as plt
df['platform'].value_counts().plot(kind='bar')
# annotate
for i, v in enumerate(df['platform'].value_counts()):
    plt.text(i - .25, v + 200, str(v))
# title
plt.suptitle('Deployments by platform, no filtering')
plt.title('Note: snapshot maxed out at 16k deployments', fontsize=8)
plt.show()

# %%
import seaborn as sns
f, ax = plt.subplots(figsize=(7, 7))
# small dots
sns.scatterplot(x='proposals_count', y='votes_count', hue='platform', data=df, s=8, ax=ax)
ax.set(xscale="log", yscale="log")
plt.suptitle('Votes count by proposal count, no filtering')
plt.show()

# %% [markdown]
# # Filtering

# %%
# hist of proposals_count, log scale
df['proposals_count'].plot(kind='hist', bins=100, logy=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# hist of votes_count, log scale
df['votes_count'].plot(kind='hist', bins=100, logy=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.shape
# Out:
# (21985, 7)

# %%
# keep only the daos that have more than ten votes and more than ten proposals
# filtered_df = df[(df['proposals_count'] > 10) & (df['votes_count'] > 10)]
# filtered_df.shape

# %%
# if we filtered by 50 and 50?
df[(df['proposals_count'] > 50) & (df['votes_count'] > 50)].shape
# Out:
# (495, 7)

# %%
# 50 votes and 10 proposals
filtered_df = df[(df['proposals_count'] > 10) & (df['votes_count'] > 50)]
# filtered_df = df[(df['proposals_count'] > 10) & (df['votes_count'] > 50)]
filtered_df.shape
# Out:
# (1645, 7)

# %%
# platform vlaue counts annotated with count
import matplotlib.pyplot as plt
filtered_df['platform'].value_counts().plot(kind='bar')
# annotate
for i, v in enumerate(filtered_df['platform'].value_counts()):
    plt.text(i - .25, v + 20, str(v))
# title
plt.suptitle('Deployments by platform, DAOS with >50 votes and >10 proposals')
plt.title('Note: snapshot maxed out at 16k deployments', fontsize=8)
plt.show()

# %%
# run the charts again
f, ax = plt.subplots(figsize=(7, 7))
# small dots
sns.scatterplot(x='proposals_count', y='votes_count', hue='platform', data=filtered_df, s=8, ax=ax)
ax.set(xscale="log", yscale="log")
plt.suptitle('Votes count by proposal count, DAOS with >50 votes and >10 proposals')
plt.show()

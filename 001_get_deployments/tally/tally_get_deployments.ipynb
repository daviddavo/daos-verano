# %%
import requests

response = requests.get('https://www.tally.xyz/api/search-daos')

import pandas as pd
df = pd.DataFrame(response.json()['governances'])
df.head()
# Out:
#                                                   id               slug  \
# 0  eip155:10:0x8087dE46076212A21EA5cD8b4368BCbd82...  sector-3-optimism
# 1  eip155:137:0x3343aEb44A2a277e3Ae346014e181aE15...           coindaox
# 2  eip155:1:0x064515Cc2dcf070b6302d2B9ffc9643c449...                tai
# 3  eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...  spore-engineering
# 4  eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...               diva
#
#                   name        kind     chainId  \
# 0  Sector#3 (Optimism)  SINGLE_GOV   eip155:10
# 1             CoinDaoX  SINGLE_GOV  eip155:137
# 2       TAI Governance  SINGLE_GOV    eip155:1
# 3    Spore Engineering  SINGLE_GOV  eip155:100
# 4         Diva Staking  SINGLE_GOV    eip155:1
#
#                                         organization
# 0  {'name': 'Sector#3 (Optimism)', 'slug': 'secto...
# 1  {'name': 'CoinDaoX', 'slug': 'coindaox', 'visu...
# 2  {'name': 'TAI Governance', 'slug': 'tai-govern...
# 3  {'name': 'Spore Engineering', 'slug': 'dsfsdf'...
# 4  {'name': 'Diva Staking', 'slug': 'diva-staking...

# %%
df.columns
# Out:
# Index(['id', 'slug', 'name', 'kind', 'chainId', 'organization'], dtype='object')

# %%
# expand the organization column
df = pd.concat([df.drop(['organization'], axis=1), df['organization'].apply(pd.Series)], axis=1)
df.head()
# Out:
#                                                   id               slug  \
# 0  eip155:10:0x8087dE46076212A21EA5cD8b4368BCbd82...  sector-3-optimism
# 1  eip155:137:0x3343aEb44A2a277e3Ae346014e181aE15...           coindaox
# 2  eip155:1:0x064515Cc2dcf070b6302d2B9ffc9643c449...                tai
# 3  eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...  spore-engineering
# 4  eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...               diva
#
#                   name        kind     chainId                 name  \
# 0  Sector#3 (Optimism)  SINGLE_GOV   eip155:10  Sector#3 (Optimism)
# 1             CoinDaoX  SINGLE_GOV  eip155:137             CoinDaoX
# 2       TAI Governance  SINGLE_GOV    eip155:1       TAI Governance
# 3    Spore Engineering  SINGLE_GOV  eip155:100    Spore Engineering
# 4         Diva Staking  SINGLE_GOV    eip155:1         Diva Staking
#
#                 slug                                             visual  \
# 0  sector-3-optimism  {'icon': 'https://static.tally.xyz/268e141b-ec...
# 1           coindaox  {'icon': 'https://static.tally.xyz/24c28289-66...
# 2   tai-governance-1  {'icon': 'https://static.tally.xyz/5b7ab399-b2...
# 3             dsfsdf  {'icon': 'https://static.tally.xyz/fbe60111-1b...
# 4       diva-staking  {'icon': 'https://static.tally.xyz/3c15ec19-51...
#
#                                          governances
# 0  [{'stats': {'proposals': {'active': 0, 'total'...
# 1  [{'stats': {'proposals': {'active': 0, 'total'...
# 2  [{'stats': {'proposals': {'active': 0, 'total'...
# 3  [{'stats': {'proposals': {'active': 0, 'total'...
# 4  [{'stats': {'proposals': {'active': 0, 'total'...

# %%
df.iloc[0]['governances']
# Out:
# [{'stats': {'proposals': {'active': 0, 'total': 0},
#    'tokens': {'owners': 8, 'voters': 2}}}]

# %%
df['proposals_count'] = df['governances'].apply(lambda x: sum([g['stats']['proposals']['total'] for g in x]))
df['votes_count'] = df['governances'].apply(lambda x: sum([g['stats']['tokens']['voters'] for g in x]))
df
# Out:
#                                                     id               slug  \
# 0    eip155:10:0x8087dE46076212A21EA5cD8b4368BCbd82...  sector-3-optimism
# 1    eip155:137:0x3343aEb44A2a277e3Ae346014e181aE15...           coindaox
# 2    eip155:1:0x064515Cc2dcf070b6302d2B9ffc9643c449...                tai
# 3    eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...  spore-engineering
# 4    eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...               diva
# ..                                                 ...                ...
# 574  eip155:1:0x0BEF27FEB58e857046d630B2c03dFb7bae5...                fei
# 575  eip155:137:0x9B3a9e3f289095A7E1117deb3bD29Fd7C...             under3
# 576  eip155:137:0x89de859404FeAC5346f5a843Db6B5E136...    harry-potter-82
# 577  eip155:137:0x806713eAAAAFEBfb4F0f6d6ED54775f76...   allturn-space-83
# 578  eip155:137:0x010C5507C43a161240d4C0FA40043244c...   immunity-dao-181
#
#                     name        kind     chainId                 name  \
# 0    Sector#3 (Optimism)  SINGLE_GOV   eip155:10  Sector#3 (Optimism)
# 1               CoinDaoX  SINGLE_GOV  eip155:137             CoinDaoX
# 2         TAI Governance  SINGLE_GOV    eip155:1       TAI Governance
# 3      Spore Engineering  SINGLE_GOV  eip155:100    Spore Engineering
# 4           Diva Staking  SINGLE_GOV    eip155:1         Diva Staking
# ..                   ...         ...         ...                  ...
# 574                  Fei  SINGLE_GOV    eip155:1                  Fei
# 575               Under3  SINGLE_GOV  eip155:137               Under3
# 576         Harry Potter  SINGLE_GOV  eip155:137         Harry Potter
# 577        AllTurn.Space  SINGLE_GOV  eip155:137        AllTurn.Space
# 578         Immunity DAO  SINGLE_GOV  eip155:137         Immunity DAO
#
#                   slug                                             visual  \
# 0    sector-3-optimism  {'icon': 'https://static.tally.xyz/268e141b-ec...
# 1             coindaox  {'icon': 'https://static.tally.xyz/24c28289-66...
# 2     tai-governance-1  {'icon': 'https://static.tally.xyz/5b7ab399-b2...
# 3               dsfsdf  {'icon': 'https://static.tally.xyz/fbe60111-1b...
# 4         diva-staking  {'icon': 'https://static.tally.xyz/3c15ec19-51...
# ..                 ...                                                ...
# 574                fei  {'icon': 'https://static.withtally.com/c180925...
# 575             under3  {'icon': 'https://static.withtally.com/a5054e9...
# 576    harry-potter-82  {'icon': 'https://static.withtally.com/131bcd2...
# 577      allturn.space  {'icon': 'https://static.withtally.com/5dcfedc...
# 578   immunity-dao-181  {'icon': 'https://static.withtally.com/d51a658...
#
#                                            governances  proposals_count  \
# 0    [{'stats': {'proposals': {'active': 0, 'total'...                0
# 1    [{'stats': {'proposals': {'active': 0, 'total'...                1
# 2    [{'stats': {'proposals': {'active': 0, 'total'...                0
# 3    [{'stats': {'proposals': {'active': 0, 'total'...                0
# 4    [{'stats': {'proposals': {'active': 0, 'total'...                0
# ..                                                 ...              ...
# 574  [{'stats': {'proposals': {'active': 0, 'total'...               64
# 575  [{'stats': {'proposals': {'active': 0, 'total'...                7
# 576  [{'stats': {'proposals': {'active': 0, 'total'...                6
# 577  [{'stats': {'proposals': {'active': 0, 'total'...                3
# 578  [{'stats': {'proposals': {'active': 0, 'total'...                1
#
#      votes_count
# 0              2
# 1              1
# 2              0
# 3              0
# 4           2055
# ..           ...
# 574          336
# 575            2
# 576            1
# 577            1
# 578            1
#
# [579 rows x 11 columns]

# %%
df = df[['id', 'slug', 'name', 'votes_count', 'proposals_count']]
# drop one of the slug columns
df.head()
# Out:
#                                                   id               slug  \
# 0  eip155:10:0x8087dE46076212A21EA5cD8b4368BCbd82...  sector-3-optimism
# 1  eip155:137:0x3343aEb44A2a277e3Ae346014e181aE15...           coindaox
# 2  eip155:1:0x064515Cc2dcf070b6302d2B9ffc9643c449...                tai
# 3  eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...  spore-engineering
# 4  eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...               diva
#
#                 slug                 name                 name  votes_count  \
# 0  sector-3-optimism  Sector#3 (Optimism)  Sector#3 (Optimism)            2
# 1           coindaox             CoinDaoX             CoinDaoX            1
# 2   tai-governance-1       TAI Governance       TAI Governance            0
# 3             dsfsdf    Spore Engineering    Spore Engineering            0
# 4       diva-staking         Diva Staking         Diva Staking         2055
#
#    proposals_count
# 0                0
# 1                1
# 2                0
# 3                0
# 4                0

# %%
# add platform column
df['platform'] = 'tally'
df = df.rename(columns={'id': 'platform_id'})
df
# Out:
# /var/folders/yn/b6240_995k3gl4vwtnbzzy480000gq/T/ipykernel_13324/301900197.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['platform'] = 'tally'
#                                            platform_id               slug  \
# 0    eip155:10:0x8087dE46076212A21EA5cD8b4368BCbd82...  sector-3-optimism
# 1    eip155:137:0x3343aEb44A2a277e3Ae346014e181aE15...           coindaox
# 2    eip155:1:0x064515Cc2dcf070b6302d2B9ffc9643c449...                tai
# 3    eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...  spore-engineering
# 4    eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...               diva
# ..                                                 ...                ...
# 574  eip155:1:0x0BEF27FEB58e857046d630B2c03dFb7bae5...                fei
# 575  eip155:137:0x9B3a9e3f289095A7E1117deb3bD29Fd7C...             under3
# 576  eip155:137:0x89de859404FeAC5346f5a843Db6B5E136...    harry-potter-82
# 577  eip155:137:0x806713eAAAAFEBfb4F0f6d6ED54775f76...   allturn-space-83
# 578  eip155:137:0x010C5507C43a161240d4C0FA40043244c...   immunity-dao-181
#
#                   slug                 name                 name  votes_count  \
# 0    sector-3-optimism  Sector#3 (Optimism)  Sector#3 (Optimism)            2
# 1             coindaox             CoinDaoX             CoinDaoX            1
# 2     tai-governance-1       TAI Governance       TAI Governance            0
# 3               dsfsdf    Spore Engineering    Spore Engineering            0
# 4         diva-staking         Diva Staking         Diva Staking         2055
# ..                 ...                  ...                  ...          ...
# 574                fei                  Fei                  Fei          336
# 575             under3               Under3               Under3            2
# 576    harry-potter-82         Harry Potter         Harry Potter            1
# 577      allturn.space        AllTurn.Space        AllTurn.Space            1
# 578   immunity-dao-181         Immunity DAO         Immunity DAO            1
#
#      proposals_count platform
# 0                  0    tally
# 1                  1    tally
# 2                  0    tally
# 3                  0    tally
# 4                  0    tally
# ..               ...      ...
# 574               64    tally
# 575                7    tally
# 576                6    tally
# 577                3    tally
# 578                1    tally
#
# [579 rows x 8 columns]

# %%
# make website column from https://www.tally.xyz/gov/<platform_id>
df['website'] = 'https://www.tally.xyz/gov/' + df['platform_id']
df
# Out:
#                                            platform_id               slug  \
# 0    eip155:10:0x8087dE46076212A21EA5cD8b4368BCbd82...  sector-3-optimism
# 1    eip155:137:0x3343aEb44A2a277e3Ae346014e181aE15...           coindaox
# 2    eip155:1:0x064515Cc2dcf070b6302d2B9ffc9643c449...                tai
# 3    eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...  spore-engineering
# 4    eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...               diva
# ..                                                 ...                ...
# 574  eip155:1:0x0BEF27FEB58e857046d630B2c03dFb7bae5...                fei
# 575  eip155:137:0x9B3a9e3f289095A7E1117deb3bD29Fd7C...             under3
# 576  eip155:137:0x89de859404FeAC5346f5a843Db6B5E136...    harry-potter-82
# 577  eip155:137:0x806713eAAAAFEBfb4F0f6d6ED54775f76...   allturn-space-83
# 578  eip155:137:0x010C5507C43a161240d4C0FA40043244c...   immunity-dao-181
#
#                   slug                 name                 name  votes_count  \
# 0    sector-3-optimism  Sector#3 (Optimism)  Sector#3 (Optimism)            2
# 1             coindaox             CoinDaoX             CoinDaoX            1
# 2     tai-governance-1       TAI Governance       TAI Governance            0
# 3               dsfsdf    Spore Engineering    Spore Engineering            0
# 4         diva-staking         Diva Staking         Diva Staking         2055
# ..                 ...                  ...                  ...          ...
# 574                fei                  Fei                  Fei          336
# 575             under3               Under3               Under3            2
# 576    harry-potter-82         Harry Potter         Harry Potter            1
# 577      allturn.space        AllTurn.Space        AllTurn.Space            1
# 578   immunity-dao-181         Immunity DAO         Immunity DAO            1
#
#      proposals_count platform  \
# 0                  0    tally
# 1                  1    tally
# 2                  0    tally
# 3                  0    tally
# 4                  0    tally
# ..               ...      ...
# 574               64    tally
# 575                7    tally
# 576                6    tally
# 577                3    tally
# 578                1    tally
#
#                                                website
# 0    https://www.tally.xyz/gov/eip155:10:0x8087dE46...
# 1    https://www.tally.xyz/gov/eip155:137:0x3343aEb...
# 2    https://www.tally.xyz/gov/eip155:1:0x064515Cc2...
# 3    https://www.tally.xyz/gov/eip155:100:0x9685308...
# 4    https://www.tally.xyz/gov/eip155:1:0xFb6B7C11a...
# ..                                                 ...
# 574  https://www.tally.xyz/gov/eip155:1:0x0BEF27FEB...
# 575  https://www.tally.xyz/gov/eip155:137:0x9B3a9e3...
# 576  https://www.tally.xyz/gov/eip155:137:0x89de859...
# 577  https://www.tally.xyz/gov/eip155:137:0x806713e...
# 578  https://www.tally.xyz/gov/eip155:137:0x010C550...
#
# [579 rows x 9 columns]

# %%
# add an empty additional column
df['additional'] = None
df = df[['platform', 'platform_id', 'name', 'additional', 'website', 'votes_count', 'proposals_count']]

# %%
df.head()
# Out:
#   platform                                        platform_id  \
# 0    tally  eip155:10:0x8087dE46076212A21EA5cD8b4368BCbd82...
# 1    tally  eip155:137:0x3343aEb44A2a277e3Ae346014e181aE15...
# 2    tally  eip155:1:0x064515Cc2dcf070b6302d2B9ffc9643c449...
# 3    tally  eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...
# 4    tally  eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...
#
#                   name                 name additional  \
# 0  Sector#3 (Optimism)  Sector#3 (Optimism)       None
# 1             CoinDaoX             CoinDaoX       None
# 2       TAI Governance       TAI Governance       None
# 3    Spore Engineering    Spore Engineering       None
# 4         Diva Staking         Diva Staking       None
#
#                                              website  votes_count  \
# 0  https://www.tally.xyz/gov/eip155:10:0x8087dE46...            2
# 1  https://www.tally.xyz/gov/eip155:137:0x3343aEb...            1
# 2  https://www.tally.xyz/gov/eip155:1:0x064515Cc2...            0
# 3  https://www.tally.xyz/gov/eip155:100:0x9685308...            0
# 4  https://www.tally.xyz/gov/eip155:1:0xFb6B7C11a...         2055
#
#    proposals_count
# 0                0
# 1                1
# 2                0
# 3                0
# 4                0

# %%
# fix dupe name col
df.columns = ['platform', 'platform_id', 'name', 'name_duplicate', 'additional', 'website', 'votes_count', 'proposals_count']
df.head()
# Out:
#   platform                                        platform_id  \
# 0    tally  eip155:10:0x8087dE46076212A21EA5cD8b4368BCbd82...
# 1    tally  eip155:137:0x3343aEb44A2a277e3Ae346014e181aE15...
# 2    tally  eip155:1:0x064515Cc2dcf070b6302d2B9ffc9643c449...
# 3    tally  eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...
# 4    tally  eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...
#
#                   name       name_duplicate additional  \
# 0  Sector#3 (Optimism)  Sector#3 (Optimism)       None
# 1             CoinDaoX             CoinDaoX       None
# 2       TAI Governance       TAI Governance       None
# 3    Spore Engineering    Spore Engineering       None
# 4         Diva Staking         Diva Staking       None
#
#                                              website  votes_count  \
# 0  https://www.tally.xyz/gov/eip155:10:0x8087dE46...            2
# 1  https://www.tally.xyz/gov/eip155:137:0x3343aEb...            1
# 2  https://www.tally.xyz/gov/eip155:1:0x064515Cc2...            0
# 3  https://www.tally.xyz/gov/eip155:100:0x9685308...            0
# 4  https://www.tally.xyz/gov/eip155:1:0xFb6B7C11a...         2055
#
#    proposals_count
# 0                0
# 1                1
# 2                0
# 3                0
# 4                0

# %%
# drop dupe name col
df = df.drop(['name_duplicate'], axis=1)

# %%
# save
df.to_csv('tally_deployments.csv', index=False)

# %%
import json
import pandas as pd
import os
import time
import datetime as dt
import requests_cache

# %%
BATCH_SIZE = 1000 # Max first: size
backoff_seconds = 60 / 100 # 100 requests per minute
MAX_DATE: str = "2024-01-01T00:00:00Z"

# %%
MAX_TIMESTAMP: int = int(dt.datetime.fromisoformat(MAX_DATE).timestamp())
print(MAX_TIMESTAMP)
# Out:
# 1704067200

# %%
def generate_query(created_gte):
  return f"""
    query Proposals {{
      proposals(first: {BATCH_SIZE}, orderBy: "created", orderDirection: asc, where: {{ created_gte: {created_gte}, created_lt: {MAX_TIMESTAMP}, state: "closed" }}) {{
        id
        space {{
        id
        }}
        author
        created
        votes
        title
        body
        start
        end
      }}
    }}
  """

print(generate_query(0))
# Out:
#     query Proposals {
#       proposals(first: 1000, orderBy: "created", orderDirection: asc, where: { created_gte: 0, created_lt: 1704067200, state: "closed" }) {
#         id
#         space {
#         id
#         }
#         author
#         created
#         votes
#         title
#         body
#         start
#         end
#       }
#     }

# %%
session = requests_cache.CachedSession(
  '.cache',
  allowable_methods=['GET', 'POST'],
)

def get_all_proposals():
  URL = "https://hub.snapshot.org/graphql"
  all_proposals = []

  last_index = 0
  while last_index is not None:
      query = generate_query(last_index)
      r = session.post(URL, json={'query': query})
      if not r.from_cache:
        time.sleep(backoff_seconds)

      data = json.loads(r.text)

      print(f"last_index {dt.datetime.fromtimestamp(last_index)}, {'HIT' if r.from_cache else 'MISS'}")
      
      if 'errors' in data:
        print(data['errors'])
        if 'The `skip` argument must not be greater than 30000' in data['errors'][0]['message']:
            break
      
      proposals = data['data']['proposals']

      if len(proposals) < BATCH_SIZE:
          last_index = None
      else:
          last_index = proposals[-1]['created']

      if not proposals:
        print('No proposals found')
      else:
        all_proposals.extend(proposals)

  return pd.json_normalize(all_proposals)

df = get_all_proposals()
len(df)
# Out:
# last_index 1970-01-01 01:00:00, HIT
# last_index 2020-10-30 11:24:09, HIT
# last_index 2020-12-30 06:56:59, HIT
# last_index 2021-02-18 07:48:38, HIT
# last_index 2021-03-22 11:15:02, HIT
# last_index 2021-04-18 21:50:18, HIT
# last_index 2021-05-13 19:33:50, HIT
# last_index 2021-06-05 09:11:57, HIT
# last_index 2021-06-25 13:49:27, HIT
# last_index 2021-07-19 10:01:24, HIT
# last_index 2021-08-09 21:44:27, HIT
# last_index 2021-09-01 10:37:19, HIT
# last_index 2021-09-22 06:09:01, HIT
# last_index 2021-10-09 09:55:29, HIT
# last_index 2021-10-23 10:42:47, HIT
# last_index 2021-11-03 15:07:39, HIT
# last_index 2021-11-10 08:49:12, HIT
# last_index 2021-11-14 20:56:51, HIT
# last_index 2021-11-19 09:48:10, HIT
# last_index 2021-11-20 13:19:49, HIT
# last_index 2021-11-21 11:01:10, HIT
# last_index 2021-11-23 03:17:50, HIT
# last_index 2021-11-25 06:46:24, HIT
# last_index 2021-11-29 04:35:29, HIT
# last_index 2021-12-02 09:25:42, HIT
# last_index 2021-12-06 10:44:05, HIT
# last_index 2021-12-09 10:08:17, HIT
# last_index 2021-12-13 03:52:46, HIT
# last_index 2021-12-15 19:29:48, HIT
# last_index 2021-12-19 16:17:37, HIT
# last_index 2021-12-22 15:25:30, HIT
# last_index 2021-12-27 05:49:42, HIT
# last_index 2021-12-31 14:28:23, HIT
# last_index 2022-01-05 21:16:12, HIT
# last_index 2022-01-12 04:13:35, HIT
# last_index 2022-01-18 21:38:32, HIT
# last_index 2022-01-25 11:26:01, HIT
# last_index 2022-02-02 14:23:13, HIT
# last_index 2022-02-09 18:39:28, HIT
# last_index 2022-02-17 19:31:50, HIT
# last_index 2022-02-27 16:09:11, HIT
# last_index 2022-03-06 13:30:19, HIT
# last_index 2022-03-14 10:54:07, HIT
# last_index 2022-03-21 23:40:42, HIT
# last_index 2022-03-29 22:14:00, HIT
# last_index 2022-04-06 13:43:03, HIT
# last_index 2022-04-13 17:25:16, HIT
# last_index 2022-04-21 03:32:39, HIT
# last_index 2022-04-27 14:38:43, HIT
# last_index 2022-05-02 11:10:03, HIT
# last_index 2022-05-07 17:13:26, HIT
# last_index 2022-05-12 07:29:56, HIT
# last_index 2022-05-17 15:25:04, HIT
# last_index 2022-05-22 19:12:31, HIT
# last_index 2022-05-28 21:05:53, HIT
# last_index 2022-06-05 16:43:53, HIT
# last_index 2022-06-13 03:07:07, HIT
# last_index 2022-06-21 16:06:51, HIT
# last_index 2022-07-01 04:41:51, HIT
# last_index 2022-07-09 10:51:32, HIT
# last_index 2022-07-20 11:25:54, HIT
# last_index 2022-07-29 11:26:19, HIT
# last_index 2022-08-07 09:37:11, HIT
# last_index 2022-08-16 19:11:06, HIT
# last_index 2022-08-25 06:06:59, HIT
# last_index 2022-09-03 04:41:17, HIT
# last_index 2022-09-11 18:29:53, HIT
# last_index 2022-09-19 12:39:07, HIT
# last_index 2022-09-28 14:06:52, HIT
# last_index 2022-10-08 17:15:06, HIT
# last_index 2022-10-17 23:20:47, HIT
# last_index 2022-10-25 11:12:25, HIT
# last_index 2022-11-02 16:14:37, HIT
# last_index 2022-11-12 19:29:08, HIT
# last_index 2022-11-23 19:28:06, HIT
# last_index 2022-12-01 19:29:37, HIT
# last_index 2022-12-10 13:59:14, HIT
# last_index 2022-12-19 18:41:30, HIT
# last_index 2022-12-31 16:14:49, HIT
# last_index 2023-01-11 07:48:16, HIT
# last_index 2023-01-14 10:08:33, HIT
# last_index 2023-01-22 06:45:08, HIT
# last_index 2023-01-31 04:09:13, HIT
# last_index 2023-02-07 21:58:32, HIT
# last_index 2023-02-16 10:45:52, HIT
# last_index 2023-02-23 08:25:24, HIT
# last_index 2023-03-05 04:33:51, HIT
# last_index 2023-03-14 23:44:05, HIT
# last_index 2023-03-23 19:19:56, HIT
# last_index 2023-03-30 19:16:16, HIT
# last_index 2023-04-06 04:14:15, HIT
# last_index 2023-04-11 19:41:24, HIT
# last_index 2023-04-16 10:20:49, HIT
# last_index 2023-04-19 11:30:59, HIT
# last_index 2023-04-23 06:19:09, HIT
# last_index 2023-04-26 05:33:36, HIT
# last_index 2023-04-30 13:39:44, HIT
# last_index 2023-05-04 04:52:36, HIT
# last_index 2023-05-10 13:01:05, HIT
# last_index 2023-05-11 06:59:06, HIT
# last_index 2023-05-14 18:35:38, HIT
# last_index 2023-05-17 10:41:54, HIT
# last_index 2023-05-20 16:09:17, HIT
# last_index 2023-05-23 08:47:58, HIT
# last_index 2023-05-26 01:26:35, HIT
# last_index 2023-05-29 04:36:13, HIT
# last_index 2023-06-03 17:03:14, HIT
# last_index 2023-06-09 20:03:03, HIT
# last_index 2023-06-13 15:43:58, HIT
# last_index 2023-06-14 21:34:03, HIT
# last_index 2023-06-16 00:40:10, HIT
# last_index 2023-06-17 07:48:50, HIT
# last_index 2023-06-18 11:25:09, HIT
# last_index 2023-06-19 15:33:39, HIT
# last_index 2023-06-20 12:01:30, HIT
# last_index 2023-06-21 09:04:49, HIT
# last_index 2023-06-22 05:15:18, HIT
# last_index 2023-06-23 06:42:20, HIT
# last_index 2023-06-24 03:21:16, HIT
# last_index 2023-06-24 17:54:20, HIT
# last_index 2023-06-25 13:27:38, HIT
# last_index 2023-06-26 06:32:10, HIT
# last_index 2023-06-26 14:18:54, HIT
# last_index 2023-06-27 06:31:42, HIT
# last_index 2023-06-27 16:53:40, HIT
# last_index 2023-06-28 07:58:18, HIT
# last_index 2023-06-28 17:05:03, HIT
# last_index 2023-06-29 09:07:02, HIT
# last_index 2023-06-29 18:42:47, HIT
# last_index 2023-06-30 10:27:51, HIT
# last_index 2023-06-30 23:32:14, HIT
# last_index 2023-07-01 09:04:16, HIT
# last_index 2023-07-01 14:01:45, HIT
# last_index 2023-07-02 06:48:03, HIT
# last_index 2023-07-02 11:23:50, HIT
# last_index 2023-07-02 17:20:53, HIT
# last_index 2023-07-03 09:02:13, HIT
# last_index 2023-07-03 16:39:18, HIT
# last_index 2023-07-04 08:00:00, HIT
# last_index 2023-07-04 20:07:36, HIT
# last_index 2023-07-05 06:55:18, HIT
# last_index 2023-07-05 23:34:28, HIT
# last_index 2023-07-07 03:35:35, HIT
# last_index 2023-07-08 08:59:45, HIT
# last_index 2023-07-09 03:38:29, HIT
# last_index 2023-07-10 18:46:03, HIT
# last_index 2023-07-12 21:16:03, HIT
# last_index 2023-07-15 03:27:27, HIT
# last_index 2023-07-15 11:44:16, HIT
# last_index 2023-07-16 13:00:06, HIT
# last_index 2023-07-17 18:41:35, HIT
# last_index 2023-07-18 12:00:12, HIT
# last_index 2023-07-19 02:08:28, HIT
# last_index 2023-07-19 17:56:11, HIT
# last_index 2023-07-20 20:26:19, HIT
# last_index 2023-07-22 11:12:04, HIT
# last_index 2023-07-23 16:01:29, HIT
# last_index 2023-07-24 19:44:19, HIT
# last_index 2023-07-26 08:41:31, HIT
# last_index 2023-07-27 00:50:42, HIT
# last_index 2023-07-28 04:25:11, HIT
# last_index 2023-07-29 03:02:38, HIT
# last_index 2023-07-29 16:42:12, HIT
# last_index 2023-07-30 07:09:03, HIT
# last_index 2023-07-30 16:55:40, HIT
# last_index 2023-07-31 08:34:47, HIT
# last_index 2023-07-31 17:37:28, HIT
# last_index 2023-08-01 09:41:06, HIT
# last_index 2023-08-01 17:22:20, HIT
# last_index 2023-08-02 04:43:44, HIT
# last_index 2023-08-02 12:01:31, HIT
# last_index 2023-08-02 18:27:29, HIT
# last_index 2023-08-03 09:12:31, HIT
# last_index 2023-08-03 17:12:30, HIT
# last_index 2023-08-04 08:39:50, HIT
# last_index 2023-08-04 17:32:42, HIT
# last_index 2023-08-05 11:14:29, HIT
# last_index 2023-08-05 21:50:17, HIT
# last_index 2023-08-06 13:34:19, HIT
# last_index 2023-08-07 09:39:46, HIT
# last_index 2023-08-07 19:21:15, HIT
# last_index 2023-08-08 10:41:21, HIT
# last_index 2023-08-08 21:21:04, HIT
# last_index 2023-08-09 13:05:44, HIT
# last_index 2023-08-10 02:42:39, HIT
# last_index 2023-08-10 14:21:12, HIT
# last_index 2023-08-11 04:46:12, HIT
# last_index 2023-08-11 13:05:37, HIT
# last_index 2023-08-12 01:11:06, HIT
# last_index 2023-08-12 11:47:22, HIT
# last_index 2023-08-12 22:13:21, HIT
# last_index 2023-08-13 13:08:56, HIT
# last_index 2023-08-15 05:44:06, HIT
# last_index 2023-08-17 03:14:07, HIT
# last_index 2023-08-19 08:16:45, HIT
# last_index 2023-08-21 15:20:42, HIT
# last_index 2023-08-24 02:07:38, HIT
# last_index 2023-08-27 01:56:57, HIT
# last_index 2023-08-29 11:35:50, HIT
# last_index 2023-09-02 18:40:54, HIT
# last_index 2023-09-08 08:56:38, HIT
# last_index 2023-09-13 06:47:26, HIT
# last_index 2023-09-18 18:11:53, HIT
# last_index 2023-09-23 17:05:06, HIT
# last_index 2023-09-28 10:54:44, HIT
# last_index 2023-10-01 06:39:37, HIT
# last_index 2023-10-03 14:30:41, HIT
# last_index 2023-10-06 11:16:03, HIT
# last_index 2023-10-09 08:20:02, HIT
# last_index 2023-10-12 11:54:51, HIT
# last_index 2023-10-15 05:15:48, HIT
# last_index 2023-10-17 03:53:24, HIT
# last_index 2023-10-18 19:59:26, HIT
# last_index 2023-10-20 22:17:26, HIT
# last_index 2023-10-23 23:05:58, HIT
# last_index 2023-10-26 15:57:42, HIT
# last_index 2023-10-30 16:06:33, HIT
# last_index 2023-11-02 21:14:56, HIT
# last_index 2023-11-06 17:37:46, HIT
# last_index 2023-11-09 10:16:36, HIT
# last_index 2023-11-12 10:49:24, HIT
# last_index 2023-11-15 10:35:09, HIT
# last_index 2023-11-20 10:35:52, HIT
# last_index 2023-11-24 07:27:51, HIT
# last_index 2023-11-26 17:37:22, HIT
# last_index 2023-11-28 19:04:41, HIT
# last_index 2023-12-01 11:56:21, HIT
# last_index 2023-12-04 21:40:15, HIT
# last_index 2023-12-08 11:27:33, HIT
# last_index 2023-12-13 14:43:01, HIT
# last_index 2023-12-20 12:05:38, HIT
# last_index 2023-12-24 15:53:51, HIT
# last_index 2023-12-27 13:18:09, HIT
# last_index 2023-12-30 15:45:39, HIT
# 233269

# %%
df = df.drop_duplicates(["id"])

# %%
# * platform
df['platform'] = 'snapshot'
# * rename space.id to platform_deployment_id
df.rename(columns={'space.id': 'platform_deployment_id'}, inplace=True)
# * rename id to proposal_id
df.rename(columns={'id': 'proposal_id'}, inplace=True)
# * author no chg
# * rename created to date
df.rename(columns={'created': 'date'}, inplace=True)
# * votes to votes_count
df.rename(columns={'votes': 'votes_count'}, inplace=True)
# * body to description
df.rename(columns={'body': 'description'}, inplace=True)

# keep only these cols
df = df[['platform', 'platform_deployment_id', 'proposal_id', 'author', 'date', 'votes_count', 'title', 'description', 'start', 'end']]
df.head()
# Out:
#    platform platform_deployment_id  \
# 0  snapshot           balancer.eth
# 1  snapshot           balancer.eth
# 2  snapshot           balancer.eth
# 3  snapshot           balancer.eth
# 4  snapshot           balancer.eth
#
#                                       proposal_id  \
# 0  QmSXpyHBrkjzjmGpdYxKvYoRAMvdJNp7rrnyvJqTdtpayZ
# 1  QmXYVj4GBu16GfuTLouxQSvbB8w3G2EAvYq9TAxX38ruKb
# 2  QmboDWvsXYXPZb44arPVoMa3LHuv74YsGZ3cSoG6uj4oZe
# 3  QmeWmvdFCTq5tnFHqgFmAVJDCccTYjg1zWb9cfUByg7zbz
# 4  QmUadcUgd3jAhJbofgrnKNMfeuGFvMmybhCkttW4gGfYYJ
#
#                                        author        date  votes_count  \
# 0  0x8BBE4Ac64246d600BC2889ef5d83809D138F03DF  1595088499           97
# 1  0x8BBE4Ac64246d600BC2889ef5d83809D138F03DF  1595088523           72
# 2  0x8BBE4Ac64246d600BC2889ef5d83809D138F03DF  1595088879           83
# 3  0x8BBE4Ac64246d600BC2889ef5d83809D138F03DF  1595837264           31
# 4  0x107174D70b33523E83711EA4C3F4229cdB8A7Cb1  1596226825          107
#
#                                                title  \
# 0  balFactor: incentivizing BAL liquidity on Bala...
# 1  Modifying feeFactor: toward reducing the minin...
# 2  Modifying wrapFactor: applying a 0.7 factor to...
# 3  First batch of grants from Balancer Ecosystem ...
# 4  Modifying wrapFactor: applying a 0.2 factor to...
#
#                                          description       start         end
# 0  Read the formatted version of this proposal at...  1595088000  1595174400
# 1  Read the formatted version of this proposal at...  1595088000  1595174400
# 2  Read the formatted version of this proposal at...  1595088000  1595174400
# 3  [This proposal is also on Balancer's forum.](h...  1595865600  1595952000
# 4  [This proposal has been posted by user 5325235...  1596297600  1596384000

# %%
# read date as pd date, it's a seconds epoch timestamp
df['date'] = pd.to_datetime(df['date'], unit='s')
df['start'] = pd.to_datetime(df['start'], unit='s')
df['end'] = pd.to_datetime(df['end'], unit='s')
df.head()
# Out:
#    platform platform_deployment_id  \
# 0  snapshot           balancer.eth
# 1  snapshot           balancer.eth
# 2  snapshot           balancer.eth
# 3  snapshot           balancer.eth
# 4  snapshot           balancer.eth
#
#                                       proposal_id  \
# 0  QmSXpyHBrkjzjmGpdYxKvYoRAMvdJNp7rrnyvJqTdtpayZ
# 1  QmXYVj4GBu16GfuTLouxQSvbB8w3G2EAvYq9TAxX38ruKb
# 2  QmboDWvsXYXPZb44arPVoMa3LHuv74YsGZ3cSoG6uj4oZe
# 3  QmeWmvdFCTq5tnFHqgFmAVJDCccTYjg1zWb9cfUByg7zbz
# 4  QmUadcUgd3jAhJbofgrnKNMfeuGFvMmybhCkttW4gGfYYJ
#
#                                        author                date  \
# 0  0x8BBE4Ac64246d600BC2889ef5d83809D138F03DF 2020-07-18 16:08:19
# 1  0x8BBE4Ac64246d600BC2889ef5d83809D138F03DF 2020-07-18 16:08:43
# 2  0x8BBE4Ac64246d600BC2889ef5d83809D138F03DF 2020-07-18 16:14:39
# 3  0x8BBE4Ac64246d600BC2889ef5d83809D138F03DF 2020-07-27 08:07:44
# 4  0x107174D70b33523E83711EA4C3F4229cdB8A7Cb1 2020-07-31 20:20:25
#
#    votes_count                                              title  \
# 0           97  balFactor: incentivizing BAL liquidity on Bala...
# 1           72  Modifying feeFactor: toward reducing the minin...
# 2           83  Modifying wrapFactor: applying a 0.7 factor to...
# 3           31  First batch of grants from Balancer Ecosystem ...
# 4          107  Modifying wrapFactor: applying a 0.2 factor to...
#
#                                          description               start  \
# 0  Read the formatted version of this proposal at... 2020-07-18 16:00:00
# 1  Read the formatted version of this proposal at... 2020-07-18 16:00:00
# 2  Read the formatted version of this proposal at... 2020-07-18 16:00:00
# 3  [This proposal is also on Balancer's forum.](h... 2020-07-27 16:00:00
# 4  [This proposal has been posted by user 5325235... 2020-08-01 16:00:00
#
#                   end
# 0 2020-07-19 16:00:00
# 1 2020-07-19 16:00:00
# 2 2020-07-19 16:00:00
# 3 2020-07-28 16:00:00
# 4 2020-08-02 16:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 232976 entries, 0 to 233268
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   platform                232976 non-null  object
#  1   platform_deployment_id  232976 non-null  object
#  2   proposal_id             232976 non-null  object
#  3   author                  232976 non-null  object
#  4   date                    232976 non-null  datetime64[ns]
#  5   votes_count             232976 non-null  int64
#  6   title                   232976 non-null  object
#  7   description             232976 non-null  object
#  8   start                   232976 non-null  datetime64[ns]
#  9   end                     232976 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(1), object(6)
# memory usage: 19.6+ MB

# %%
df[df['votes_count'].isna()]
# Out:
# Empty DataFrame
# Columns: [platform, platform_deployment_id, proposal_id, author, date, votes_count, title, description, start, end]
# Index: []

# %%
# save
# df.to_csv('snapshot_proposals.csv', index=False)
df.to_parquet('snapshot_proposals.parquet', index=False)

# %%
aux = pd.read_parquet('snapshot_proposals.parquet')
aux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232976 entries, 0 to 232975
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   platform                232976 non-null  object
#  1   platform_deployment_id  232976 non-null  object
#  2   proposal_id             232976 non-null  object
#  3   author                  232976 non-null  object
#  4   date                    232976 non-null  datetime64[ns]
#  5   votes_count             232976 non-null  int64
#  6   title                   232976 non-null  object
#  7   description             232976 non-null  object
#  8   start                   232976 non-null  datetime64[ns]
#  9   end                     232976 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(1), object(6)
# memory usage: 17.8+ MB

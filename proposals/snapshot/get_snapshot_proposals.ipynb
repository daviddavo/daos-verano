# %%
import pandas as pd
proposals_df = pd.read_csv('./03_snapshot_proposals/1687557600_snapshot_proposals.csv')
proposals_df.head()
# Out:
#   snapshotSpaceId                                 snapshotProposalId  \
# 0      01meta.eth  0x9e04371f12c80f8d483b78132702703a294f6a209ce1...
# 1      01meta.eth  0x8678f41a17815fb641f8fb3f1618587c8509359f27a5...
# 2      01meta.eth  0x6f7e95dbb0036c37a817aabec735fceb5d6e4646042f...
# 3      01meta.eth  0x5484a06b64bd7aaa5d9a96c64476543c55781b23a112...
# 4      01meta.eth  0xb90f3fd67b646b0c91c3cbaf17571fea30e20ed8ae12...
#
#                                                 ipfs  \
# 0  bafkreiecdi6nwwtvxdnkkji7lov6zpdc3ewz3sut4ncz3...
# 1  bafkreiagwfqogvhadg2yf5fdvmkp5dhrdbjxsbzoont6a...
# 2  bafkreif7xacvqenpy2monngk5hhzytfgcr6oenn6lfszc...
# 3  bafkreiec3ebsfygli2mknyyg6au64p4haodxpkkz4oy72...
# 4     QmVDrSy36MQYUU6iQohS6jD8k3L7tgxCTx5Y7EeAybBrtH
#
#                                        author              created  network  \
# 0  0x707982CaDBBbC6F3f46EfA681737fDC371F934D7  2023-02-03 07:45:41    137.0
# ...

# %%
# * platform
# add platform column = snapshot
proposals_df['platform'] = 'snapshot'
# * platform_deployment_id
# rename snapshotSpaceId to platform_deployment_id
proposals_df.rename(columns={'snapshotSpaceId': 'platform_deployment_id'}, inplace=True)
# * proposal_id
# rename snapshotProposalId to proposal_id
proposals_df.rename(columns={'snapshotProposalId': 'proposal_id'}, inplace=True)
# * author
# leave as-is
# * date
# rename created to date
proposals_df.rename(columns={'created': 'date'}, inplace=True)
# * votes_count
# rename votes to votes_count
proposals_df.rename(columns={'votes': 'votes_count'}, inplace=True)
# keep only the columns we need
proposals_df = proposals_df[['platform', 'platform_deployment_id', 'proposal_id', 'author', 'date', 'votes_count']]
proposals_df.head()
# Out:
#    platform platform_deployment_id  \
# 0  snapshot             01meta.eth
# 1  snapshot             01meta.eth
# 2  snapshot             01meta.eth
# 3  snapshot             01meta.eth
# 4  snapshot             01meta.eth
#
#                                          proposal_id  \
# 0  0x9e04371f12c80f8d483b78132702703a294f6a209ce1...
# 1  0x8678f41a17815fb641f8fb3f1618587c8509359f27a5...
# 2  0x6f7e95dbb0036c37a817aabec735fceb5d6e4646042f...
# 3  0x5484a06b64bd7aaa5d9a96c64476543c55781b23a112...
# 4  0xb90f3fd67b646b0c91c3cbaf17571fea30e20ed8ae12...
#
#                                        author                 date  \
# 0  0x707982CaDBBbC6F3f46EfA681737fDC371F934D7  2023-02-03 07:45:41
# 1  0xd35325eDd273bb9B54369B54874Df7ED637f7DC9  2023-02-08 13:29:08
# 2  0x239F902A295e27Ae3c59Ed4DC007B94AbDE324F3  2023-02-07 15:51:35
# 3  0x239F902A295e27Ae3c59Ed4DC007B94AbDE324F3  2023-02-04 00:31:10
# 4  0x0616072d6937245C9186B63adC4e746F576b777c  2023-06-16 06:45:04
#
#    votes_count
# ...

# %%
# show col types
proposals_df.dtypes
# Out:
# platform                   object
# platform_deployment_id     object
# proposal_id                object
# author                     object
# date                       object
# votes_count               float64
# dtype: object

# %%
# make date column a datetime
proposals_df['date'] = pd.to_datetime(proposals_df['date'])
proposals_df.head()
# Out:
#    platform platform_deployment_id  \
# 0  snapshot             01meta.eth
# 1  snapshot             01meta.eth
# 2  snapshot             01meta.eth
# 3  snapshot             01meta.eth
# 4  snapshot             01meta.eth
#
#                                          proposal_id  \
# 0  0x9e04371f12c80f8d483b78132702703a294f6a209ce1...
# 1  0x8678f41a17815fb641f8fb3f1618587c8509359f27a5...
# 2  0x6f7e95dbb0036c37a817aabec735fceb5d6e4646042f...
# 3  0x5484a06b64bd7aaa5d9a96c64476543c55781b23a112...
# 4  0xb90f3fd67b646b0c91c3cbaf17571fea30e20ed8ae12...
#
#                                        author                date  votes_count
# 0  0x707982CaDBBbC6F3f46EfA681737fDC371F934D7 2023-02-03 07:45:41          6.0
# 1  0xd35325eDd273bb9B54369B54874Df7ED637f7DC9 2023-02-08 13:29:08         41.0
# 2  0x239F902A295e27Ae3c59Ed4DC007B94AbDE324F3 2023-02-07 15:51:35         22.0
# 3  0x239F902A295e27Ae3c59Ed4DC007B94AbDE324F3 2023-02-04 00:31:10          7.0
# ...

# %%
# save to csv
proposals_df.to_csv('snapshot_proposals.csv', index=False)

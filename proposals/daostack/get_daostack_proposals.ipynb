# %%
import pandas as pd

df = pd.read_csv('proposals.csv')
# drop unknown col
df = df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#    network                                                 id  \
# 0  mainnet  0x0025c38d987acba1f1d446d3690384327ebe06d15f1f...
# 1  mainnet  0x0033a337b620add50be9ba0fff1128ab866ece51cfdd...
# 2  mainnet  0x003c109411e96e5607ce609278536262e12afdaa65ab...
# 3  mainnet  0x0071c649968f7939fc9729c5dc25a8ae3f50dc86220a...
# 4  mainnet  0x007eaf0fc8d6ae35ba3f28bc7cf4b34af659db8161d4...
#
#                                      proposer     stage   createdAt  \
# 0  0xbaaea72417f4dc3e0f52a1783b0913d0f3516634  Executed  1571738878
# 1  0x052c68abe8e4bf0b78925e488b98f6fdc18a3af9  Executed  1579288039
# 2  0xb33b9fba681653fe263b31a95766d83d18c2128d  Executed  1584208352
# 3  0x86fd6dd41bad636b5b3b9228bc5642fa0df392e8  Executed  1576335174
# 4  0x7cb9032844e722bef2e16a761832c59c96550898  Executed  1572636389
#
#    preBoostedAt     boostedAt  quietEndingPeriodBeganAt    closingAt  \
# 0  1.571741e+09  1.571835e+09                       NaN  57530338900
# 1           NaN           NaN                       NaN  56819369100
# 2  1.584216e+09  1.584302e+09                       NaN  56257678600
# 3  1.576347e+09  1.576447e+09                       NaN  57077736800
# 4  1.572637e+09  1.572767e+09                       NaN  57445129400
#
#    preBoostedClosingAt  ...  confidence confidenceThreshold  \
# 0         1.571827e+09  ...   13.061167       2279947311352
# 1                  NaN  ...    0.000000                   0
# 2         1.584302e+09  ...    5.200000       1099511627776
# 3         1.576434e+09  ...    8.000000       1319413953331
# 4         1.572723e+09  ...    1.006667       1099511627776
#
#   queuedVoteRequiredPercentage queuedVotePeriodLimit  boostedVotePeriodLimit  \
# 0                           50               2592000                  345600
# 1                           50               2592000                  345600
# 2                           50               3888000                  604800
# 3                           50               1209600                  259200
# 4                           50               1728000                  259200
#
#   thresholdConst       minimumDaoBounty daoBountyConst  \
# 0  1319413953331  150000000000000000000             10
# 1  1319413953331  150000000000000000000             10
# 2  1319413953331  250000000000000000000             10
# 3  1319413953331   50000000000000000000             10
# 4  1319413953331  150000000000000000000             10
#
#                                           dao competitionId
# 0  0x294f999356ed03347c7a23bcbcf8d33fa41dc830           NaN
# 1  0x39757e7cdb7022c3829195d57b29428d79593c9d           NaN
# 2  0x519b70055af55a007110b4ff99b0ea33071c720a           NaN
# 3  0x8990e11b69403ea53ef2b32434bbd7dbf84b5234           NaN
# 4  0x440583455bcd85ab2bd429c015d3aabcae135f0a           NaN
#
# [5 rows x 33 columns]

# %%
df.iloc[2]
# Out:
# network                                                                   mainnet
# id                              0x003c109411e96e5607ce609278536262e12afdaa65ab...
# proposer                               0xb33b9fba681653fe263b31a95766d83d18c2128d
# stage                                                                    Executed
# createdAt                                                              1584208352
# preBoostedAt                                                         1584215629.0
# boostedAt                                                            1584302043.0
# quietEndingPeriodBeganAt                                                      NaN
# closingAt                                                             56257678600
# preBoostedClosingAt                                                  1584302029.0
# executedAt                                                           1584906861.0
# totalRepWhenExecuted                                    1008460514844475278975098
# totalRepWhenCreated                                     1008460514844475278975098
# executionState                                                     BoostedTimeOut
# expiresInQueueAt                                                       1588096352
# votesFor                                                 251374125552087928247807
# votesAgainst                                                                    0
# winningOutcome                                                               Pass
# stakesFor                                                  1300000000000000000000
# stakesAgainst                                               250000000000000000000
# title                                         dxwallet.eth set resolver contract
# description                     Setting ENS resolver contracts for dxDAO domai...
# url                             https://daotalk.org/t/next-steps-for-the-ens-d...
# confidence                                                                    5.2
# confidenceThreshold                                                 1099511627776
# queuedVoteRequiredPercentage                                                   50
# queuedVotePeriodLimit                                                     3888000
# boostedVotePeriodLimit                                                     604800
# thresholdConst                                                      1319413953331
# minimumDaoBounty                                            250000000000000000000
# daoBountyConst                                                                 10
# dao                                    0x519b70055af55a007110b4ff99b0ea33071c720a
# competitionId                                                                 NaN
# Name: 2, dtype: object

# %%
# * platform
df['platform'] = 'daostack'
# * platform_deployment_id
# rename dao to platform_deployment_id
df = df.rename(columns={'dao': 'platform_deployment_id'})
# * proposal_id
# id -> proposal_id
df = df.rename(columns={'id': 'proposal_id'})
# * author
# proposer -> author
df = df.rename(columns={'proposer': 'author'})
# * date -- this should be as a pandas date, not as an epoch
# createdAt -> date
df['date'] = pd.to_datetime(df['createdAt'], unit='s')
# * votes_count
# tbd
df.head()
# Out:
#    network                                        proposal_id  \
# 0  mainnet  0x0025c38d987acba1f1d446d3690384327ebe06d15f1f...
# 1  mainnet  0x0033a337b620add50be9ba0fff1128ab866ece51cfdd...
# 2  mainnet  0x003c109411e96e5607ce609278536262e12afdaa65ab...
# 3  mainnet  0x0071c649968f7939fc9729c5dc25a8ae3f50dc86220a...
# 4  mainnet  0x007eaf0fc8d6ae35ba3f28bc7cf4b34af659db8161d4...
#
#                                        author     stage   createdAt  \
# 0  0xbaaea72417f4dc3e0f52a1783b0913d0f3516634  Executed  1571738878
# 1  0x052c68abe8e4bf0b78925e488b98f6fdc18a3af9  Executed  1579288039
# 2  0xb33b9fba681653fe263b31a95766d83d18c2128d  Executed  1584208352
# 3  0x86fd6dd41bad636b5b3b9228bc5642fa0df392e8  Executed  1576335174
# 4  0x7cb9032844e722bef2e16a761832c59c96550898  Executed  1572636389
#
#    preBoostedAt     boostedAt  quietEndingPeriodBeganAt    closingAt  \
# 0  1.571741e+09  1.571835e+09                       NaN  57530338900
# 1           NaN           NaN                       NaN  56819369100
# 2  1.584216e+09  1.584302e+09                       NaN  56257678600
# 3  1.576347e+09  1.576447e+09                       NaN  57077736800
# 4  1.572637e+09  1.572767e+09                       NaN  57445129400
#
#    preBoostedClosingAt  ...  queuedVoteRequiredPercentage  \
# 0         1.571827e+09  ...                            50
# 1                  NaN  ...                            50
# 2         1.584302e+09  ...                            50
# 3         1.576434e+09  ...                            50
# 4         1.572723e+09  ...                            50
#
#   queuedVotePeriodLimit boostedVotePeriodLimit thresholdConst  \
# 0               2592000                 345600  1319413953331
# 1               2592000                 345600  1319413953331
# 2               3888000                 604800  1319413953331
# 3               1209600                 259200  1319413953331
# 4               1728000                 259200  1319413953331
#
#         minimumDaoBounty daoBountyConst  \
# 0  150000000000000000000             10
# 1  150000000000000000000             10
# 2  250000000000000000000             10
# 3   50000000000000000000             10
# 4  150000000000000000000             10
#
#                        platform_deployment_id competitionId  platform  \
# 0  0x294f999356ed03347c7a23bcbcf8d33fa41dc830           NaN  daostack
# 1  0x39757e7cdb7022c3829195d57b29428d79593c9d           NaN  daostack
# 2  0x519b70055af55a007110b4ff99b0ea33071c720a           NaN  daostack
# 3  0x8990e11b69403ea53ef2b32434bbd7dbf84b5234           NaN  daostack
# 4  0x440583455bcd85ab2bd429c015d3aabcae135f0a           NaN  daostack
#
#                  date
# 0 2019-10-22 10:07:58
# 1 2020-01-17 19:07:19
# 2 2020-03-14 17:52:32
# 3 2019-12-14 14:52:54
# 4 2019-11-01 19:26:29
#
# [5 rows x 35 columns]

# %%
df = df[['platform', 'platform_deployment_id', 'proposal_id', 'author', 'date']]
df.head()
# Out:
#    platform                      platform_deployment_id  \
# 0  daostack  0x294f999356ed03347c7a23bcbcf8d33fa41dc830
# 1  daostack  0x39757e7cdb7022c3829195d57b29428d79593c9d
# 2  daostack  0x519b70055af55a007110b4ff99b0ea33071c720a
# 3  daostack  0x8990e11b69403ea53ef2b32434bbd7dbf84b5234
# 4  daostack  0x440583455bcd85ab2bd429c015d3aabcae135f0a
#
#                                          proposal_id  \
# 0  0x0025c38d987acba1f1d446d3690384327ebe06d15f1f...
# 1  0x0033a337b620add50be9ba0fff1128ab866ece51cfdd...
# 2  0x003c109411e96e5607ce609278536262e12afdaa65ab...
# 3  0x0071c649968f7939fc9729c5dc25a8ae3f50dc86220a...
# 4  0x007eaf0fc8d6ae35ba3f28bc7cf4b34af659db8161d4...
#
#                                        author                date
# 0  0xbaaea72417f4dc3e0f52a1783b0913d0f3516634 2019-10-22 10:07:58
# 1  0x052c68abe8e4bf0b78925e488b98f6fdc18a3af9 2020-01-17 19:07:19
# 2  0xb33b9fba681653fe263b31a95766d83d18c2128d 2020-03-14 17:52:32
# 3  0x86fd6dd41bad636b5b3b9228bc5642fa0df392e8 2019-12-14 14:52:54
# 4  0x7cb9032844e722bef2e16a761832c59c96550898 2019-11-01 19:26:29

# %%
# add in votes
votes_df = pd.read_csv('votes.csv')
votes_df.head()
# Out:
#    Unnamed: 0  network                                                 id  \
# 0           0  mainnet  0x000682a038b22925343bd5b9e84acb424a9d14884326...
# 1           1  mainnet  0x001cde4d98e26191fc34308be3b51ce50d3eb9561b1b...
# 2           2  mainnet  0x001e7617a24d4e379669db1b4be94aa5cdc1b735d492...
# 3           3  mainnet  0x00202af217d5d4f46006ee508af4d4a8e40fa0c58ea0...
# 4           4  mainnet  0x00230b335032c2f363d717da48d79d7574b1712580e0...
#
#     createdAt                                       voter outcome  \
# 0  1678762043  0x91628ddc3a6ff9b48a2f34fc315d243eb07a9501    Pass
# 1  1653185389  0xabd238fa6b6042438fbd22e7d398199080b4224c    Pass
# 2  1564737938  0x13a0b42b9c180065510615972858bf41d1972a55    Pass
# 3  1578641505  0xba527d8301178a03a6993ab5a08cab06b975d5ae    Pass
# 4  1582800315  0xfc898b18a70ce49579f8d79a32e29928c15b4bc8    Fail
#
#                 reputation                                         dao  \
# 0  90248500000000000000000  0x519b70055af55a007110b4ff99b0ea33071c720a
# 1  68359641109260095429647  0x519b70055af55a007110b4ff99b0ea33071c720a
# 2    372846309003008579630  0x519b70055af55a007110b4ff99b0ea33071c720a
# 3    159178674775209859978  0x294f999356ed03347c7a23bcbcf8d33fa41dc830
# 4   1957062589266673407556  0xe56b4d8d42b1c9ea7dda8a6950e3699755943de7
#
#                                             proposal
# 0  0xb2a2b6baeed346c4e49a241044bd547504d02a3b593a...
# 1  0x53c9666338692a720a3ee3841b49f58a4d580cf7ed11...
# 2  0xb804dbb6ba463b704c5be53c3be122e0f9fd72ebd1d9...
# 3  0x576035e158f1b82d6ac8c0022f577ca39dfc8f0d7c92...
# 4  0xca3e2d80a89548ede61675882eed5c124e100d7f6bc2...

# %%
votes_by_proposal = votes_df.groupby('proposal').id.count()
# reindex
votes_by_proposal = votes_by_proposal.reset_index()
# name the col votes_count
votes_by_proposal = votes_by_proposal.rename(columns={'proposal': 'proposal_id', 'id': 'votes_count'})
votes_by_proposal.head()
# Out:
#                                          proposal_id  votes_count
# 0  0x0025c38d987acba1f1d446d3690384327ebe06d15f1f...            8
# 1  0x003011ffd2e419036cf900a1f03596d2548936067fc6...            1
# 2  0x0033a337b620add50be9ba0fff1128ab866ece51cfdd...            1
# 3  0x003c109411e96e5607ce609278536262e12afdaa65ab...            5
# 4  0x0048ff80a698fdc8eaa8cca00bd92f5bf93ba29d8544...            3

# %%
# left join
df = df.merge(votes_by_proposal, on='proposal_id', how='left', validate='one_to_one')
df.head()
# Out:
#    platform                      platform_deployment_id  \
# 0  daostack  0x294f999356ed03347c7a23bcbcf8d33fa41dc830
# 1  daostack  0x39757e7cdb7022c3829195d57b29428d79593c9d
# 2  daostack  0x519b70055af55a007110b4ff99b0ea33071c720a
# 3  daostack  0x8990e11b69403ea53ef2b32434bbd7dbf84b5234
# 4  daostack  0x440583455bcd85ab2bd429c015d3aabcae135f0a
#
#                                          proposal_id  \
# 0  0x0025c38d987acba1f1d446d3690384327ebe06d15f1f...
# 1  0x0033a337b620add50be9ba0fff1128ab866ece51cfdd...
# 2  0x003c109411e96e5607ce609278536262e12afdaa65ab...
# 3  0x0071c649968f7939fc9729c5dc25a8ae3f50dc86220a...
# 4  0x007eaf0fc8d6ae35ba3f28bc7cf4b34af659db8161d4...
#
#                                        author                date  votes_count
# 0  0xbaaea72417f4dc3e0f52a1783b0913d0f3516634 2019-10-22 10:07:58          8.0
# 1  0x052c68abe8e4bf0b78925e488b98f6fdc18a3af9 2020-01-17 19:07:19          1.0
# 2  0xb33b9fba681653fe263b31a95766d83d18c2128d 2020-03-14 17:52:32          5.0
# 3  0x86fd6dd41bad636b5b3b9228bc5642fa0df392e8 2019-12-14 14:52:54          1.0
# 4  0x7cb9032844e722bef2e16a761832c59c96550898 2019-11-01 19:26:29          1.0

# %%
# fill na with 0
df['votes_count'] = df['votes_count'].fillna(0)
# make votes_count an int
df['votes_count'] = df['votes_count'].astype(int)
df.head()
# Out:
#    platform                      platform_deployment_id  \
# 0  daostack  0x294f999356ed03347c7a23bcbcf8d33fa41dc830
# 1  daostack  0x39757e7cdb7022c3829195d57b29428d79593c9d
# 2  daostack  0x519b70055af55a007110b4ff99b0ea33071c720a
# 3  daostack  0x8990e11b69403ea53ef2b32434bbd7dbf84b5234
# 4  daostack  0x440583455bcd85ab2bd429c015d3aabcae135f0a
#
#                                          proposal_id  \
# 0  0x0025c38d987acba1f1d446d3690384327ebe06d15f1f...
# 1  0x0033a337b620add50be9ba0fff1128ab866ece51cfdd...
# 2  0x003c109411e96e5607ce609278536262e12afdaa65ab...
# 3  0x0071c649968f7939fc9729c5dc25a8ae3f50dc86220a...
# 4  0x007eaf0fc8d6ae35ba3f28bc7cf4b34af659db8161d4...
#
#                                        author                date  votes_count
# 0  0xbaaea72417f4dc3e0f52a1783b0913d0f3516634 2019-10-22 10:07:58            8
# 1  0x052c68abe8e4bf0b78925e488b98f6fdc18a3af9 2020-01-17 19:07:19            1
# 2  0xb33b9fba681653fe263b31a95766d83d18c2128d 2020-03-14 17:52:32            5
# 3  0x86fd6dd41bad636b5b3b9228bc5642fa0df392e8 2019-12-14 14:52:54            1
# 4  0x7cb9032844e722bef2e16a761832c59c96550898 2019-11-01 19:26:29            1

# %%
# save
df.to_csv('daostack_proposals.csv', index=False)

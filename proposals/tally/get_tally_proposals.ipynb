# %%
import json
# read api key from tally_api_key.json
TALLY_API_KEY = json.load(open('tally_api_key.json'))['key']

# %%
import requests

url = "https://api.tally.xyz/query"

headers = {
  'Api-Key': TALLY_API_KEY,
  'Content-Type': 'application/json'
}

# %%
payload="{\"query\":\"query Chains {\\n    chains {\\n        id\\n    }\\n}\",\"variables\":{}}"

chains_response = requests.request("POST", url, headers=headers, data=payload)

chains_data = chains_response.json()
chains_data
# Out:
# {'data': {'chains': [{'id': 'eip155:412346'},
#    {'id': 'eip155:42'},
#    {'id': 'eip155:80001'},
#    {'id': 'eip155:137'},
#    {'id': 'eip155:42161'},
#    {'id': 'eip155:421611'},
#    {'id': 'eip155:43113'},
#    {'id': 'eip155:5'},
#    {'id': 'eip155:534353'},
#    {'id': 'eip155:1'},
#    {'id': 'eip155:100'},
#    {'id': 'eip155:10'},
#    {'id': 'eip155:4'},
#    {'id': 'eip155:56'},
#    {'id': 'eip155:42170'},
#    {'id': 'eip155:97'},
#    {'id': 'eip155:43114'},
#    {'id': 'eip155:84531'},
#    {'id': 'eip155:420'},
#    {'id': 'eip155:1284'},
#    {'id': 'eip155:69'},
#    {'id': 'eip155:11155111'},
#    {'id': 'eip155:421613'}]}}

# %%
chains = chains_data['data']['chains']
chains = [c['id'] for c in chains]
chains
# Out:
# ['eip155:412346',
#  'eip155:42',
#  'eip155:80001',
#  'eip155:137',
#  'eip155:42161',
#  'eip155:421611',
#  'eip155:43113',
#  'eip155:5',
#  'eip155:534353',
#  'eip155:1',
#  'eip155:100',
#  'eip155:10',
#  'eip155:4',
#  'eip155:56',
#  'eip155:42170',
#  'eip155:97',
#  'eip155:43114',
#  'eip155:84531',
#  'eip155:420',
#  'eip155:1284',
#  'eip155:69',
#  'eip155:11155111',
#  'eip155:421613']

# %%
query = """query Proposals {
    proposals(
        chainId: "eip155:42161"
    ) {
        platform_deployment_id: governanceId
        proposal_id: id
        author: proposer {
            id
        }
        date: start {
            timestamp
        }
        voteStats {
            support
            votes
        }
    }
}"""

# %%
response = requests.request("POST", url, headers=headers, data=json.dumps({'query': query}))
response.content
# Out:
# b'{"data":{"proposals":[{"platform_deployment_id":"eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B82EB04F01","proposal_id":"7111974346912460307016744445591582524939682069963197750155992426034337655927","author":{"id":"eip155:42161:0xfA5F7CE9055A36c673F7F12970570938633934c0"},"date":{"timestamp":"2022-09-12T01:29:49Z"},"voteStats":[{"support":"FOR","votes":"0"},{"support":"AGAINST","votes":"0"},{"support":"ABSTAIN","votes":"0"}]},{"platform_deployment_id":"eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B82EB04F01","proposal_id":"113638556591867963012662177908817688187696698785932907203812977693535248523190","author":{"id":"eip155:42161:0xfA5F7CE9055A36c673F7F12970570938633934c0"},"date":{"timestamp":"2022-09-12T06:49:26Z"},"voteStats":[{"support":"FOR","votes":"0"},{"support":"AGAINST","votes":"0"},{"support":"ABSTAIN","votes":"0"}]},{"platform_deployment_id":"eip155:42161:0x936139366c5db48543368EE9cD075267d176a02c","proposal_id":"13493017690761946741400093368187230035591034324284495176513333880370190856201","author":{"id":"eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760433147287"},"date":{"timestamp":"2023-04-10T18:24:35Z"},"voteStats":[{"support":"FOR","votes":"1"},{"support":"AGAINST","votes":"0"},{"support":"ABSTAIN","votes":"0"}]},{"platform_deployment_id":"eip155:42161:0x936139366c5db48543368EE9cD075267d176a02c","proposal_id":"103714146047724671567962670629574765893960633329325169312853689645859637618425","author":{"id":"eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760433147287"},"date":{"timestamp":"2023-04-17T15:10:47Z"},"voteStats":[{"support":"FOR","votes":"1"},{"support":"AGAINST","votes":"0"},{"support":"ABSTAIN","votes":"0"}]},{"platform_deployment_id":"eip155:42161:0x8dEc1460C23767e17557f163d8Fe39AF37A244Bb","proposal_id":"50801983938071129676641503698831609861611568381815710876135484678256646066529","author":{"id":"eip155:42161:0x96223b32A75a22de7c192A1b99366c7eD12c1649"},"date":{"timestamp":"2023-03-23T01:00:35Z"},"voteStats":[{"support":"FOR","votes":"0"},{"support":"AGAINST","votes":"0"},{"support":"ABSTAIN","votes":"0"}]},{"platform_deployment_id":"eip155:42161:0x936139366c5db48543368EE9cD075267d176a02c","proposal_id":"110740543188552961321198802095505241882170377945956616630060446973719509718865","author":{"id":"eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760433147287"},"date":{"timestamp":"2023-04-18T06:52:59Z"},"voteStats":[{"support":"FOR","votes":"1"},{"support":"AGAINST","votes":"0"},{"support":"ABSTAIN","votes":"0"}]},{"platform_deployment_id":"eip155:42161:0x936139366c5db48543368EE9cD075267d176a02c","proposal_id":"55714642950107918353106875793573558173090439945974536792140800861794487805775","author":{"id":"eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760433147287"},"date":{"timestamp":"2023-04-18T07:30:59Z"},"voteStats":[{"support":"FOR","votes":"1"},{"support":"AGAINST","votes":"0"},{"support":"ABSTAIN","votes":"0"}]},{"platform_deployment_id":"eip155:42161:0x8dEc1460C23767e17557f163d8Fe39AF37A244Bb","proposal_id":"17191167863539107028650932328259151319447759713925225253185152894602985856238","author":{"id":"eip155:42161:0x96223b32A75a22de7c192A1b99366c7eD12c1649"},"date":{"timestamp":"2023-03-23T01:01:23Z"},"voteStats":[{"support":"FOR","votes":"0"},{"support":"AGAINST","votes":"0"},{"support":"ABSTAIN","votes":"0"}]},{"platform_deployment_id":"eip155:42161:0x50091D36E8904a222dFa84a23812451a169A3b0f","proposal_id":"47630952603044807181918290412895044285278805241555873713012182112967341021937","author":{"id":"eip155:42161:0x7Adc86401f246B87177CEbBEC189dE075b75Af3A"},"date":{"timestamp":"2023-02-28T19:14:11Z"},"voteStats":[{"support":"FOR","votes":"2"},{"support":"AGAINST","votes":"0"},{"support":"ABSTAIN","votes":"0"}]},{"platform_deployment_id":"eip155:42161:0x50091D36E8904a222dFa84a23812451a169A3b0f","proposal_id":"67225298146254293804326713665378316584414830750053385702095020637427710003806","author":{"id":"eip155:42161:0x7Adc86401f246B87177CEbBEC189dE075b75Af3A"},"date":{"timestamp":"2023-02-28T19:56:47Z ...

# %%
import pandas as pd
df = pd.DataFrame(response.json()['data']['proposals'])
df.head()
# Out:
#                               platform_deployment_id  \
# 0  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 1  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 2  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 3  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 4  eip155:42161:0x8dEc1460C23767e17557f163d8Fe39A...
#
#                                          proposal_id  \
# 0  7111974346912460307016744445591582524939682069...
# 1  1136385565918679630126621779088176881876966987...
# 2  1349301769076194674140009336818723003559103432...
# 3  1037141460477246715679626706295747658939606333...
# 4  5080198393807112967664150369883160986161156838...
#
#                                               author  \
# 0  {'id': 'eip155:42161:0xfA5F7CE9055A36c673F7F12...
# 1  {'id': 'eip155:42161:0xfA5F7CE9055A36c673F7F12...
# 2  {'id': 'eip155:42161:0xA4a3aC7cBA6B584c674737e...
# 3  {'id': 'eip155:42161:0xA4a3aC7cBA6B584c674737e...
# 4  {'id': 'eip155:42161:0x96223b32A75a22de7c192A1...
#
#                                     date  \
# 0  {'timestamp': '2022-09-12T01:29:49Z'}
# 1  {'timestamp': '2022-09-12T06:49:26Z'}
# 2  {'timestamp': '2023-04-10T18:24:35Z'}
# 3  {'timestamp': '2023-04-17T15:10:47Z'}
# 4  {'timestamp': '2023-03-23T01:00:35Z'}
#
#                                            voteStats
# 0  [{'support': 'FOR', 'votes': '0'}, {'support':...
# 1  [{'support': 'FOR', 'votes': '0'}, {'support':...
# 2  [{'support': 'FOR', 'votes': '1'}, {'support':...
# 3  [{'support': 'FOR', 'votes': '1'}, {'support':...
# 4  [{'support': 'FOR', 'votes': '0'}, {'support':...

# %%
# replace author column with author_id
df['author'] = df['author'].apply(lambda x: x['id'])
df.head()
# Out:
#                               platform_deployment_id  \
# 0  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 1  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 2  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 3  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 4  eip155:42161:0x8dEc1460C23767e17557f163d8Fe39A...
#
#                                          proposal_id  \
# 0  7111974346912460307016744445591582524939682069...
# 1  1136385565918679630126621779088176881876966987...
# 2  1349301769076194674140009336818723003559103432...
# 3  1037141460477246715679626706295747658939606333...
# 4  5080198393807112967664150369883160986161156838...
#
#                                               author  \
# 0  eip155:42161:0xfA5F7CE9055A36c673F7F1297057093...
# 1  eip155:42161:0xfA5F7CE9055A36c673F7F1297057093...
# 2  eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760...
# 3  eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760...
# 4  eip155:42161:0x96223b32A75a22de7c192A1b99366c7...
#
#                                     date  \
# 0  {'timestamp': '2022-09-12T01:29:49Z'}
# 1  {'timestamp': '2022-09-12T06:49:26Z'}
# 2  {'timestamp': '2023-04-10T18:24:35Z'}
# 3  {'timestamp': '2023-04-17T15:10:47Z'}
# 4  {'timestamp': '2023-03-23T01:00:35Z'}
#
#                                            voteStats
# 0  [{'support': 'FOR', 'votes': '0'}, {'support':...
# 1  [{'support': 'FOR', 'votes': '0'}, {'support':...
# 2  [{'support': 'FOR', 'votes': '1'}, {'support':...
# 3  [{'support': 'FOR', 'votes': '1'}, {'support':...
# 4  [{'support': 'FOR', 'votes': '0'}, {'support':...

# %%
# read date.timestamp as date
df['date'] = df['date'].apply(lambda x: x['timestamp'])
# convert date to datetime from 2022-09-12T06:49:26Z format
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#                               platform_deployment_id  \
# 0  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 1  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 2  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 3  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 4  eip155:42161:0x8dEc1460C23767e17557f163d8Fe39A...
#
#                                          proposal_id  \
# 0  7111974346912460307016744445591582524939682069...
# 1  1136385565918679630126621779088176881876966987...
# 2  1349301769076194674140009336818723003559103432...
# 3  1037141460477246715679626706295747658939606333...
# 4  5080198393807112967664150369883160986161156838...
#
#                                               author  \
# 0  eip155:42161:0xfA5F7CE9055A36c673F7F1297057093...
# 1  eip155:42161:0xfA5F7CE9055A36c673F7F1297057093...
# 2  eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760...
# 3  eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760...
# 4  eip155:42161:0x96223b32A75a22de7c192A1b99366c7...
#
#                        date                                          voteStats
# 0 2022-09-12 01:29:49+00:00  [{'support': 'FOR', 'votes': '0'}, {'support':...
# 1 2022-09-12 06:49:26+00:00  [{'support': 'FOR', 'votes': '0'}, {'support':...
# 2 2023-04-10 18:24:35+00:00  [{'support': 'FOR', 'votes': '1'}, {'support':...
# 3 2023-04-17 15:10:47+00:00  [{'support': 'FOR', 'votes': '1'}, {'support':...
# 4 2023-03-23 01:00:35+00:00  [{'support': 'FOR', 'votes': '0'}, {'support':...

# %%
# remove tz info from date
df['date'] = df['date'].apply(lambda x: x.replace(tzinfo=None))
df.head()
# Out:
#                               platform_deployment_id  \
# 0  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 1  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 2  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 3  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 4  eip155:42161:0x8dEc1460C23767e17557f163d8Fe39A...
#
#                                          proposal_id  \
# 0  7111974346912460307016744445591582524939682069...
# 1  1136385565918679630126621779088176881876966987...
# 2  1349301769076194674140009336818723003559103432...
# 3  1037141460477246715679626706295747658939606333...
# 4  5080198393807112967664150369883160986161156838...
#
#                                               author                date  \
# 0  eip155:42161:0xfA5F7CE9055A36c673F7F1297057093... 2022-09-12 01:29:49
# 1  eip155:42161:0xfA5F7CE9055A36c673F7F1297057093... 2022-09-12 06:49:26
# 2  eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760... 2023-04-10 18:24:35
# 3  eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760... 2023-04-17 15:10:47
# 4  eip155:42161:0x96223b32A75a22de7c192A1b99366c7... 2023-03-23 01:00:35
#
#                                            voteStats
# 0  [{'support': 'FOR', 'votes': '0'}, {'support':...
# 1  [{'support': 'FOR', 'votes': '0'}, {'support':...
# 2  [{'support': 'FOR', 'votes': '1'}, {'support':...
# 3  [{'support': 'FOR', 'votes': '1'}, {'support':...
# 4  [{'support': 'FOR', 'votes': '0'}, {'support':...

# %%
# sum the 'votes' value for each item in voteStats and save as votes_count
df['votes_count'] = df['voteStats'].apply(lambda x: sum([int(i['votes']) for i in x]))
# drop voteStats column
df.drop('voteStats', axis=1, inplace=True)
df.head()
# Out:
#                               platform_deployment_id  \
# 0  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 1  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 2  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 3  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 4  eip155:42161:0x8dEc1460C23767e17557f163d8Fe39A...
#
#                                          proposal_id  \
# 0  7111974346912460307016744445591582524939682069...
# 1  1136385565918679630126621779088176881876966987...
# 2  1349301769076194674140009336818723003559103432...
# 3  1037141460477246715679626706295747658939606333...
# 4  5080198393807112967664150369883160986161156838...
#
#                                               author                date  \
# 0  eip155:42161:0xfA5F7CE9055A36c673F7F1297057093... 2022-09-12 01:29:49
# 1  eip155:42161:0xfA5F7CE9055A36c673F7F1297057093... 2022-09-12 06:49:26
# 2  eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760... 2023-04-10 18:24:35
# 3  eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760... 2023-04-17 15:10:47
# 4  eip155:42161:0x96223b32A75a22de7c192A1b99366c7... 2023-03-23 01:00:35
#
#    votes_count
# 0            0
# 1            0
# 2            1
# 3            1
# 4            0

# %%
df['platform'] = 'tally'
# reorder cols so that platform is first
df = df[['platform', 'platform_deployment_id', 'proposal_id', 'author', 'date', 'votes_count']]
df.head()
# Out:
#   platform                             platform_deployment_id  \
# 0    tally  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 1    tally  eip155:42161:0xbCC46a8D83B6f16e5b8A99116B4467B...
# 2    tally  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 3    tally  eip155:42161:0x936139366c5db48543368EE9cD07526...
# 4    tally  eip155:42161:0x8dEc1460C23767e17557f163d8Fe39A...
#
#                                          proposal_id  \
# 0  7111974346912460307016744445591582524939682069...
# 1  1136385565918679630126621779088176881876966987...
# 2  1349301769076194674140009336818723003559103432...
# 3  1037141460477246715679626706295747658939606333...
# 4  5080198393807112967664150369883160986161156838...
#
#                                               author                date  \
# 0  eip155:42161:0xfA5F7CE9055A36c673F7F1297057093... 2022-09-12 01:29:49
# 1  eip155:42161:0xfA5F7CE9055A36c673F7F1297057093... 2022-09-12 06:49:26
# 2  eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760... 2023-04-10 18:24:35
# 3  eip155:42161:0xA4a3aC7cBA6B584c674737e7a04d760... 2023-04-17 15:10:47
# 4  eip155:42161:0x96223b32A75a22de7c192A1b99366c7... 2023-03-23 01:00:35
#
#    votes_count
# 0            0
# 1            0
# 2            1
# 3            1
# 4            0

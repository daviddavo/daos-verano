# %%
import pandas as pd

# read proposals.csv
df = pd.read_csv('proposals.csv')
# drop unnamed column
df = df.drop(df.columns[0], axis=1)
df.head()
# Out:
#     network                                                 id   createdAt  \
# 0  arbitrum  0x02c6c33b9bb6b2fc8ae9ab43a0235f4d7897b5d9-pro...  1662047614
# 1  arbitrum  0x02c6c33b9bb6b2fc8ae9ab43a0235f4d7897b5d9-pro...  1662048470
# 2  arbitrum  0x0d8d5002562405cb1ed598ff4fb48c948f36a18b-pro...  1667987888
# 3  arbitrum  0x15909f6e92e32a6c3187fad2f7ea91f2b3dfdcf9-pro...  1642252357
# 4  arbitrum  0x15909f6e92e32a6c3187fad2f7ea91f2b3dfdcf9-pro...  1642252710
#
#    proposalId                               molochAddress  \
# 0           0  0x02c6c33b9bb6b2fc8ae9ab43a0235f4d7897b5d9
# 1           1  0x02c6c33b9bb6b2fc8ae9ab43a0235f4d7897b5d9
# 2           0  0x0d8d5002562405cb1ed598ff4fb48c948f36a18b
# 3           0  0x15909f6e92e32a6c3187fad2f7ea91f2b3dfdcf9
# 4           1  0x15909f6e92e32a6c3187fad2f7ea91f2b3dfdcf9
#
#                                 memberAddress  \
# 0  0x8435d0a8f19f748cba91863b70eb986895ee4b49
# 1  0x8435d0a8f19f748cba91863b70eb986895ee4b49
# 2  0xe3d8c94be1550dbde55811bb39c0d3868bafd068
# 3  0x54c375c481f95ba43e2cecd6ef30631f55518f57
# 4  0x54c375c481f95ba43e2cecd6ef30631f55518f57
#
#                                      proposer  \
# 0  0x8435d0a8f19f748cba91863b70eb986895ee4b49
# 1  0x8435d0a8f19f748cba91863b70eb986895ee4b49
# 2  0xe3d8c94be1550dbde55811bb39c0d3868bafd068
# 3  0x54c375c481f95ba43e2cecd6ef30631f55518f57
# 4  0x54c375c481f95ba43e2cecd6ef30631f55518f57
#
#                                       sponsor  sharesRequested  lootRequested  \
# 0  0x0000000000000000000000000000000000000000               50              0
# 1  0x8435d0a8f19f748cba91863b70eb986895ee4b49               50              0
# 2  0xe3d8c94be1550dbde55811bb39c0d3868bafd068                0              0
# 3  0x0000000000000000000000000000000000000000                0              0
# 4  0x0000000000000000000000000000000000000000                1              0
#
#    ... paymentRequested yesVotes  noVotes  sponsored   sponsoredAt  processed  \
# 0  ...                0        0        0      False           NaN      False
# 1  ...                0        1        0       True  1.662049e+09      False
# 2  ...                0        1        0       True  1.667988e+09       True
# 3  ...                0        0        0      False           NaN      False
# 4  ...                0        0        0      False           NaN      False
#
#     processedAt  didPass  yesShares  noShares
# 0           NaN    False          0         0
# 1           NaN    False          1         0
# 2  1.669313e+09     True          1         0
# 3           NaN    False          0         0
# 4           NaN    False          0         0
#
# [5 rows x 21 columns]

# %%
df.iloc[0]
# Out:
# network                                                      arbitrum
# id                  0x02c6c33b9bb6b2fc8ae9ab43a0235f4d7897b5d9-pro...
# createdAt                                                  1662047614
# proposalId                                                          0
# molochAddress              0x02c6c33b9bb6b2fc8ae9ab43a0235f4d7897b5d9
# memberAddress              0x8435d0a8f19f748cba91863b70eb986895ee4b49
# proposer                   0x8435d0a8f19f748cba91863b70eb986895ee4b49
# sponsor                    0x0000000000000000000000000000000000000000
# sharesRequested                                                    50
# lootRequested                                                       0
# tributeOffered                                                      0
# paymentRequested                                                    0
# yesVotes                                                            0
# noVotes                                                             0
# sponsored                                                       False
# sponsoredAt                                                       NaN
# processed                                                       False
# processedAt                                                       NaN
# didPass                                                         False
# yesShares                                                           0
# noShares                                                            0
# Name: 0, dtype: object

# %%
# make a votes_count column from yes_votes and no_votes sum
df['votes_count'] = df['yesVotes'] + df['noVotes']

# %%
# * platform
df['platform'] = 'daohaus'
# * platform_deployment_id
# rename molochAddress to platform_deployment_id
df = df.rename(columns={'molochAddress': 'platform_deployment_id'})
# * proposal_id
# rename id to proposal_id
df = df.rename(columns={'id': 'proposal_id'})
# * author
# rename proposer to author
df = df.rename(columns={'proposer': 'author'})
# * date -- this should be as a pandas date, not as an epoch
# convert epoch to pandas date
df['date'] = pd.to_datetime(df['createdAt'], unit='s')
# * votes_count

# %%
df = df[['platform', 'platform_deployment_id', 'proposal_id', 'author', 'date', 'votes_count']]
df.head()
# Out:
#   platform                      platform_deployment_id  \
# 0  daohaus  0x02c6c33b9bb6b2fc8ae9ab43a0235f4d7897b5d9
# 1  daohaus  0x02c6c33b9bb6b2fc8ae9ab43a0235f4d7897b5d9
# 2  daohaus  0x0d8d5002562405cb1ed598ff4fb48c948f36a18b
# 3  daohaus  0x15909f6e92e32a6c3187fad2f7ea91f2b3dfdcf9
# 4  daohaus  0x15909f6e92e32a6c3187fad2f7ea91f2b3dfdcf9
#
#                                          proposal_id  \
# 0  0x02c6c33b9bb6b2fc8ae9ab43a0235f4d7897b5d9-pro...
# 1  0x02c6c33b9bb6b2fc8ae9ab43a0235f4d7897b5d9-pro...
# 2  0x0d8d5002562405cb1ed598ff4fb48c948f36a18b-pro...
# 3  0x15909f6e92e32a6c3187fad2f7ea91f2b3dfdcf9-pro...
# 4  0x15909f6e92e32a6c3187fad2f7ea91f2b3dfdcf9-pro...
#
#                                        author                date  votes_count
# 0  0x8435d0a8f19f748cba91863b70eb986895ee4b49 2022-09-01 15:53:34            0
# 1  0x8435d0a8f19f748cba91863b70eb986895ee4b49 2022-09-01 16:07:50            1
# 2  0xe3d8c94be1550dbde55811bb39c0d3868bafd068 2022-11-09 09:58:08            1
# 3  0x54c375c481f95ba43e2cecd6ef30631f55518f57 2022-01-15 13:12:37            0
# 4  0x54c375c481f95ba43e2cecd6ef30631f55518f57 2022-01-15 13:18:30            0

# %%
# save as csv
df.to_csv('daohaus_proposals.csv', index=False)

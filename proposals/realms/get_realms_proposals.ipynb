# %% [markdown]
# We'll used the downloaded data from node to output a proposals csv

# %%
import os
REALMS_NODE_DIR = '../../realms_node'
REALMS_NODE_DATA_DIR = os.path.join(REALMS_NODE_DIR, 'output_proposals_2023_8_3')

# %%
# read all of the jsons in the directory, set the filename as a column
# and concat them all together
import glob
import pandas as pd
import json

jsons = glob.glob(os.path.join(REALMS_NODE_DATA_DIR, '*proposals.json'))

# read all the jsons into a flattened list
json_list = []
for json_file in jsons:
    with open(json_file, 'r') as f:
        read_json = json.load(f)
        # these files are a list of lists of dicts, so flatten them
        # if this is an empty list, skip
        if len(read_json) == 0:
            continue
        # if this is a list of dicts, flatten it
        if type(read_json[0]) == dict:
            read_json = [read_json]
        if type(read_json) != list:
            print(read_json)
        # for all objects in the list, set the filename as a key
        for obj in read_json:
            for i in obj:
                i['filename'] = os.path.basename(json_file)
                # replace _proposals.json at end with ''
                i['filename'] = i['filename'].replace('_proposals.json', '')
        json_list.extend(read_json)

# %%
# remove empty lists from the json_list
json_list = [x for x in json_list if x != []]
# make json_list a 1d list instead of a list of lists
json_list = [item for sublist in json_list for item in sublist]
json_list
# Out:
# [{'pubkey': 'GThdf6h1QFFNxBijUzCZRsnJP7JZY713koFTnyytxXMc',
#   'account': {'accountType': 14,
#    'governance': '7qFBvR5SGe3GrifRBZjBZFdwidSX64G2kRQvgALfFBWY',
#    'governingTokenMint': '86PBLBdCjj7R4maYw696Ftj168UZV4sp3VggQ3VFd2oR',
#    'state': 5,
#    'tokenOwnerRecord': '12g7fJGJka8BGGYmvCkEU5ezKHBjxSPGk41S3QP57yJY',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Add council member zNpv2…Expve',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '625f2266',
#    'signingOffAt': '625f2266',
#    'votingAt': '625f2266',
#    'votingAtSlot': '07c6c4f1',
#    'votingCompletedAt': 1650401951,
#    'executingAt': '625f2363',
#    'closedAt': '625f2363',
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 51},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'GM89o7QLfMcCvTC92dcg2oXFYm99RHeJ1qggFDzMwtDF',
#   'account': {'accountType': 14,
#    'governance': '7qFBvR5SGe3GrifRBZjBZFdwidSX64G2kRQvgALfFBWY',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 6,
#    'tokenOwnerRecord': '12g7fJGJka8BGGYmvCkEU5ezKHBjxSPGk41S3QP57yJY',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Upcoming mint of Shkary Scenes is essential for the future of our project. We need to make sure that we do all we can to make it a success. ',
#    'name': 'Marketing Budget for Shkary Scenes',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62ff8a83',
#    'signingOffAt': '62ff8a83',
#    'votingAt': '62ff8a83',
#    'votingAtSlot': '08be42dd',
#    'closedAt': '62ff8aba',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': '9NWj6RsHgTx19aqrrGQeTLdkE1kuD6X5Lhg8k91PkvfV',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': '86PBLBdCjj7R4maYw696Ftj168UZV4sp3VggQ3VFd2oR',
#    'state': 0,
#    'tokenOwnerRecord': 'HmLRS3bTH7PBsK5mvcEcR6Neh4Qp847xbsH5i5fbeJ3M',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 0,
#    'descriptionLink': 'Create NFT plugin registrar',
#    'name': 'Create NFT plugin registrar',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '625f261c',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'cEMSFTCQrDWAgENaXW5FLVCAe5vuDUxLvfDhUjVGMC4',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': '86PBLBdCjj7R4maYw696Ftj168UZV4sp3VggQ3VFd2oR',
#    'state': 5,
#    'tokenOwnerRecord': 'EbXQD3FZCPAM1uAWKaQgepxMy9EJjPoBvfSDM9XaPxy5',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change vote threshold to 7%',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '02',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '6262db5f',
#    'signingOffAt': '6262db5f',
#    'votingAt': '6262db5f',
#    'votingAtSlot': '07ccfbb3',
#    'votingCompletedAt': 1650650046,
#    'executingAt': '6262f48b',
#    'closedAt': '6262f48b',
#    'executionFlags': 0,
#    'maxVoteWeight': '02',
#    'voteThreshold': {'type': 0, 'value': 51},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': '2BEDW1goPvvU2a6ZxFqMGb3mop8DoGsWeBrcnupSE21q',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': '86PBLBdCjj7R4maYw696Ftj168UZV4sp3VggQ3VFd2oR',
#    'state': 5,
#    'tokenOwnerRecord': 'HmLRS3bTH7PBsK5mvcEcR6Neh4Qp847xbsH5i5fbeJ3M',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Enable NFT voter plugin',
#    'name': 'Enable NFT voter plugin',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '02',
#      'voteResult': 1,
#      'instructionsExecutedCount': 3,
#      'instructionsCount': 3,
#      'instructionsNextIndex': 3}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '625f266d',
#    'signingOffAt': '625f267d',
#    'votingAt': '625f267d',
#    'votingAtSlot': '07c6cab1',
#    'votingCompletedAt': 1650403208,
#    'executingAt': '625f2893',
#    'closedAt': '625f28f9',
#    'executionFlags': 0,
#    'maxVoteWeight': '02',
#    'voteThreshold': {'type': 0, 'value': 51},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': '3Y8tExvaJC7rSLU6CRjFcFiPH4AAGabAPMXyc4kmTeHD',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': '86PBLBdCjj7R4maYw696Ftj168UZV4sp3VggQ3VFd2oR',
#    'state': 5,
#    'tokenOwnerRecord': 'HmLRS3bTH7PBsK5mvcEcR6Neh4Qp847xbsH5i5fbeJ3M',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change config to NFT Voting',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '02',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '625f2a5d',
#    'signingOffAt': '625f2a5d',
#    'votingAt': '625f2a5d',
#    'votingAtSlot': '07c6d019',
#    'votingCompletedAt': 1650404147,
#    'executingAt': '625f2ba1',
#    'closedAt': '625f2ba1',
#    'executionFlags': 0,
#    'maxVoteWeight': '02',
#    'voteThreshold': {'type': 0, 'value': 51},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': '3tjQLkKw7K5Q94ke3usGiSAQvgkYdwqDSPuMzsq7VLg5',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': '86PBLBdCjj7R4maYw696Ftj168UZV4sp3VggQ3VFd2oR',
#    'state': 5,
#    'tokenOwnerRecord': 'HmLRS3bTH7PBsK5mvcEcR6Neh4Qp847xbsH5i5fbeJ3M',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'change minimum tokens for proposal to 1',
#    'name': 'change minimum tokens for proposal',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '02',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '625f465d',
#    'signingOffAt': '625f465d',
#    'votingAt': '625f465d',
#    'votingAtSlot': '07c6fa61',
#    'votingCompletedAt': 1650411277,
#    'executingAt': '625f472c',
#    'closedAt': '625f472c',
#    'executionFlags': 0,
#    'maxVoteWeight': '02',
#    'voteThreshold': {'type': 0, 'value': 51},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': '62kUkYmeEHPf38r8C9PW83B43sHCPK2kis8nY4VUyV4T',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 0,
#    'tokenOwnerRecord': '23DWoq5AQh1hnKRS4Dk4CRXHKofW2QcADP6YTbSEe79z',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 0,
#    'descriptionLink': 'https://discord.com/channels/886787538294026260/937841739971039342/971540069167026196',
#    'name': 'Initiate easy utility program for CHOMPS - NFT raffle tickets',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '627445aa',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': '7cfgKJpZ9NPgicYhzbfvikvXo9FdNUE7G9Z7v6CsqhKp',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 3,
#    'tokenOwnerRecord': '7qwMUcDoU8jvZimUugiUeH7fZoeEn5bHGAykSwBH57Qp',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Approve the budget of 6500$ for The Shkary Casino.',
#    'name': 'Shkary Casino',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '07641700',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '7a1200',
#    'reserved1': 0,
#    'draftAt': '627ae0eb',
#    'signingOffAt': '627ae0fa',
#    'votingAt': '627ae0fa',
#    'votingAtSlot': '07f24dcc',
#    'votingCompletedAt': 1652481811,
#    'executionFlags': 0,
#    'maxVoteWeight': '53dd1dc0',
#    'voteThreshold': {'type': 0, 'value': 7},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': '9CXHPnE2y8xhqzC89jZswPjZknY4FJPJXupVgRf6qtLZ',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 6,
#    'tokenOwnerRecord': '7qwMUcDoU8jvZimUugiUeH7fZoeEn5bHGAykSwBH57Qp',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'You can read more info on Discord :) You can also ask questions...',
#    'name': "''Sharks Bite Back Better'' update",
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '627ee54e',
#    'signingOffAt': '627ee57d',
#    'votingAt': '627ee57d',
#    'votingAtSlot': '07f80112',
#    'closedAt': '627ef4da',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': '9knr5suFpSnb3LCZaeAormeEoCanptHmqbtfpf81PGuD',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 6,
#    'tokenOwnerRecord': 'HmLRS3bTH7PBsK5mvcEcR6Neh4Qp847xbsH5i5fbeJ3M',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'This Is a test proposal for testing the NFT governance',
#    'name': 'Test Voting Proposal',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '1e8480',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '625f2e58',
#    'signingOffAt': '625f2e58',
#    'votingAt': '625f2e58',
#    'votingAtSlot': '07c6d5e5',
#    'closedAt': '625f41af',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'AjS3gUDW4mx65TE7UzPBkqwwVgX1mU5UET2BV9qDzoWz',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 6,
#    'tokenOwnerRecord': '7La494eR3ffAe9GtPGHwReWPqw9WTrnKSBvwWYsE6Zhy',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'test proposal',
#    'name': 'test proposal',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '1e8480',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '625f4b24',
#    'signingOffAt': '625f4b24',
#    'votingAt': '625f4b24',
#    'votingAtSlot': '07c701ba',
#    'closedAt': '625f4d8b',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'BGBjeFTiao7gbRoXWjgkoidkvVgJmXSfRke83gSk2z1F',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 2,
#    'tokenOwnerRecord': '7qwMUcDoU8jvZimUugiUeH7fZoeEn5bHGAykSwBH57Qp',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Implementation of Sol Decoder tools and their engage to earn platform + utilizing the funds from Sunken Booty to reward community members based on their engagement. ',
#    'name': 'Engage to earn',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '07641700',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '632c8f87',
#    'signingOffAt': '632c8f88',
#    'votingAt': '632c8f88',
#    'votingAtSlot': '090d12f3',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'CdPd5CwAZpmtJAxXr8HUSsYbvXjQjuv3jdVsM3RWjDd5',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 7,
#    'tokenOwnerRecord': '7qwMUcDoU8jvZimUugiUeH7fZoeEn5bHGAykSwBH57Qp',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Finally here.',
#    'name': 'Test',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '054e0840',
#      'voteResult': 2,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '1e8480',
#    'reserved1': 0,
#    'draftAt': '625f4afd',
#    'signingOffAt': '625f4afd',
#    'votingAt': '625f4afd',
#    'votingAtSlot': '07c70179',
#    'votingCompletedAt': 1650679561,
#    'executionFlags': 0,
#    'maxVoteWeight': '53dd1dc0',
#    'voteThreshold': {'type': 0, 'value': 7},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'CtgUmRvB5X6NMFbDsG3mbGivEvhBtNfE126vrP8mroB6',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 0,
#    'tokenOwnerRecord': '23DWoq5AQh1hnKRS4Dk4CRXHKofW2QcADP6YTbSEe79z',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 0,
#    'descriptionLink': 'https://discord.com/channels/886787538294026260/937850882903650366/971535183536853012',
#    'name': 'Increasing Twitter presence with a rewarding system',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62744632',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'DBUo3jnd3QosMohbcm4Ztbbqsn7WtgD2pt2MmA1dR4Fp',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 3,
#    'tokenOwnerRecord': '7qwMUcDoU8jvZimUugiUeH7fZoeEn5bHGAykSwBH57Qp',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'check recent DAO announcement ',
#    'name': '30 Sol Marketing budget.',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '07088980',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '6305eb50',
#    'signingOffAt': '6305eb52',
#    'votingAt': '6305eb52',
#    'votingAtSlot': '08c9638e',
#    'votingCompletedAt': 1663029682,
#    'executionFlags': 0,
#    'maxVoteWeight': '53dd1dc0',
#    'voteThreshold': {'type': 0, 'value': 7},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'DqFPrmk1fCsXaRVeZM2A6RMEwg9YCaUeor5mH6HT8dpr',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 3,
#    'tokenOwnerRecord': '7qwMUcDoU8jvZimUugiUeH7fZoeEn5bHGAykSwBH57Qp',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'You can read more info on Discord :) You can also ask questions...',
#    'name': "''Sharks Bite Back Better'' update",
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '07365040',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '627ee48c',
#    'signingOffAt': '627ee4ce',
#    'votingAt': '627ee4ce',
#    'votingAtSlot': '07f80029',
#    'votingCompletedAt': 1652753924,
#    'executionFlags': 0,
#    'maxVoteWeight': '53dd1dc0',
#    'voteThreshold': {'type': 0, 'value': 7},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'FhpzEy8AMXwG3XoMqYRrNnmGkH4rDUEcucm1DTWoWPqh',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 6,
#    'tokenOwnerRecord': '36FpEMnFCvVwT1LRjaE8N7ttRDx2SL2YL91RmDQphrbA',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 0,
#    'descriptionLink': 'Sh',
#    'name': 'Sh',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '6261fc7d',
#    'closedAt': '6261fd05',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'HtgHyn1YZdQKN9nyLRfLQmH1C51wXewguFWvYDco3YRS',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 6,
#    'tokenOwnerRecord': '36FpEMnFCvVwT1LRjaE8N7ttRDx2SL2YL91RmDQphrbA',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Go to link to view proposal\nFunding request: 50 SOL\n\nhttps://discord.com/channels/886787538294026260/937841739971039342/966875503267033108',
#    'name': 'Shkare Back Better',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '6262b213',
#    'signingOffAt': '6262b213',
#    'votingAt': '6262b213',
#    'votingAtSlot': '07ccb6fc',
#    'closedAt': '6262b6e8',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'HxbsDahQhunGyJxvQQkfDXEZ8BSSxMLohq9ooVCsB5PL',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 3,
#    'tokenOwnerRecord': '36FpEMnFCvVwT1LRjaE8N7ttRDx2SL2YL91RmDQphrbA',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'A purchase and sell program for Shkary Sharks \nGo to link and read the proposal \nhttps://discord.com/channels/886787538294026260/937841739971039342/966875503267033108\nAnd VOTE!!',
#    'name': 'Shkare Back Better',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '07829b80',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '0f4240',
#    'reserved1': 0,
#    'draftAt': '6262eebb',
#    'signingOffAt': '6262eebb',
#    'votingAt': '6262eebb',
#    'votingAtSlot': '07cd1c2e',
#    'votingCompletedAt': 1650940975,
#    'executionFlags': 0,
#    'maxVoteWeight': '53dd1dc0',
#    'voteThreshold': {'type': 0, 'value': 7},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'HzN43ADQyJkr5gyCa5opyoixyZBphcJGLDi8UKHv424f',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 3,
#    'tokenOwnerRecord': 'DMjJZGoVLdoiskz8aNW3AWrBvFaZqBx1pZVoNxqDeQFy',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '20 SOL is needed for a weekly giveaway across 6-8 most likely. Please read the latest announcement in DAO Announcements for more info.',
#    'name': 'Weekly Traits Giveaway',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '08954400',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b07557',
#    'signingOffAt': '62b07559',
#    'votingAt': '62b07559',
#    'votingAtSlot': '083e38dc',
#    'votingCompletedAt': 1655993735,
#    'executionFlags': 0,
#    'maxVoteWeight': '53dd1dc0',
#    'voteThreshold': {'type': 0, 'value': 7},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'J4rPdEVaCKwbwZAzkiZasXAwh3XhYLLt1j8TQxbnGZiu',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 6,
#    'tokenOwnerRecord': '12g7fJGJka8BGGYmvCkEU5ezKHBjxSPGk41S3QP57yJY',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': '30 Sol Marketing Budget to support the mint of Shkary Scenes',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62ff8b0d',
#    'signingOffAt': '62ff8b10',
#    'votingAt': '62ff8b10',
#    'votingAtSlot': '08be43c7',
#    'closedAt': '63009e83',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': 'RwxrPLJBDyxkK4YXmVADdFXgvfoXq2Q5oGs1paPNvc2',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 6,
#    'tokenOwnerRecord': '36FpEMnFCvVwT1LRjaE8N7ttRDx2SL2YL91RmDQphrbA',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 0,
#    'descriptionLink': 'Copy/Paste link to read proposal\n\nFunding Request: 50SOL\n\nhttps://discord.com/channels/886787538294026260/937841739971039342/966875503267033108',
#    'name': 'Shkare Back Better',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '626207fa',
#    'closedAt': '6262b6c6',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': '4HVeuUcfJQENKZAQScrGqribDS36eaKemWdaHcDFCtfc',
#   'account': {'accountType': 14,
#    'governance': '52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573',
#    'governingTokenMint': 'F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh',
#    'state': 6,
#    'tokenOwnerRecord': '23DWoq5AQh1hnKRS4Dk4CRXHKofW2QcADP6YTbSEe79z',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'https://discord.com/channels/886787538294026260/937841739971039342/971540069167026196',
#    'name': 'Initiate easy utility program for CHOMPS - NFT raffle tickets',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '0f4240',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62743945',
#    'signingOffAt': '62743958',
#    'votingAt': '62743958',
#    'votingAtSlot': '07e7e5a3',
#    'closedAt': '6274455c',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A8qRHr5BuaEDtotz9Dp3nxDuoqPsNbksQDxHAxC5J6WB'},
#  {'pubkey': '7BA31zKajR1f7Fn2FLxtiXjFQQaLebvSdDXwjHngtsPX',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change governance config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afdcd0',
#    'signingOffAt': '62afdcd2',
#    'votingAt': '62afdcd2',
#    'votingAtSlot': '083d2a7f',
#    'closedAt': '62afdd25',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'BBV4Qkwx4g4LVWvcHDZbqySy4Wk4cmGfRwKeqWadjFGR',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'A proposal to elect the following for Finance Officer: \n@Cottonballs (48 votes) = YES\n@Killuavie (22 votes) = NO',
#    'name': 'Finance Officer Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '3d0900',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '1e8480',
#    'reserved1': 0,
#    'draftAt': '62b66bba',
#    'signingOffAt': '62b66bbe',
#    'votingAt': '62b66bbe',
#    'votingAtSlot': '08476807',
#    'closedAt': '62b748d0',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'CQScJP8aBqHF2yddGKG5w9GjD6qe3k4vkBN477QA4rGR',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 0,
#    'tokenOwnerRecord': '3sbgxyZ5sEMruY7bVr7GpHaMtv66UwUpgYTFWFnNmiyy',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 0,
#    'descriptionLink': '',
#    'name': 'Change realm config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afbd33',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'CUqhQc1qd2oJ5QpBu56GQ7rDscYWBGgo7q6wbsC4xreT',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': "A proposal to elect ',t' as Governance Officer!",
#    'name': 'Governance Officer Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '4c4b40',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b66b29',
#    'signingOffAt': '62b66b2e',
#    'votingAt': '62b66b2e',
#    'votingAtSlot': '0847672c',
#    'closedAt': '62b748ba',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'DEfrhqxXPKke3rzmg6hRMrokNhp4G91Ucossth9rgqvu',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 3,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': "A proposal to allocate (5-8%) of DAO funds solely towards SOL NFT investments of interest to the community. Will promote discussions in Discord and is a 'fun' community building exercise. ",
#    'name': 'Community Investment Allocations',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2bde7800',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '6acfc0',
#    'reserved1': 0,
#    'draftAt': '62afe597',
#    'signingOffAt': '62afe59c',
#    'votingAt': '62afe59c',
#    'votingAtSlot': '083d3a74',
#    'votingCompletedAt': 1655801871,
#    'executionFlags': 0,
#    'maxVoteWeight': '017a7d4f80',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'ETXfDrENdPkmA9vUKxNFyhAGTbEAST7BXoaaw7GroJ9C',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 3,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Official proposal to hold DIP-1 as the formal governance structure of Droid|DAO.',
#    'name': 'DroidDAO (DIP-1): Proposed DAO Governance',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2f9fc5c0',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afe19a',
#    'signingOffAt': '62afe19b',
#    'votingAt': '62afe19b',
#    'votingAtSlot': '083d330c',
#    'votingCompletedAt': 1655782023,
#    'executionFlags': 0,
#    'maxVoteWeight': '017a7d4f80',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'F8ccczMkPfCvx4JGEKSAUhgYzamLRc35MEBvMq7DqEVU',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Send Droid Capital to BhxzT…mHxc6',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b563e2',
#    'signingOffAt': '62b563e4',
#    'votingAt': '62b563e4',
#    'votingAtSlot': '0845e530',
#    'closedAt': '62b563fc',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'Gd459KLZ1m1c8GyxrjMp2YiDJWnRmLPn2L5nrNHsbGJ1',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'A vote to elect @Genio to Partnership Officer!',
#    'name': 'Partnership Officer Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '4c4b40',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b66c05',
#    'signingOffAt': '62b66c07',
#    'votingAt': '62b66c07',
#    'votingAtSlot': '08476876',
#    'closedAt': '62b748dc',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'HsUnTtZVwdKEVicMYbp8JKrfNma4VK5V2uzyZh4o7iJ3',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'A vote to elect the Marketing & Communications Officer!\n@ReFined (22 votes) = YES\n@Thzz (24 votes) = NO',
#    'name': 'Marketing & Communications Officer Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '03197500',
#    'reserved1': 0,
#    'draftAt': '62b66c98',
#    'signingOffAt': '62b66c9a',
#    'votingAt': '62b66c9a',
#    'votingAtSlot': '08476963',
#    'closedAt': '62b748ec',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'SRPYuA7EMr6JjeHJY4ugZntytVezxA5xLfUF6jcrULq',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'A proposal to elect @Dreak as Security Officer!',
#    'name': 'Security Officer Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2dc6c0',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b66c46',
#    'signingOffAt': '62b66c49',
#    'votingAt': '62b66c49',
#    'votingAtSlot': '084768e0',
#    'closedAt': '62b748fb',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '2Rm5UbDmPydPY8zMZBhECSkaR79tstu5W47tgRSUZXXu',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'A proposal to elect the (5) highest voted candidates to High Council position: \naDroid\niamDroid\nbentheape\nDollarDroid\nPaolo',
#    'name': 'High Council Members (5) Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '02349340',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b66ae8',
#    'signingOffAt': '62b66aea',
#    'votingAt': '62b66aea',
#    'votingAtSlot': '084766c7',
#    'closedAt': '62b748aa',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '3ASUzT3SWbfxLd7en1oXRGa7Xx8sVczruH6fR4tYCniy',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 3,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Proposal for 2 BTC to be purchased in 4 lots (DCA method over next few days/week or two). ',
#    'name': 'Purchase 2 Bitcoin (BTC) ',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2f443840',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afe7f3',
#    'signingOffAt': '62afe7f5',
#    'votingAt': '62afe7f5',
#    'votingAtSlot': '083d3eab',
#    'votingCompletedAt': 1655801832,
#    'executionFlags': 0,
#    'maxVoteWeight': '017a7d4f80',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '3McFQK687FwzjsL9kgdd6kFiHuAc69n8c5FgqJfvpvC6',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Test',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afd2ae',
#    'signingOffAt': '62afd2ae',
#    'votingAt': '62afd2ae',
#    'votingAtSlot': '083d1971',
#    'closedAt': '62afd36c',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '5xihFY98ZoGYoLFn5oEWf7NFTA5yRM8z8hHcbX6AYRxK',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 5,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Changing of DAO vote period from 1 day to 3 days',
#    'name': 'Change vote time to 3 days',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b7941b',
#    'signingOffAt': '62b7941c',
#    'votingAt': '62b7941c',
#    'votingAtSlot': '08492427',
#    'votingCompletedAt': 1656198273,
#    'executingAt': '62b794d2',
#    'closedAt': '62b794d2',
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'ARg54H5RSvoTxehM4jHGVETnxwqi4zGGFrYMvEhFy9Vm',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change realm config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afbee3',
#    'signingOffAt': '62afbee5',
#    'votingAt': '62afbee5',
#    'votingAtSlot': '083cf638',
#    'closedAt': '62afdc70',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'HazF6BXuDfAQQ5NV3M9yb57XHGfXZxKhXfYdUWiAfM1i',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 3,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change governance config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b6911f',
#    'signingOffAt': '62b69120',
#    'votingAt': '62b69120',
#    'votingAtSlot': '08479ff7',
#    'votingCompletedAt': 1656131899,
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'J7gXMw7L8pYZqKzeFx4LSbhV7Aw6sux6RBHefd9rijUd',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 5,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change governance config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afdd45',
#    'signingOffAt': '62afdd47',
#    'votingAt': '62afdd47',
#    'votingAtSlot': '083d2b4c',
#    'votingCompletedAt': 1655692962,
#    'executingAt': '62afe05f',
#    'closedAt': '62afe05f',
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'piF3cMjwq46XRCfu8jxayGwQyweL4JXTNgBhY3esFea',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 6,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Realms allows a single period for all votes. This is being changed to 3 days for the DAO election vote. ',
#    'name': 'Change Voting Time to 5 Days',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
# ...
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 7,
#    'tokenOwnerRecord': 'D7KvxgVc6o9mpWqJpA3tcGkZy6BX9YzkyEWqrDd59mCE',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Pay Statik for Sales Bot work from Exile DAO Treasury',
#    'yesVotesCount': '00',
#    'noVotesCount': '02',
#    'instructionsExecutedCount': 0,
#    'instructionsCount': 0,
#    'instructionsNextIndex': 0,
#    'draftAt': '62006535',
#    'signingOffAt': '62006535',
#    'votingAt': '62006535',
#    'votingAtSlot': '07222eb5',
#    'votingCompletedAt': 1644886944,
#    'executionFlags': 0,
#    'maxVoteWeight': '05',
#    'voteThreshold': {'type': 0, 'value': 60}},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': 'CBrrsg11MGgPkE9YiarhSkYbpMUotZ3qqJwcTwFMXnYR',
#   'account': {'accountType': 14,
#    'governance': '4tZaJsNgRAMAXMph51pzUCjDZAkgyvDMzdTyeGUWq22g',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 3,
#    'tokenOwnerRecord': '7tKZQQ8XPMUPKPj7paY5TPkTPC3mnm3pFVjBZrvvqcUD',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Proposal to convert 10 Sol to USDC in the Exiled DAO treasury. ',
#    'name': 'Sol to USDC coversion',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '03',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62360d74',
#    'signingOffAt': '62360d74',
#    'votingAt': '62360d74',
#    'votingAtSlot': '077e16f7',
#    'votingCompletedAt': 1647717683,
#    'executionFlags': 0,
#    'maxVoteWeight': '05',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': 'EG8g5EJfo34PEyrUcmn6u4ksSckR2ZwxEcDSEKrn6X71',
#   'account': {'accountType': 14,
#    'governance': '4tZaJsNgRAMAXMph51pzUCjDZAkgyvDMzdTyeGUWq22g',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 3,
#    'tokenOwnerRecord': '7tKZQQ8XPMUPKPj7paY5TPkTPC3mnm3pFVjBZrvvqcUD',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'The purpose of this proposal is to take record of Royalty and Entangler Fee distribution. \n\nExiled DAO - 22 SOL to : 4PC3jH8txRfFfa2n9AtuQMY3CZ2e3Bq8sbHEG784Zp6C\nMirc - 17.32 SOL to : \nFzba5Rx6zZHzeUs7XQxaBAxMYE55qaJ8ptrobSSuPzKk\nSanctuary 4.37 SOL to :\nGvTWhQCTeqrs8E3GMUCiaMgEgGte4BrcBXjVBNZ5wTjU',
#    'name': 'Entangler/Royalty Distribution',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '03',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62151d30',
#    'signingOffAt': '62151d30',
#    'votingAt': '62151d30',
#    'votingAtSlot': '0745c470',
#    'votingCompletedAt': 1645552054,
#    'executionFlags': 0,
#    'maxVoteWeight': '05',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': '5jzXab2pSYhi3iaY3z4aeSTDizVt7rURxqxgE6v4c9xs',
#   'account': {'accountType': 14,
#    'governance': 'BuHkEPonKAYWiqhtHDcAiAyjNKbfyshSVX7f8kygEaRo',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 0,
#    'tokenOwnerRecord': 'D1zHPLW1FDWRzP4NSbx44VRaqHuyFYDutUvGHb8Mkc5C',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 0,
#    'descriptionLink': 'Staking APY\n6.79%',
#    'name': '25 SOL to mSOL - Marinade Staking',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '6364be24',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': '7ubaSnppj5npwgEVgwYmc9vHUA5Wde8Te9pxmE3BxpMA',
#   'account': {'accountType': 14,
#    'governance': 'BuHkEPonKAYWiqhtHDcAiAyjNKbfyshSVX7f8kygEaRo',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 7,
#    'tokenOwnerRecord': 'D1zHPLW1FDWRzP4NSbx44VRaqHuyFYDutUvGHb8Mkc5C',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '2.57 = .28*9.19\n185.79 - 76.52(dan = joey return) = 109.27-100.08 (prior distribution balance) = 9.19\n',
#    'name': 'Pay 2.57 SOL royalty to Mirc',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 2,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '64b5ab89',
#    'signingOffAt': '64b5ab8a',
#    'votingAt': '64b5ab8a',
#    'votingAtSlot': '0c467a4d',
#    'votingCompletedAt': 1690039810,
#    'executionFlags': 0,
#    'maxVoteWeight': '05',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': '7zBMC3w7Y82V5Tco3Xx5YJtT2LYXY8phzS5RE2LYNLDT',
#   'account': {'accountType': 14,
#    'governance': 'BuHkEPonKAYWiqhtHDcAiAyjNKbfyshSVX7f8kygEaRo',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 5,
#    'tokenOwnerRecord': '7quaGPqNZQ45qYLESzVzCRDX7eCBUUCj3DYqipENbsLh',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'as approved by community vote in discord, sending 10sol to lyb.',
#    'name': 'Donation to Lybberty ',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '03',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62888202',
#    'signingOffAt': '62888207',
#    'votingAt': '62888207',
#    'votingAtSlot': '080625a4',
#    'votingCompletedAt': 1653154547,
#    'executingAt': '6289288f',
#    'closedAt': '6289288f',
#    'executionFlags': 0,
#    'maxVoteWeight': '05',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': '8RkhPsKo2NRkhLtdmR4BNo7vKhN8GGVNM2Q5R1yCsDBT',
#   'account': {'accountType': 14,
#    'governance': 'BuHkEPonKAYWiqhtHDcAiAyjNKbfyshSVX7f8kygEaRo',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 6,
#    'tokenOwnerRecord': 'D1zHPLW1FDWRzP4NSbx44VRaqHuyFYDutUvGHb8Mkc5C',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Convert 55 SOL to stSOL',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '636369de',
#    'signingOffAt': '636369df',
#    'votingAt': '636369df',
#    'votingAtSlot': '097a03de',
#    'closedAt': '63636d02',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': '9qwbcBu4unU2ciQPapbr3P8ReQo5RWJYNmzVccrChvuR',
#   'account': {'accountType': 14,
#    'governance': 'BuHkEPonKAYWiqhtHDcAiAyjNKbfyshSVX7f8kygEaRo',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 0,
#    'tokenOwnerRecord': 'D1zHPLW1FDWRzP4NSbx44VRaqHuyFYDutUvGHb8Mkc5C',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 0,
#    'descriptionLink': 'Have already sent 69,420 so total deposit is 169,420 ARTE for Achievements system cost of 500,000 ARTE',
#    'name': 'Send $ARTE to ArtPunk burn address as deposit for Achievements',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '6364d264',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': '9xdPEWJTt48z8jxY2iFASMdfYDk74gj8XsJyTLLzL1n2',
#   'account': {'accountType': 14,
#    'governance': 'BuHkEPonKAYWiqhtHDcAiAyjNKbfyshSVX7f8kygEaRo',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 5,
#    'tokenOwnerRecord': 'D1zHPLW1FDWRzP4NSbx44VRaqHuyFYDutUvGHb8Mkc5C',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Last distribution had acct value at 135 SOL. Current 166.2. \n\nMirc 8.74 = 31.2 * .28\nSanctuary 6.86 = 31.2 * .22\n\nhttps://app.realms.today/dao/$XAPE/proposal/ArQPqMc6LkQJj5dtCb72Y1x7wzKjJnyoaXD8vjCSoY3N\nhttps://explorer.solana.com/tx/3GQt7iny8rnumUNxUfqeXQhyQBruiYtgM5di6RceVrPCov6zZJpZxTVPcJ1cLBKGAS32ir39sqguXohsz4o38yXa',
#    'name': 'Distribute royalties to Mirc and Sanctuary',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '03',
#      'voteResult': 1,
#      'instructionsExecutedCount': 2,
#      'instructionsCount': 2,
#      'instructionsNextIndex': 2}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '6364ce8d',
#    'signingOffAt': '6364ce8f',
#    'votingAt': '6364ce8f',
#    'votingAtSlot': '097d2547',
#    'votingCompletedAt': 1667569118,
#    'executingAt': '63651e91',
#    'closedAt': '63651e91',
#    'executionFlags': 0,
#    'maxVoteWeight': '05',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': 'AEAnJBzWp5fqAWotfK1w2u7aneTFEXgtJT5nSHESzXzk',
#   'account': {'accountType': 14,
#    'governance': 'BuHkEPonKAYWiqhtHDcAiAyjNKbfyshSVX7f8kygEaRo',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 5,
#    'tokenOwnerRecord': '7tKZQQ8XPMUPKPj7paY5TPkTPC3mnm3pFVjBZrvvqcUD',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Sanctuary 1.91 to: GvTWhQCTeqrs8E3GMUCiaMgEgGte4BrcBXjVBNZ5wTjU',
#    'name': 'Entangler/Royalty Distribution',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '03',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '6239dfea',
#    'signingOffAt': '6239dfea',
#    'votingAt': '6239dfea',
#    'votingAtSlot': '0784eb06',
#    'votingCompletedAt': 1647966651,
#    'executingAt': '6239fdad',
#    'closedAt': '6239fdad',
#    'executionFlags': 0,
#    'maxVoteWeight': '05',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': 'ArQPqMc6LkQJj5dtCb72Y1x7wzKjJnyoaXD8vjCSoY3N',
#   'account': {'accountType': 14,
#    'governance': 'BuHkEPonKAYWiqhtHDcAiAyjNKbfyshSVX7f8kygEaRo',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 5,
#    'tokenOwnerRecord': '7quaGPqNZQ45qYLESzVzCRDX7eCBUUCj3DYqipENbsLh',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Based on whitepaper , distribute cut to Mirc and Sanctuary\nMirc - 8,21\nSanctuary - 3,6',
#    'name': 'Royalty distribution - april - july',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '03',
#      'voteResult': 1,
#      'instructionsExecutedCount': 2,
#      'instructionsCount': 2,
#      'instructionsNextIndex': 2}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62c933f0',
#    'signingOffAt': '62c933f2',
#    'votingAt': '62c933f2',
#    'votingAtSlot': '0864d218',
#    'votingCompletedAt': 1657553281,
#    'executingAt': '62cc419f',
#    'closedAt': '62cc419f',
#    'executionFlags': 0,
#    'maxVoteWeight': '05',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': 'BjkLQo8EkmpPx4887Pgr83s1b3Y2GeKoVLGKZqSLCKVq',
#   'account': {'accountType': 14,
#    'governance': 'BuHkEPonKAYWiqhtHDcAiAyjNKbfyshSVX7f8kygEaRo',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 5,
#    'tokenOwnerRecord': 'D1zHPLW1FDWRzP4NSbx44VRaqHuyFYDutUvGHb8Mkc5C',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': "Send 15 SOL to Thurgood's wallet for conversion to USDC and return to treasury",
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '03',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '64b446ed',
#    'signingOffAt': '64b446f0',
#    'votingAt': '64b446f0',
#    'votingAtSlot': '0c43610c',
#    'votingCompletedAt': 1689617867,
#    'executingAt': '64b588b1',
#    'closedAt': '64b588b1',
#    'executionFlags': 0,
#    'maxVoteWeight': '05',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  {'pubkey': 'CnTwK9BSMqP9idzN6jkQs8TRUKtzHVCCwnKqnWPExtVi',
#   'account': {'accountType': 14,
#    'governance': 'BuHkEPonKAYWiqhtHDcAiAyjNKbfyshSVX7f8kygEaRo',
#    'governingTokenMint': 'CxAPEcK5nhZx2bDgYhjY6sFbi9ddXPqLJN1LrYShH2A4',
#    'state': 5,
#    'tokenOwnerRecord': '7quaGPqNZQ45qYLESzVzCRDX7eCBUUCj3DYqipENbsLh',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'on 04/29 current amount within the treasury sits @ 174.32 , 20,98 of which is not yet distributed per WL specifications \nhttps://docs.google.com/spreadsheets/d/1bxLGsnQufIUyl2v9Po43pGFso5Ad5GQd\nSend  7,12Sol to Mirc,  send 3,26 to Sanctuary',
#    'name': 'Fund distribution april 29',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '03',
#      'voteResult': 1,
#      'instructionsExecutedCount': 2,
#      'instructionsCount': 2,
#      'instructionsNextIndex': 2}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '626c0b31',
#    'signingOffAt': '626c0b31',
#    'votingAt': '626c0b31',
#    'votingAtSlot': '07db72b6',
#    'votingCompletedAt': 1651253085,
#    'executingAt': '626c1fd0',
#    'closedAt': '626c1fd0',
#    'executionFlags': 0,
#    'maxVoteWeight': '05',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS',
#   'filename': 'Ghope52FuF6HU3AAhJuAAyS2fiqbVhkAotb7YprL5tdS_2J1YbWH991rv7ZAsUVdV2cWXNf89XNuhqUsabaAP3Hc1'},
#  ...]

# %%
len(json_list)
# Out:
# 11885

# %%
# read into df
df = pd.DataFrame(json_list)
df
# Out:
#                                              pubkey  \
# 0      GThdf6h1QFFNxBijUzCZRsnJP7JZY713koFTnyytxXMc
# 1      GM89o7QLfMcCvTC92dcg2oXFYm99RHeJ1qggFDzMwtDF
# 2      9NWj6RsHgTx19aqrrGQeTLdkE1kuD6X5Lhg8k91PkvfV
# 3       cEMSFTCQrDWAgENaXW5FLVCAe5vuDUxLvfDhUjVGMC4
# 4      2BEDW1goPvvU2a6ZxFqMGb3mop8DoGsWeBrcnupSE21q
# ...                                             ...
# 11880  4e2DGqJRbU6n2znd2shT9x4An4B3EzuDMsxWwDFKDQqs
# 11881  BKUbYdSwkYRQ9HnrxigZixtMDhUujREzpjHnCfw7nn7E
# 11882  HwLDejVp4KrZ1EMuxypFR7Ds9J1UkqnhRULMhe2VaMSb
# 11883   8HeBHe6f9UCabEstTg26xohY66yYjoG9WzmTFqmd1tj
# 11884  3dnAJchiJyheZtvFWQy9edkikdNgKDgxJSje4xjydQ4H
#
#                                                  account  \
# 0      {'accountType': 14, 'governance': '7qFBvR5SGe3...
# 1      {'accountType': 14, 'governance': '7qFBvR5SGe3...
# 2      {'accountType': 14, 'governance': '52DUBNBSvoW...
# 3      {'accountType': 14, 'governance': '52DUBNBSvoW...
# 4      {'accountType': 14, 'governance': '52DUBNBSvoW...
# ...                                                  ...
# 11880  {'accountType': 14, 'governance': 'DU3iHrA445z...
# 11881  {'accountType': 14, 'governance': 'GXMhSQEmfk4...
# 11882  {'accountType': 14, 'governance': 'GXMhSQEmfk4...
# 11883  {'accountType': 14, 'governance': 'GXMhSQEmfk4...
# 11884  {'accountType': 14, 'governance': 'GXMhSQEmfk4...
#
#                                               owner  \
# 0      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 1      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 2      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 3      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 4      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# ...                                             ...
# 11880  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 11881  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 11882  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 11883  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 11884  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
#
#                                                 filename
# 0      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 1      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 2      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 3      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 4      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# ...                                                  ...
# 11880  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 11881  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 11882  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 11883  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 11884  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
#
# [11885 rows x 4 columns]

# %%
# expand account column
df = pd.concat([df.drop(['account'], axis=1), df['account'].apply(pd.Series)], axis=1)
df
# Out:
#                                              pubkey  \
# 0      GThdf6h1QFFNxBijUzCZRsnJP7JZY713koFTnyytxXMc
# 1      GM89o7QLfMcCvTC92dcg2oXFYm99RHeJ1qggFDzMwtDF
# 2      9NWj6RsHgTx19aqrrGQeTLdkE1kuD6X5Lhg8k91PkvfV
# 3       cEMSFTCQrDWAgENaXW5FLVCAe5vuDUxLvfDhUjVGMC4
# 4      2BEDW1goPvvU2a6ZxFqMGb3mop8DoGsWeBrcnupSE21q
# ...                                             ...
# 11880  4e2DGqJRbU6n2znd2shT9x4An4B3EzuDMsxWwDFKDQqs
# 11881  BKUbYdSwkYRQ9HnrxigZixtMDhUujREzpjHnCfw7nn7E
# 11882  HwLDejVp4KrZ1EMuxypFR7Ds9J1UkqnhRULMhe2VaMSb
# 11883   8HeBHe6f9UCabEstTg26xohY66yYjoG9WzmTFqmd1tj
# 11884  3dnAJchiJyheZtvFWQy9edkikdNgKDgxJSje4xjydQ4H
#
#                                               owner  \
# 0      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 1      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 2      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 3      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 4      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# ...                                             ...
# 11880  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 11881  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 11882  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 11883  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 11884  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
#
#                                                 filename  accountType  \
# 0      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 1      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 2      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 3      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 4      GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# ...                                                  ...          ...
# 11880  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 11881  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 11882  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 11883  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 11884  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
#
#                                          governance  \
# 0      7qFBvR5SGe3GrifRBZjBZFdwidSX64G2kRQvgALfFBWY
# 1      7qFBvR5SGe3GrifRBZjBZFdwidSX64G2kRQvgALfFBWY
# 2      52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573
# 3      52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573
# 4      52DUBNBSvoW9eFkT37WxrGg2DWzU8zJMMDkseHs4L573
# ...                                             ...
# 11880  DU3iHrA445zpvEc3bLEfVWUJtNbbTM2aiLq9yih1BANe
# 11881  GXMhSQEmfk4CfK9Ae2U67aL84LDPCySJzscDhBTMY8hM
# 11882  GXMhSQEmfk4CfK9Ae2U67aL84LDPCySJzscDhBTMY8hM
# 11883  GXMhSQEmfk4CfK9Ae2U67aL84LDPCySJzscDhBTMY8hM
# 11884  GXMhSQEmfk4CfK9Ae2U67aL84LDPCySJzscDhBTMY8hM
#
#                                  governingTokenMint  state  \
# 0      86PBLBdCjj7R4maYw696Ftj168UZV4sp3VggQ3VFd2oR      5
# 1      F5gsWAdrPxBAP9kK2N1L9At6Bm2HApPwKWYu2Mq8cZXh      6
# 2      86PBLBdCjj7R4maYw696Ftj168UZV4sp3VggQ3VFd2oR      0
# 3      86PBLBdCjj7R4maYw696Ftj168UZV4sp3VggQ3VFd2oR      5
# 4      86PBLBdCjj7R4maYw696Ftj168UZV4sp3VggQ3VFd2oR      5
# ...                                             ...    ...
# 11880  5rXvJVnQicvcDdthygGLqvdmfETHDdS3FPWUeusEU6Wo      3
# 11881  5rXvJVnQicvcDdthygGLqvdmfETHDdS3FPWUeusEU6Wo      5
# 11882  5rXvJVnQicvcDdthygGLqvdmfETHDdS3FPWUeusEU6Wo      3
# 11883  5rXvJVnQicvcDdthygGLqvdmfETHDdS3FPWUeusEU6Wo      3
# 11884  5rXvJVnQicvcDdthygGLqvdmfETHDdS3FPWUeusEU6Wo      7
#
#                                    tokenOwnerRecord  signatoriesCount  \
# 0      12g7fJGJka8BGGYmvCkEU5ezKHBjxSPGk41S3QP57yJY                 1
# 1      12g7fJGJka8BGGYmvCkEU5ezKHBjxSPGk41S3QP57yJY                 1
# 2      HmLRS3bTH7PBsK5mvcEcR6Neh4Qp847xbsH5i5fbeJ3M                 1
# 3      EbXQD3FZCPAM1uAWKaQgepxMy9EJjPoBvfSDM9XaPxy5                 1
# 4      HmLRS3bTH7PBsK5mvcEcR6Neh4Qp847xbsH5i5fbeJ3M                 1
# ...                                             ...               ...
# 11880  FhJ9siUV3xbp8fybXTDhC2WtLedTdrz6WY86KkYS3YZ2                 1
# 11881  FhJ9siUV3xbp8fybXTDhC2WtLedTdrz6WY86KkYS3YZ2                 1
# 11882  42Si1ZXKKjGgwmfnRpj6TnYL8NyzbGPJvqeg9JyQJZRo                 1
# 11883  FhJ9siUV3xbp8fybXTDhC2WtLedTdrz6WY86KkYS3YZ2                 1
# 11884  FhJ9siUV3xbp8fybXTDhC2WtLedTdrz6WY86KkYS3YZ2                 1
#
#        signatoriesSignedOffCount  ...  closedAt executionFlags maxVoteWeight  \
# 0                              1  ...  625f2363              0            01
# 1                              1  ...  62ff8aba              0           NaN
# 2                              0  ...       NaN              0           NaN
# 3                              1  ...  6262f48b              0            02
# 4                              1  ...  625f28f9              0            02
# ...                          ...  ...       ...            ...           ...
# 11880                          1  ...       NaN              0            02
# 11881                          1  ...  62fd1b36              0            02
# 11882                          1  ...       NaN              0            02
# 11883                          1  ...       NaN              0            02
# 11884                          1  ...       NaN              0            02
#
#                   voteThreshold vetoVoteWeight  yesVotesCount noVotesCount  \
# 0      {'type': 0, 'value': 51}             00            NaN          NaN
# 1                           NaN             00            NaN          NaN
# 2                           NaN             00            NaN          NaN
# 3      {'type': 0, 'value': 51}             00            NaN          NaN
# 4      {'type': 0, 'value': 51}             00            NaN          NaN
# ...                         ...            ...            ...          ...
# 11880  {'type': 0, 'value': 18}             00            NaN          NaN
# 11881   {'type': 0, 'value': 5}             00            NaN          NaN
# 11882   {'type': 0, 'value': 9}             00            NaN          NaN
# 11883   {'type': 0, 'value': 9}             00            NaN          NaN
# 11884   {'type': 0, 'value': 5}             00            NaN          NaN
#
#       instructionsExecutedCount instructionsCount instructionsNextIndex
# 0                           NaN               NaN                   NaN
# 1                           NaN               NaN                   NaN
# 2                           NaN               NaN                   NaN
# 3                           NaN               NaN                   NaN
# 4                           NaN               NaN                   NaN
# ...                         ...               ...                   ...
# 11880                       NaN               NaN                   NaN
# 11881                       NaN               NaN                   NaN
# 11882                       NaN               NaN                   NaN
# 11883                       NaN               NaN                   NaN
# 11884                       NaN               NaN                   NaN
#
# [11885 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['pubkey', 'owner', 'filename', 'accountType', 'governance',
#        'governingTokenMint', 'state', 'tokenOwnerRecord', 'signatoriesCount',
#        'signatoriesSignedOffCount', 'descriptionLink', 'name', 'voteType',
#        'options', 'denyVoteWeight', 'reserved1', 'draftAt', 'signingOffAt',
#        'votingAt', 'votingAtSlot', 'votingCompletedAt', 'executingAt',
#        'closedAt', 'executionFlags', 'maxVoteWeight', 'voteThreshold',
#        'vetoVoteWeight', 'yesVotesCount', 'noVotesCount',
#        'instructionsExecutedCount', 'instructionsCount',
#        'instructionsNextIndex'],
#       dtype='object')

# %%
# how many proposals are there?
len(df)
# Out:
# 11885

# %%
# how many null votingCompletedAt are there?
len(df[df['votingCompletedAt'].isnull()])
# Out:
# 2334

# %%
# keep only proposals where voting has finished
df = df[df['votingCompletedAt'].notnull()]
len(df)
# Out:
# 9551

# %%
df = df[['pubkey', 'filename', 'votingCompletedAt']]

# %%
df.head()
# Out:
#                                          pubkey  \
# 0  GThdf6h1QFFNxBijUzCZRsnJP7JZY713koFTnyytxXMc
# 3   cEMSFTCQrDWAgENaXW5FLVCAe5vuDUxLvfDhUjVGMC4
# 4  2BEDW1goPvvU2a6ZxFqMGb3mop8DoGsWeBrcnupSE21q
# 5  3Y8tExvaJC7rSLU6CRjFcFiPH4AAGabAPMXyc4kmTeHD
# 6  3tjQLkKw7K5Q94ke3usGiSAQvgkYdwqDSPuMzsq7VLg5
#
#                                             filename  votingCompletedAt
# 0  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...       1.650402e+09
# 3  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...       1.650650e+09
# 4  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...       1.650403e+09
# 5  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...       1.650404e+09
# 6  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...       1.650411e+09

# %%
# remove 'realms_proposals_' from beginning of filename
df['filename'] = df['filename'].str.replace(r'^realm_proposals_', '')
df.head()
# Out:
# /var/folders/yn/b6240_995k3gl4vwtnbzzy480000gq/T/ipykernel_85598/2761627738.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['filename'] = df['filename'].str.replace(r'^realm_proposals_', '')
#                                          pubkey  \
# 0  GThdf6h1QFFNxBijUzCZRsnJP7JZY713koFTnyytxXMc
# 3   cEMSFTCQrDWAgENaXW5FLVCAe5vuDUxLvfDhUjVGMC4
# 4  2BEDW1goPvvU2a6ZxFqMGb3mop8DoGsWeBrcnupSE21q
# 5  3Y8tExvaJC7rSLU6CRjFcFiPH4AAGabAPMXyc4kmTeHD
# 6  3tjQLkKw7K5Q94ke3usGiSAQvgkYdwqDSPuMzsq7VLg5
#
#                                             filename  votingCompletedAt
# 0  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...       1.650402e+09
# 3  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...       1.650650e+09
# 4  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...       1.650403e+09
# 5  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...       1.650404e+09
# 6  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...       1.650411e+09

# %%
# * platform
# add platform column = 'realms'
df['platform'] = 'realms'
# * platform_deployment_id
# rename governance to platform_deployment_id
df = df.rename(columns={'filename': 'platform_deployment_id'})
# * proposal_id
# rename pubkey to proposal_id
df = df.rename(columns={'pubkey': 'proposal_id'})
# * author
df['author'] = None # FIXME: pull this
# * date -- this should be as a pandas date, not as an epoch
# rename voting completed at to date
df = df.rename(columns={'votingCompletedAt': 'date'})
# convert date to pandas date
df['date'] = pd.to_datetime(df['date'], unit='s')
# * votes_count
# make votes_count column nulls
df['votes_count'] = None
df.head()
# Out:
#                                     proposal_id  \
# 0  GThdf6h1QFFNxBijUzCZRsnJP7JZY713koFTnyytxXMc
# 3   cEMSFTCQrDWAgENaXW5FLVCAe5vuDUxLvfDhUjVGMC4
# 4  2BEDW1goPvvU2a6ZxFqMGb3mop8DoGsWeBrcnupSE21q
# 5  3Y8tExvaJC7rSLU6CRjFcFiPH4AAGabAPMXyc4kmTeHD
# 6  3tjQLkKw7K5Q94ke3usGiSAQvgkYdwqDSPuMzsq7VLg5
#
#                               platform_deployment_id                date  \
# 0  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A... 2022-04-19 20:59:11
# 3  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A... 2022-04-22 17:54:06
# 4  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A... 2022-04-19 21:20:08
# 5  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A... 2022-04-19 21:35:47
# 6  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A... 2022-04-19 23:34:37
#
#   platform author votes_count
# 0   realms   None        None
# 3   realms   None        None
# 4   realms   None        None
# 5   realms   None        None
# 6   realms   None        None

# %%
# reordenar columnas: platform, platform_deployment_id, proposal_id, author, date, votes_count
df = df[['platform', 'platform_deployment_id', 'proposal_id', 'author', 'date', 'votes_count']]

# %%
# let's save a list of all of the platform_deployment_ids to a json file to be used by the downloadVotes js script
proposal_ids = df['proposal_id'].unique().tolist()
with open('proposal_ids.json', 'w') as f:
    json.dump(proposal_ids, f)

# %%
# guardar como realms_proposals.csv
df.to_csv('realms_proposals.csv', index=False)

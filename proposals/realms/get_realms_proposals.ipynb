# %% [markdown]
# We'll used the downloaded data from node to output a proposals csv

# %%
import os
REALMS_NODE_DIR = '../../realms_node'
REALMS_NODE_DATA_DIR = os.path.join(REALMS_NODE_DIR, 'output_proposals_2023_8_3')

# %%
# read all of the jsons in the directory, set the filename as a column
# and concat them all together
import glob
import pandas as pd
import json

jsons = glob.glob(os.path.join(REALMS_NODE_DATA_DIR, '*proposals.json'))

# read all the jsons into a flattened list
json_list = []
for json_file in jsons:
    with open(json_file, 'r') as f:
        read_json = json.load(f)
        # these files are a list of lists of dicts, so flatten them
        # if this is an empty list, skip
        if len(read_json) == 0:
            continue
        # if this is a list of dicts, flatten it
        if type(read_json[0]) == dict:
            read_json = [read_json]
        if type(read_json) != list:
            print(read_json)
        # for all objects in the list, set the filename as a key
        for obj in read_json:
            for i in obj:
                i['filename'] = os.path.basename(json_file)
                # replace _proposals.json at end with ''
                i['filename'] = i['filename'].replace('_proposals.json', '')
        json_list.extend(read_json)

# %%
# remove empty lists from the json_list
json_list = [x for x in json_list if x != []]
# make json_list a 1d list instead of a list of lists
json_list = [item for sublist in json_list for item in sublist]
json_list
# Out:
# [{'pubkey': '7BA31zKajR1f7Fn2FLxtiXjFQQaLebvSdDXwjHngtsPX',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change governance config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afdcd0',
#    'signingOffAt': '62afdcd2',
#    'votingAt': '62afdcd2',
#    'votingAtSlot': '083d2a7f',
#    'closedAt': '62afdd25',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'BBV4Qkwx4g4LVWvcHDZbqySy4Wk4cmGfRwKeqWadjFGR',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'A proposal to elect the following for Finance Officer: \n@Cottonballs (48 votes) = YES\n@Killuavie (22 votes) = NO',
#    'name': 'Finance Officer Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '3d0900',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '1e8480',
#    'reserved1': 0,
#    'draftAt': '62b66bba',
#    'signingOffAt': '62b66bbe',
#    'votingAt': '62b66bbe',
#    'votingAtSlot': '08476807',
#    'closedAt': '62b748d0',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'CQScJP8aBqHF2yddGKG5w9GjD6qe3k4vkBN477QA4rGR',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 0,
#    'tokenOwnerRecord': '3sbgxyZ5sEMruY7bVr7GpHaMtv66UwUpgYTFWFnNmiyy',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 0,
#    'descriptionLink': '',
#    'name': 'Change realm config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afbd33',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'CUqhQc1qd2oJ5QpBu56GQ7rDscYWBGgo7q6wbsC4xreT',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': "A proposal to elect ',t' as Governance Officer!",
#    'name': 'Governance Officer Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '4c4b40',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b66b29',
#    'signingOffAt': '62b66b2e',
#    'votingAt': '62b66b2e',
#    'votingAtSlot': '0847672c',
#    'closedAt': '62b748ba',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'DEfrhqxXPKke3rzmg6hRMrokNhp4G91Ucossth9rgqvu',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 3,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': "A proposal to allocate (5-8%) of DAO funds solely towards SOL NFT investments of interest to the community. Will promote discussions in Discord and is a 'fun' community building exercise. ",
#    'name': 'Community Investment Allocations',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2bde7800',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '6acfc0',
#    'reserved1': 0,
#    'draftAt': '62afe597',
#    'signingOffAt': '62afe59c',
#    'votingAt': '62afe59c',
#    'votingAtSlot': '083d3a74',
#    'votingCompletedAt': 1655801871,
#    'executionFlags': 0,
#    'maxVoteWeight': '017a7d4f80',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'ETXfDrENdPkmA9vUKxNFyhAGTbEAST7BXoaaw7GroJ9C',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 3,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Official proposal to hold DIP-1 as the formal governance structure of Droid|DAO.',
#    'name': 'DroidDAO (DIP-1): Proposed DAO Governance',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2f9fc5c0',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afe19a',
#    'signingOffAt': '62afe19b',
#    'votingAt': '62afe19b',
#    'votingAtSlot': '083d330c',
#    'votingCompletedAt': 1655782023,
#    'executionFlags': 0,
#    'maxVoteWeight': '017a7d4f80',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'F8ccczMkPfCvx4JGEKSAUhgYzamLRc35MEBvMq7DqEVU',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Send Droid Capital to BhxzT…mHxc6',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b563e2',
#    'signingOffAt': '62b563e4',
#    'votingAt': '62b563e4',
#    'votingAtSlot': '0845e530',
#    'closedAt': '62b563fc',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'Gd459KLZ1m1c8GyxrjMp2YiDJWnRmLPn2L5nrNHsbGJ1',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'A vote to elect @Genio to Partnership Officer!',
#    'name': 'Partnership Officer Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '4c4b40',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b66c05',
#    'signingOffAt': '62b66c07',
#    'votingAt': '62b66c07',
#    'votingAtSlot': '08476876',
#    'closedAt': '62b748dc',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'HsUnTtZVwdKEVicMYbp8JKrfNma4VK5V2uzyZh4o7iJ3',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'A vote to elect the Marketing & Communications Officer!\n@ReFined (22 votes) = YES\n@Thzz (24 votes) = NO',
#    'name': 'Marketing & Communications Officer Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '03197500',
#    'reserved1': 0,
#    'draftAt': '62b66c98',
#    'signingOffAt': '62b66c9a',
#    'votingAt': '62b66c9a',
#    'votingAtSlot': '08476963',
#    'closedAt': '62b748ec',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'SRPYuA7EMr6JjeHJY4ugZntytVezxA5xLfUF6jcrULq',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'A proposal to elect @Dreak as Security Officer!',
#    'name': 'Security Officer Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2dc6c0',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b66c46',
#    'signingOffAt': '62b66c49',
#    'votingAt': '62b66c49',
#    'votingAtSlot': '084768e0',
#    'closedAt': '62b748fb',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '2Rm5UbDmPydPY8zMZBhECSkaR79tstu5W47tgRSUZXXu',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'A proposal to elect the (5) highest voted candidates to High Council position: \naDroid\niamDroid\nbentheape\nDollarDroid\nPaolo',
#    'name': 'High Council Members (5) Vote',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '02349340',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b66ae8',
#    'signingOffAt': '62b66aea',
#    'votingAt': '62b66aea',
#    'votingAtSlot': '084766c7',
#    'closedAt': '62b748aa',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '3ASUzT3SWbfxLd7en1oXRGa7Xx8sVczruH6fR4tYCniy',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 3,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Proposal for 2 BTC to be purchased in 4 lots (DCA method over next few days/week or two). ',
#    'name': 'Purchase 2 Bitcoin (BTC) ',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2f443840',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afe7f3',
#    'signingOffAt': '62afe7f5',
#    'votingAt': '62afe7f5',
#    'votingAtSlot': '083d3eab',
#    'votingCompletedAt': 1655801832,
#    'executionFlags': 0,
#    'maxVoteWeight': '017a7d4f80',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '3McFQK687FwzjsL9kgdd6kFiHuAc69n8c5FgqJfvpvC6',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Test',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afd2ae',
#    'signingOffAt': '62afd2ae',
#    'votingAt': '62afd2ae',
#    'votingAtSlot': '083d1971',
#    'closedAt': '62afd36c',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '5xihFY98ZoGYoLFn5oEWf7NFTA5yRM8z8hHcbX6AYRxK',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 5,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Changing of DAO vote period from 1 day to 3 days',
#    'name': 'Change vote time to 3 days',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b7941b',
#    'signingOffAt': '62b7941c',
#    'votingAt': '62b7941c',
#    'votingAtSlot': '08492427',
#    'votingCompletedAt': 1656198273,
#    'executingAt': '62b794d2',
#    'closedAt': '62b794d2',
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'ARg54H5RSvoTxehM4jHGVETnxwqi4zGGFrYMvEhFy9Vm',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change realm config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afbee3',
#    'signingOffAt': '62afbee5',
#    'votingAt': '62afbee5',
#    'votingAtSlot': '083cf638',
#    'closedAt': '62afdc70',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'HazF6BXuDfAQQ5NV3M9yb57XHGfXZxKhXfYdUWiAfM1i',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 3,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change governance config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b6911f',
#    'signingOffAt': '62b69120',
#    'votingAt': '62b69120',
#    'votingAtSlot': '08479ff7',
#    'votingCompletedAt': 1656131899,
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'J7gXMw7L8pYZqKzeFx4LSbhV7Aw6sux6RBHefd9rijUd',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 5,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change governance config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afdd45',
#    'signingOffAt': '62afdd47',
#    'votingAt': '62afdd47',
#    'votingAtSlot': '083d2b4c',
#    'votingCompletedAt': 1655692962,
#    'executingAt': '62afe05f',
#    'closedAt': '62afe05f',
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'piF3cMjwq46XRCfu8jxayGwQyweL4JXTNgBhY3esFea',
#   'account': {'accountType': 14,
#    'governance': '8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 6,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Realms allows a single period for all votes. This is being changed to 3 days for the DAO election vote. ',
#    'name': 'Change Voting Time to 5 Days',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b56116',
#    'signingOffAt': '62b56119',
#    'votingAt': '62b56119',
#    'votingAtSlot': '0845e0cc',
#    'closedAt': '62b5669f',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '6CyVf3ZFgEJZikYD8kVbs29HV97Y9hHucWRikjvRLBgW',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Snak3LM 🐍 the Detective = VOTE YES\ngodsofgod = VOTE NO',
#    'name': 'Head Alpha Caller - Non-Core Investments',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b7997e',
#    'signingOffAt': '62b79981',
#    'votingAt': '62b79981',
#    'votingAtSlot': '08492c30',
#    'closedAt': '62b79995',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '8o23qPK2uoQJJjL9FCkSLbToMb3JGnuKHs2zPvz4jSCA',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 7,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '@Snak3LM 🐍 the Detective = Vote YES   |---|  @godsofgod = Vote NO',
#    'name': 'Head Alpha Caller - Non-Core Investments (ie. NFTs for Community Wallet)',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '02719c40',
#      'voteResult': 2,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '11f0e540',
#    'reserved1': 0,
#    'draftAt': '62b79aa1',
#    'signingOffAt': '62b79aa1',
#    'votingAt': '62b79aa1',
#    'votingAtSlot': '08492dcb',
#    'votingCompletedAt': 1656463864,
#    'executionFlags': 0,
#    'maxVoteWeight': '017a7d4f80',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '9GmfSDFnXHsQhHBCVBeoqDtcnmif97iRM5RB35nhtcUM',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 7,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Do you approve the High Council 5 to consist of the following members: @iAmDroid, @aDroid, @benthebape, @DollarDroid, @paolo',
#    'name': 'Confirm High Council Members (5)',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '13221240',
#      'voteResult': 2,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b79b9f',
#    'signingOffAt': '62b79b9f',
#    'votingAt': '62b79b9f',
#    'votingAtSlot': '08492f40',
#    'votingCompletedAt': 1656463867,
#    'executionFlags': 0,
#    'maxVoteWeight': '017a7d4f80',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '9NcsLF5nqDoNGGJJmF15of4AnYVUZhWev1ntdAh8RiFT',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 7,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '@DAF {satori} 🤯  = Vote YES   |------| @r2shotme🎭  = Vote NO   |------| This is a vote for the "lead" - the \'division\' will still operate as a team',
#    'name': 'Head of Marketing & Communications',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01ba8140',
#      'voteResult': 2,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '0b2564c0',
#    'reserved1': 0,
#    'draftAt': '62b79dc8',
#    'signingOffAt': '62b79dca',
#    'votingAt': '62b79dca',
#    'votingAtSlot': '0849327c',
#    'votingCompletedAt': 1656463864,
#    'executionFlags': 0,
#    'maxVoteWeight': '017a7d4f80',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '9Yeso2W2TQkQSAxvDY6ip2qJ5eoWsHEAUDDgjWyp6asg',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change governance config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b6723b',
#    'signingOffAt': '62b6723f',
#    'votingAt': '62b6723f',
#    'votingAtSlot': '084771a9',
#    'closedAt': '62b6726a',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'BBfmkCosZW6z1QtqVnSa7AXBK5STPguRYXWvJnpztf3u',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'test for timing',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b6918e',
#    'signingOffAt': '62b69190',
#    'votingAt': '62b69190',
#    'votingAtSlot': '0847a0a8',
#    'closedAt': '62b691a3',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'Bnyyk6e7ZktjA1rsoyqf72ViTqcdd6rBT8myXeRzc91v',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 7,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '@killuavie = Vote YES   |------| @Cottonballs = Vote NO\nThis is a vote for the "lead" - the \'division\' will still operate as a team',
#    'name': 'Head of Finance / Treasury',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '0ca2dd00',
#      'voteResult': 2,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '06acfc00',
#    'reserved1': 0,
#    'draftAt': '62b79d4e',
#    'signingOffAt': '62b79d50',
#    'votingAt': '62b79d50',
#    'votingAtSlot': '084931c0',
#    'votingCompletedAt': 1656463864,
#    'executionFlags': 0,
#    'maxVoteWeight': '017a7d4f80',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'Br4dgs4d23i3qg7DLvZdAtZadY1Eue9S9TuokDxagQhj',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': 'DAnFF22TX1yWvbbJ4rEx5uCmTAatRYLpTsvecfT3XETZ',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'We need to change the voting time to 5 days in order to provide enough time for people to vote',
#    'name': 'Change voting time to 5 days',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b69001',
#    'signingOffAt': '62b69002',
#    'votingAt': '62b69002',
#    'votingAtSlot': '08479e41',
#    'closedAt': '62b690c4',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'EnWvs1EM9z1HAZrSDB3y8mSWirHQVFhCWtzBpGdBvu2c',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change governance config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afddeb',
#    'signingOffAt': '62afdded',
#    'votingAt': '62afdded',
#    'votingAtSlot': '083d2c6f',
#    'closedAt': '62afde23',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '2agXyMHYm6bvJazxLAHX7nD6gvsTcZNMZe2FTqjpkWJ9',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz',
#    'state': 6,
#    'tokenOwnerRecord': 'DAnFF22TX1yWvbbJ4rEx5uCmTAatRYLpTsvecfT3XETZ',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'T1',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '00',
#      'voteResult': 0,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b918e1',
#    'signingOffAt': '62b918e6',
#    'votingAt': '62b918e6',
#    'votingAtSlot': '084bb99f',
#    'closedAt': '62b91b74',
#    'executionFlags': 0,
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '5dLeXnfhK9Ke1SeUY77GW1ceq9LY9kjdRRmGAWVGaKhh',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 3,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change governance config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b67292',
#    'signingOffAt': '62b67294',
#    'votingAt': '62b67294',
#    'votingAtSlot': '0847722d',
#    'votingCompletedAt': 1656124071,
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '7W1WkCV8D6pTpEbKiGc1Eaiyg4muhrcbP26RNKSwdFFH',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 3,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'No alternative candidate applied. Dreak is approved unopposed',
#    'name': 'Confirm @Dreak as Head of Security',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b79b03',
#    'signingOffAt': '62b79b04',
#    'votingAt': '62b79b04',
#    'votingAtSlot': '08492e58',
#    'votingCompletedAt': 1656200318,
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '8aEJiLsDELefNjrZcM6CvRv1XiNUz5HmQZyVwyeskfrG',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 5,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Changing of DAO vote period from 1 day to 3 days',
#    'name': 'Change voting time to 3 days',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b7944c',
#    'signingOffAt': '62b7944d',
#    'votingAt': '62b7944d',
#    'votingAtSlot': '08492478',
#    'votingCompletedAt': 1656198250,
#    'executingAt': '62b794fd',
#    'closedAt': '62b794fd',
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'FS3f7PNmTUpdFDHG1nn3NBBXUFzcjJPUdpHBXHyNQvJA',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 5,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change governance config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62afde65',
#    'signingOffAt': '62afde66',
#    'votingAt': '62afde66',
#    'votingAtSlot': '083d2d25',
#    'votingCompletedAt': 1655692990,
#    'executingAt': '62afe049',
#    'closedAt': '62afe049',
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'GMm4frQacfEhMxzS4B6R61WkGySSYRmbXyzFEoPncjwV',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 3,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change governance config',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b67312',
#    'signingOffAt': '62b67313',
#    'votingAt': '62b67313',
#    'votingAtSlot': '084772e7',
#    'votingCompletedAt': 1656124225,
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'GZGHRTtb1eq3Cc1Avm8CBJ27eiQoSqpviuukihzk3kAb',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 3,
#    'tokenOwnerRecord': '4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Change voting time',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b5b2ca',
#    'signingOffAt': '62b5b2cd',
#    'votingAt': '62b5b2cd',
#    'votingAtSlot': '08465a0c',
#    'votingCompletedAt': 1656117067,
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': 'GZLJfvoEZddQq7AwVR8kAP5Nbq9kLiHmqgwxREDnRhnE',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 3,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'No alternative candidate applied. Thzz is approved unopposed',
#    'name': 'Confirm @Thzz as Head of Research, Analysis & Content',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b79efd',
#    'signingOffAt': '62b79eff',
#    'votingAt': '62b79eff',
#    'votingAtSlot': '0849344f',
#    'votingCompletedAt': 1656200974,
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '2TMg9AZhSv1DqtZn96dWKnmVhjwUBf12pzSNDNf9Z1fK',
#   'account': {'accountType': 14,
#    'governance': 'HesqcR4XZyHWtdHiUuNxr7dKQqepK5pFgkHTxbJW6Ewj',
#    'governingTokenMint': 'DQ8VRfxtdfJop8YqZ51VFrEszcaiqCYX8nFBuknfRxvn',
#    'state': 3,
#    'tokenOwnerRecord': '83qxnDfNMLwbAjhmEKPDiBjNjpA3T81bQPPiGfxn5KvX',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'No alternative candidate applied. Genio is approved unopposed',
#    'name': 'Confirm @Genio as Head of Partnerships',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '62b79c3b',
#    'signingOffAt': '62b79c3d',
#    'votingAt': '62b79c3d',
#    'votingAtSlot': '08493028',
#    'votingCompletedAt': 1656200272,
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 10},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9LY3wA9g4nAG8RhgSMeVaDU8MNF261ZuUnJFDExaEn15'},
#  {'pubkey': '5BPSuS7c6qoBxpYcrN56PpEwzPJ9u6EmtAYv7DwD426D',
#   'account': {'accountType': 5,
#    'governance': 'Far1N3T6enWpHcTPGfdarTYJa2UaQ2K1tXNkKEqg6cRx',
#    'governingTokenMint': '5VCziTqqCECncjZJFLVGNGU7LFUbPtJpU5Lswv7v2Cj',
#    'state': 6,
#    'tokenOwnerRecord': 'FeAYZw76DS58BpASMzmNoz6ESpQwN4XyvxVS2g6Cgy9h',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'testing proposal',
#    'name': 'test1',
#    'yesVotesCount': 'a88a39',
#    'noVotesCount': '00',
#    'instructionsExecutedCount': 0,
#    'instructionsCount': 0,
#    'instructionsNextIndex': 0,
#    'draftAt': '61e7eb85',
#    'signingOffAt': '61e7eb85',
#    'votingAt': '61e7eb85',
#    'votingAtSlot': '06f82d2d',
#    'closedAt': '61e7ebec',
#    'executionFlags': 0},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_UBWNtt8r6YVdh2tR3KQ1k4yGyY45wWTfCUFR8vwPpFc'},
#  {'pubkey': '7hUDcfdqgavXP8acZxFCJarc5rGNv3XR8Vk12wEHZa1w',
#   'account': {'accountType': 5,
#    'governance': 'Far1N3T6enWpHcTPGfdarTYJa2UaQ2K1tXNkKEqg6cRx',
#    'governingTokenMint': '5VCziTqqCECncjZJFLVGNGU7LFUbPtJpU5Lswv7v2Cj',
#    'state': 6,
#    'tokenOwnerRecord': 'FeAYZw76DS58BpASMzmNoz6ESpQwN4XyvxVS2g6Cgy9h',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'second test',
#    'name': 'test2',
#    'yesVotesCount': '00',
#    'noVotesCount': '00',
#    'instructionsExecutedCount': 0,
#    'instructionsCount': 0,
#    'instructionsNextIndex': 0,
#    'draftAt': '61e81887',
#    'signingOffAt': '61e81887',
#    'votingAt': '61e81887',
#    'votingAtSlot': '06f874e8',
#    'closedAt': '61e81b6e',
#    'executionFlags': 0},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_UBWNtt8r6YVdh2tR3KQ1k4yGyY45wWTfCUFR8vwPpFc'},
#  {'pubkey': '56mrKNjDPQfvpGmpEJL9asKXg6gKcMJCRwyjZefBzHjq',
#   'account': {'accountType': 14,
#    'governance': 'AeKqCf2tjJQkPbc3d4VLWJCB3R1Rg3GXGhkG3C6ShwUY',
#    'governingTokenMint': 'G65Vi5JMRFUBiWkDq8DY1UrEcYeYeLEzxtpp1QGtfBqY',
#    'state': 3,
#    'tokenOwnerRecord': 'DvzYbLkvJvewFPETxKaBJ92nWdVhyihZXKKK6K93sM1n',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Add council member 23fr3…Pu66S',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '626056f6',
#    'signingOffAt': '626056f6',
#    'votingAt': '626056f6',
#    'votingAtSlot': '07c8b69e',
#    'votingCompletedAt': 1650480920,
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_AcLZFArjSvUzm8BcRqKTg6yZ8cCKtLc2VNgkogmpbTAs'},
#  {'pubkey': '6Zi5BJ6vPbienBJzmJG8vwviWKMxnJdgDAK7mJQgkFvG',
#   'account': {'accountType': 14,
#    'governance': '7CAVGhrhqPD3CdDRAfSeQtfSSv2apczfN9T9xZQasZRN',
#    'governingTokenMint': 'HfWBJGKE6XPXd9vzayip9mYh9jqHWgLayL3GD3DQ92Pp',
#    'state': 5,
#    'tokenOwnerRecord': 'DCzK6A1nkno3t1id4u2V9xa59t7ypfuczwodJs1DyUT9',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Add mod',
#    'name': 'Add council member CZyv4…PuRLE',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '64c2d26f',
#    'signingOffAt': '64c2d270',
#    'votingAt': '64c2d270',
#    'votingAtSlot': '0c64003f',
#    'votingCompletedAt': 1690489533,
#    'executingAt': '64c2d3c5',
#    'closedAt': '64c2d3c5',
#    'executionFlags': 0,
#    'maxVoteWeight': '01',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_8T1wfF96NdMTqyfZrujD8YNPc4RxMzQAzKWVVv32U9p5'},
#  {'pubkey': 'B4aQEtXot87uWk6sDMcWhi66Q1R3DxFvt2ngvihG8o9V',
#   'account': {'accountType': 14,
#    'governance': '7CAVGhrhqPD3CdDRAfSeQtfSSv2apczfN9T9xZQasZRN',
#    'governingTokenMint': 'HfWBJGKE6XPXd9vzayip9mYh9jqHWgLayL3GD3DQ92Pp',
#    'state': 5,
#    'tokenOwnerRecord': 'DCzK6A1nkno3t1id4u2V9xa59t7ypfuczwodJs1DyUT9',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Add council member 7gAiM…nkrAy',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '02',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '64c2d43c',
#    'signingOffAt': '64c2d43e',
#    'votingAt': '64c2d43e',
#    'votingAtSlot': '0c640460',
#    'votingCompletedAt': 1690489973,
#    'executingAt': '64c2d626',
#    'closedAt': '64c2d626',
#    'executionFlags': 0,
#    'maxVoteWeight': '02',
#    'voteThreshold': {'type': 0, 'value': 60},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_8T1wfF96NdMTqyfZrujD8YNPc4RxMzQAzKWVVv32U9p5'},
#  {'pubkey': 'DHJoiMNZ1tcFoCp7D7wgHkk48C5r7EMyfKzgyP4Z6yU5',
#   'account': {'accountType': 14,
#    'governance': '7CAVGhrhqPD3CdDRAfSeQtfSSv2apczfN9T9xZQasZRN',
#    'governingTokenMint': 'HfWBJGKE6XPXd9vzayip9mYh9jqHWgLayL3GD3DQ92Pp',
#    'state': 3,
#    'tokenOwnerRecord': 'DCzK6A1nkno3t1id4u2V9xa59t7ypfuczwodJs1DyUT9',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'Add council member AKnkj…kbhS2',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '01',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
# ...
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': 'o5aj19CT2h88BTK1R9nodJ94tHV8U5zUsWvrKV4jXuo',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 5,
#    'tokenOwnerRecord': '9c14TcCu5jpL9TMhb1hQxY4N1nZxH2gxmdiFAKtbAbad',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'This proposal allows us to Test Governance Streaming Grants with the VSR using Grape',
#    'name': 'Testing Governance Streaming Grants with the VSR',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2520bf6718',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '63065835',
#    'signingOffAt': '63065838',
#    'votingAt': '63065838',
#    'votingAtSlot': '08ca15be',
#    'votingCompletedAt': 1661673811,
#    'executingAt': '630cc527',
#    'closedAt': '630cc527',
#    'executionFlags': 0,
#    'maxVoteWeight': '5cb956c4f7',
#    'voteThreshold': {'type': 0, 'value': 25},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': 'xSkXriZ5CGfUpepvuKfqUnmXYa1FHCJCQePnT67eskn',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 5,
#    'tokenOwnerRecord': '3ZiLpzKDTMU1E3oU9tYbV7NUv2JXabdEGMHaHKYuiHd8',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '1st Pavelsan - 28381\n2nd Dean -17028\n3rd Scrumpy- 5676\n4th Cavicon-5676',
#    'name': 'ALCHEMY TOURNAMENT PAYMENT PROPOSAL',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '31e820ad4f',
#      'voteResult': 1,
#      'instructionsExecutedCount': 4,
#      'instructionsCount': 4,
#      'instructionsNextIndex': 4}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '6401d7ca',
#    'signingOffAt': '6401d7ce',
#    'votingAt': '6401d7ce',
#    'votingAtSlot': '0ac2770b',
#    'votingCompletedAt': 1677928782,
#    'executingAt': '64033d86',
#    'closedAt': '64033d89',
#    'executionFlags': 0,
#    'maxVoteWeight': '97dc010ba6',
#    'voteThreshold': {'type': 0, 'value': 25},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': '2DnoVmfVkUmoVjfHFTwbFCRKECTJLnUyW26UWbL31Guj',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 5,
#    'tokenOwnerRecord': '9c14TcCu5jpL9TMhb1hQxY4N1nZxH2gxmdiFAKtbAbad',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Swapping GRAPE to DEAN',
#    'name': 'For Chingari',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2629bbd1ca',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '6392de1d',
#    'signingOffAt': '6392de1e',
#    'votingAt': '6392de1e',
#    'votingAtSlot': '09e1eb60',
#    'votingCompletedAt': 1670747961,
#    'executingAt': '6397560c',
#    'closedAt': '6397560c',
#    'executionFlags': 0,
#    'maxVoteWeight': '69712559bc',
#    'voteThreshold': {'type': 0, 'value': 25},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': '2YectF8evxrJiNc4AFm9RMqyFdeZtnmFh7UQAzPzyTNE',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 7,
#    'tokenOwnerRecord': '9c14TcCu5jpL9TMhb1hQxY4N1nZxH2gxmdiFAKtbAbad',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'This is to have a more reliable vote than the one on Twitter',
#    'name': 'Free feedback #1 -- Coinable',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '1534b590e7',
#      'voteResult': 2,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '2f58e18d3e',
#    'reserved1': 0,
#    'draftAt': '63f1df0c',
#    'signingOffAt': '63f1df0d',
#    'votingAt': '63f1df0d',
#    'votingAtSlot': '0aa455c8',
#    'votingCompletedAt': 1676882061,
#    'executionFlags': 0,
#    'maxVoteWeight': '87ec4bb85b',
#    'voteThreshold': {'type': 0, 'value': 25},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': '2fBWowEsazdwJiTeRpVzAv6pPNacKokbAo9k1LDS7bEo',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 5,
#    'tokenOwnerRecord': '9c14TcCu5jpL9TMhb1hQxY4N1nZxH2gxmdiFAKtbAbad',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'This transfer is needed to begin the migration to the new token! Some assets can be left here and moved later, but this transfer is the bulk of that\n\nOnce in Squads, it can then be used to handle existing payouts as shared and then be moved to the new DAO',
#    'name': 'Moving the USDC and GRAPE Treasury to Squads',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '5178e8d158',
#      'voteResult': 1,
#      'instructionsExecutedCount': 2,
#      'instructionsCount': 2,
#      'instructionsNextIndex': 2}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '6412c5af',
#    'signingOffAt': '6412c5b0',
#    'votingAt': '6412c5b0',
#    'votingAtSlot': '0ae6543f',
#    'votingCompletedAt': 1679038256,
#    'executingAt': '64141954',
#    'closedAt': '64141955',
#    'executionFlags': 0,
#    'maxVoteWeight': 'a46fd12571',
#    'voteThreshold': {'type': 0, 'value': 25},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': '2kQp9K3RTQ8E1n1rzzaJbTKQP9uNx1uJbNoSMx8wJnbZ',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 3,
#    'tokenOwnerRecord': 'HVCS6sabK2LphPHkgQotzoYd4nbTztWq4RXBy7Q1SB4q',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': "Vote yes if you wish to keep our brand as the existing one. Our name remains Dean's List",
#    'name': "Rebranding Option 1: Dean's List",
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2e81bf365b',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '1638fc4f21',
#    'reserved1': 0,
#    'draftAt': '63fba0d0',
#    'signingOffAt': '63fba0d2',
#    'votingAt': '63fba0d2',
#    'votingAtSlot': '0ab565ac',
#    'votingCompletedAt': 1677521490,
#    'executionFlags': 0,
#    'maxVoteWeight': '9552f91b6f',
#    'voteThreshold': {'type': 0, 'value': 25},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': '2pEjVXJxwRsDc6Lc2pfGd4j8TNj3cr1pTG9SXymgmWtB',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 5,
#    'tokenOwnerRecord': '9c14TcCu5jpL9TMhb1hQxY4N1nZxH2gxmdiFAKtbAbad',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': "This is to allocate 34 WL tokens to \n\nThe 24 members mentioned in the NFT distribution by Whale's Friend and Nanko\n\nincluding\n\n5 WL tokens for the top crew3 leaderboard as described by Takisoul\n1 token for the best Backpack feedback\n2 tokens for Kokoko and ESY\n1 token for me to auction\n1 token for the secret puzzle",
#    'name': "Sending NFT WL tokens to Dean's wallet for distribution before the mint",
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '4a08bf10b1',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '63fe7e8f',
#    'signingOffAt': '63fe7e8f',
#    'votingAt': '63fe7e8f',
#    'votingAtSlot': '0abb674b',
#    'votingCompletedAt': 1677709327,
#    'executingAt': '63fff461',
#    'closedAt': '63fff461',
#    'executionFlags': 0,
#    'maxVoteWeight': '96e2e13dfc',
#    'voteThreshold': {'type': 0, 'value': 25},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': '31FC1NKQ3WD2aFAoURVCZUH4VMn3nRz2UrzUPWLAVmAk',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 5,
#    'tokenOwnerRecord': '9c14TcCu5jpL9TMhb1hQxY4N1nZxH2gxmdiFAKtbAbad',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'empyting more treasury',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '15b504198e',
#      'voteResult': 1,
#      'instructionsExecutedCount': 3,
#      'instructionsCount': 3,
#      'instructionsNextIndex': 3}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '641c5ab4',
#    'signingOffAt': '641c5ab6',
#    'votingAt': '641c5ab6',
#    'votingAtSlot': '0afb1d64',
#    'votingCompletedAt': 1679666230,
#    'executingAt': '641db7b0',
#    'closedAt': '641db7b3',
#    'executionFlags': 0,
#    'maxVoteWeight': '553b9bbcd4',
#    'voteThreshold': {'type': 0, 'value': 5},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': '3KxeR5WBHpEPtS1v3dkxpUq1UnVvwddnNhWdi9Wc15DS',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 3,
#    'tokenOwnerRecord': '9c14TcCu5jpL9TMhb1hQxY4N1nZxH2gxmdiFAKtbAbad',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'As discussed on our DAO call, we would issue a new token that would be given out 1:1 in a redemption event to prevent front-running each other\n\nIssue token, make DAO, transfer assets, do redemption',
#    'name': "Create a new Dean's List DAO",
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '554d35aa3e',
#      'voteResult': 1,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '640f78f8',
#    'signingOffAt': '640f78f8',
#    'votingAt': '640f78f8',
#    'votingAtSlot': '0adf55f9',
#    'votingCompletedAt': 1678822008,
#    'executionFlags': 0,
#    'maxVoteWeight': 'a346161e32',
#    'voteThreshold': {'type': 0, 'value': 25},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': '3ZRnst95fekeFtZzE4h9ejStgG46QAU2p3tCPYU68R7D',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 7,
#    'tokenOwnerRecord': 'HVCS6sabK2LphPHkgQotzoYd4nbTztWq4RXBy7Q1SB4q',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'Vote yes if you want our new brand to be We Earn Network and our new coin be named $WEN',
#    'name': 'Rebranding Option 3: We Earn Network, $WEN',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '16e2787ffb',
#      'voteResult': 2,
#      'instructionsExecutedCount': 0,
#      'instructionsCount': 0,
#      'instructionsNextIndex': 0}],
#    'denyVoteWeight': '354cc357ca',
#    'reserved1': 0,
#    'draftAt': '63fba18a',
#    'signingOffAt': '63fba18b',
#    'votingAt': '63fba18b',
#    'votingAtSlot': '0ab5673a',
#    'votingCompletedAt': 1677521675,
#    'executionFlags': 0,
#    'maxVoteWeight': '9552f91b6f',
#    'voteThreshold': {'type': 0, 'value': 25},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': '4NrLUngxFd4xKvJVjkkewdphW1WxwsrsaVFDLLE7fq9U',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 5,
#    'tokenOwnerRecord': '9c14TcCu5jpL9TMhb1hQxY4N1nZxH2gxmdiFAKtbAbad',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': 'This is to cover sol and shwd/ipfs costs incurred for the NFT idea we discussed on the last DAO call',
#    'name': '$100 USDC for NFT project costs to ESY',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2ab3869e56',
#      'voteResult': 1,
#      'instructionsExecutedCount': 1,
#      'instructionsCount': 1,
#      'instructionsNextIndex': 1}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '63e52a86',
#    'signingOffAt': '63e52a88',
#    'votingAt': '63e52a88',
#    'votingAtSlot': '0a8b4fd3',
#    'votingCompletedAt': 1676049416,
#    'executingAt': '63e68640',
#    'closedAt': '63e68640',
#    'executionFlags': 0,
#    'maxVoteWeight': '7963a1b9a6',
#    'voteThreshold': {'type': 0, 'value': 25},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  {'pubkey': '4QS7SQY2Cp45LRpJRwui5gZjV68utmMo4jkDpJ6hass2',
#   'account': {'accountType': 14,
#    'governance': '5QBvexpLoRAMBDDpxPmn9uuefNK1zpysaWyJAZPChxxZ',
#    'governingTokenMint': '6LyW1iUpfTPiMxSLMpKCxeAqXDz7nuWCfCNnEaSmibZ1',
#    'state': 5,
#    'tokenOwnerRecord': '9c14TcCu5jpL9TMhb1hQxY4N1nZxH2gxmdiFAKtbAbad',
#    'signatoriesCount': 1,
#    'signatoriesSignedOffCount': 1,
#    'descriptionLink': '',
#    'name': 'empyting treasury',
#    'voteType': {'type': 0},
#    'options': [{'label': 'Approve',
#      'voteWeight': '2c12f71442',
#      'voteResult': 1,
#      'instructionsExecutedCount': 4,
#      'instructionsCount': 4,
#      'instructionsNextIndex': 4}],
#    'denyVoteWeight': '00',
#    'reserved1': 0,
#    'draftAt': '641b02cd',
#    'signingOffAt': '641b02ce',
#    'votingAt': '641b02ce',
#    'votingAtSlot': '0af835cb',
#    'votingCompletedAt': 1679578190,
#    'executingAt': '641c546c',
#    'closedAt': '641c546e',
#    'executionFlags': 0,
#    'maxVoteWeight': '697d3662d4',
#    'voteThreshold': {'type': 0, 'value': 25},
#    'vetoVoteWeight': '00'},
#   'owner': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw',
#   'filename': 'GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9mS8GuMx2MkZGMSwa2k87HNLTFZ1ssa9mJ1RkGFKcGyQ'},
#  ...]

# %%
len(json_list)
# Out:
# 5764

# %%
# read into df
df = pd.DataFrame(json_list)
df
# Out:
#                                             pubkey  \
# 0     7BA31zKajR1f7Fn2FLxtiXjFQQaLebvSdDXwjHngtsPX
# 1     BBV4Qkwx4g4LVWvcHDZbqySy4Wk4cmGfRwKeqWadjFGR
# 2     CQScJP8aBqHF2yddGKG5w9GjD6qe3k4vkBN477QA4rGR
# 3     CUqhQc1qd2oJ5QpBu56GQ7rDscYWBGgo7q6wbsC4xreT
# 4     DEfrhqxXPKke3rzmg6hRMrokNhp4G91Ucossth9rgqvu
# ...                                            ...
# 5759  4e2DGqJRbU6n2znd2shT9x4An4B3EzuDMsxWwDFKDQqs
# 5760  BKUbYdSwkYRQ9HnrxigZixtMDhUujREzpjHnCfw7nn7E
# 5761  HwLDejVp4KrZ1EMuxypFR7Ds9J1UkqnhRULMhe2VaMSb
# 5762   8HeBHe6f9UCabEstTg26xohY66yYjoG9WzmTFqmd1tj
# 5763  3dnAJchiJyheZtvFWQy9edkikdNgKDgxJSje4xjydQ4H
#
#                                                 account  \
# 0     {'accountType': 14, 'governance': '8ugSYRBAkjP...
# 1     {'accountType': 14, 'governance': '8ugSYRBAkjP...
# 2     {'accountType': 14, 'governance': '8ugSYRBAkjP...
# 3     {'accountType': 14, 'governance': '8ugSYRBAkjP...
# 4     {'accountType': 14, 'governance': '8ugSYRBAkjP...
# ...                                                 ...
# 5759  {'accountType': 14, 'governance': 'DU3iHrA445z...
# 5760  {'accountType': 14, 'governance': 'GXMhSQEmfk4...
# 5761  {'accountType': 14, 'governance': 'GXMhSQEmfk4...
# 5762  {'accountType': 14, 'governance': 'GXMhSQEmfk4...
# 5763  {'accountType': 14, 'governance': 'GXMhSQEmfk4...
#
#                                              owner  \
# 0     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 1     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 2     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 3     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 4     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# ...                                            ...
# 5759  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 5760  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 5761  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 5762  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 5763  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
#
#                                                filename
# 0     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...
# 1     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...
# 2     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...
# 3     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...
# 4     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...
# ...                                                 ...
# 5759  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 5760  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 5761  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 5762  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
# 5763  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...
#
# [5764 rows x 4 columns]

# %%
# expand account column
df = pd.concat([df.drop(['account'], axis=1), df['account'].apply(pd.Series)], axis=1)
df
# Out:
#                                             pubkey  \
# 0     7BA31zKajR1f7Fn2FLxtiXjFQQaLebvSdDXwjHngtsPX
# 1     BBV4Qkwx4g4LVWvcHDZbqySy4Wk4cmGfRwKeqWadjFGR
# 2     CQScJP8aBqHF2yddGKG5w9GjD6qe3k4vkBN477QA4rGR
# 3     CUqhQc1qd2oJ5QpBu56GQ7rDscYWBGgo7q6wbsC4xreT
# 4     DEfrhqxXPKke3rzmg6hRMrokNhp4G91Ucossth9rgqvu
# ...                                            ...
# 5759  4e2DGqJRbU6n2znd2shT9x4An4B3EzuDMsxWwDFKDQqs
# 5760  BKUbYdSwkYRQ9HnrxigZixtMDhUujREzpjHnCfw7nn7E
# 5761  HwLDejVp4KrZ1EMuxypFR7Ds9J1UkqnhRULMhe2VaMSb
# 5762   8HeBHe6f9UCabEstTg26xohY66yYjoG9WzmTFqmd1tj
# 5763  3dnAJchiJyheZtvFWQy9edkikdNgKDgxJSje4xjydQ4H
#
#                                              owner  \
# 0     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 1     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 2     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 3     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 4     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# ...                                            ...
# 5759  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 5760  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 5761  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 5762  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 5763  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
#
#                                                filename  accountType  \
# 0     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...           14
# 1     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...           14
# 2     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...           14
# 3     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...           14
# 4     GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...           14
# ...                                                 ...          ...
# 5759  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 5760  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 5761  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 5762  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
# 5763  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_A...           14
#
#                                         governance  \
# 0     8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6
# 1     8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6
# 2     8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6
# 3     8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6
# 4     8ugSYRBAkjPzpt6ndWgJ875XxcJ679DEY6yCKfHy7He6
# ...                                            ...
# 5759  DU3iHrA445zpvEc3bLEfVWUJtNbbTM2aiLq9yih1BANe
# 5760  GXMhSQEmfk4CfK9Ae2U67aL84LDPCySJzscDhBTMY8hM
# 5761  GXMhSQEmfk4CfK9Ae2U67aL84LDPCySJzscDhBTMY8hM
# 5762  GXMhSQEmfk4CfK9Ae2U67aL84LDPCySJzscDhBTMY8hM
# 5763  GXMhSQEmfk4CfK9Ae2U67aL84LDPCySJzscDhBTMY8hM
#
#                                 governingTokenMint  state  \
# 0      mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz      6
# 1      mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz      6
# 2      mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz      0
# 3      mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz      6
# 4      mBFg7aS1PgSUqtMuUUBmy6SbAuJzXEcLVh3ytfwaJZz      3
# ...                                            ...    ...
# 5759  5rXvJVnQicvcDdthygGLqvdmfETHDdS3FPWUeusEU6Wo      3
# 5760  5rXvJVnQicvcDdthygGLqvdmfETHDdS3FPWUeusEU6Wo      5
# 5761  5rXvJVnQicvcDdthygGLqvdmfETHDdS3FPWUeusEU6Wo      3
# 5762  5rXvJVnQicvcDdthygGLqvdmfETHDdS3FPWUeusEU6Wo      3
# 5763  5rXvJVnQicvcDdthygGLqvdmfETHDdS3FPWUeusEU6Wo      7
#
#                                   tokenOwnerRecord  signatoriesCount  \
# 0     4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS                 1
# 1     4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS                 1
# 2     3sbgxyZ5sEMruY7bVr7GpHaMtv66UwUpgYTFWFnNmiyy                 1
# 3     4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS                 1
# 4     4WkTFCYst81Ec8DFNiyor6naMDPfu9eUmYB9GUVd1nZS                 1
# ...                                            ...               ...
# 5759  FhJ9siUV3xbp8fybXTDhC2WtLedTdrz6WY86KkYS3YZ2                 1
# 5760  FhJ9siUV3xbp8fybXTDhC2WtLedTdrz6WY86KkYS3YZ2                 1
# 5761  42Si1ZXKKjGgwmfnRpj6TnYL8NyzbGPJvqeg9JyQJZRo                 1
# 5762  FhJ9siUV3xbp8fybXTDhC2WtLedTdrz6WY86KkYS3YZ2                 1
# 5763  FhJ9siUV3xbp8fybXTDhC2WtLedTdrz6WY86KkYS3YZ2                 1
#
#       signatoriesSignedOffCount  ... vetoVoteWeight votingCompletedAt  \
# 0                             1  ...             00               NaN
# 1                             1  ...             00               NaN
# 2                             0  ...             00               NaN
# 3                             1  ...             00               NaN
# 4                             1  ...             00      1.655802e+09
# ...                         ...  ...            ...               ...
# 5759                          1  ...             00      1.660768e+09
# 5760                          1  ...             00      1.660755e+09
# 5761                          1  ...             00      1.660758e+09
# 5762                          1  ...             00      1.660757e+09
# 5763                          1  ...             00      1.660753e+09
#
#      maxVoteWeight             voteThreshold executingAt  yesVotesCount  \
# 0              NaN                       NaN         NaN            NaN
# 1              NaN                       NaN         NaN            NaN
# 2              NaN                       NaN         NaN            NaN
# 3              NaN                       NaN         NaN            NaN
# 4       017a7d4f80  {'type': 0, 'value': 10}         NaN            NaN
# ...            ...                       ...         ...            ...
# 5759            02  {'type': 0, 'value': 18}         NaN            NaN
# 5760            02   {'type': 0, 'value': 5}    62fd1b36            NaN
# 5761            02   {'type': 0, 'value': 9}         NaN            NaN
# 5762            02   {'type': 0, 'value': 9}         NaN            NaN
# 5763            02   {'type': 0, 'value': 5}         NaN            NaN
#
#      noVotesCount instructionsExecutedCount instructionsCount  \
# 0             NaN                       NaN               NaN
# 1             NaN                       NaN               NaN
# 2             NaN                       NaN               NaN
# 3             NaN                       NaN               NaN
# 4             NaN                       NaN               NaN
# ...           ...                       ...               ...
# 5759          NaN                       NaN               NaN
# 5760          NaN                       NaN               NaN
# 5761          NaN                       NaN               NaN
# 5762          NaN                       NaN               NaN
# 5763          NaN                       NaN               NaN
#
#      instructionsNextIndex
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 5759                   NaN
# 5760                   NaN
# 5761                   NaN
# 5762                   NaN
# 5763                   NaN
#
# [5764 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['pubkey', 'owner', 'filename', 'accountType', 'governance',
#        'governingTokenMint', 'state', 'tokenOwnerRecord', 'signatoriesCount',
#        'signatoriesSignedOffCount', 'descriptionLink', 'name', 'voteType',
#        'options', 'denyVoteWeight', 'reserved1', 'draftAt', 'signingOffAt',
#        'votingAt', 'votingAtSlot', 'closedAt', 'executionFlags',
#        'vetoVoteWeight', 'votingCompletedAt', 'maxVoteWeight', 'voteThreshold',
#        'executingAt', 'yesVotesCount', 'noVotesCount',
#        'instructionsExecutedCount', 'instructionsCount',
#        'instructionsNextIndex'],
#       dtype='object')

# %%
# how many proposals are there?
len(df)
# Out:
# 5764

# %%
# how many null votingCompletedAt are there?
len(df[df['votingCompletedAt'].isnull()])
# Out:
# 987

# %%
# keep only proposals where voting has finished
df = df[df['votingCompletedAt'].notnull()]

# %%
df = df[['pubkey', 'filename', 'votingCompletedAt']]

# %%
df.head()
# Out:
#                                           pubkey  \
# 4   DEfrhqxXPKke3rzmg6hRMrokNhp4G91Ucossth9rgqvu
# 5   ETXfDrENdPkmA9vUKxNFyhAGTbEAST7BXoaaw7GroJ9C
# 11  3ASUzT3SWbfxLd7en1oXRGa7Xx8sVczruH6fR4tYCniy
# 13  5xihFY98ZoGYoLFn5oEWf7NFTA5yRM8z8hHcbX6AYRxK
# 15  HazF6BXuDfAQQ5NV3M9yb57XHGfXZxKhXfYdUWiAfM1i
#
#                                              filename  votingCompletedAt
# 4   GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...       1.655802e+09
# 5   GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...       1.655782e+09
# 11  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...       1.655802e+09
# 13  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...       1.656198e+09
# 15  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...       1.656132e+09

# %%
# remove 'realms_proposals_' from beginning of filename
df['filename'] = df['filename'].str.replace(r'^realm_proposals_', '')
df.head()
# Out:
# /var/folders/yn/b6240_995k3gl4vwtnbzzy480000gq/T/ipykernel_76490/2761627738.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['filename'] = df['filename'].str.replace(r'^realm_proposals_', '')
#                                           pubkey  \
# 4   DEfrhqxXPKke3rzmg6hRMrokNhp4G91Ucossth9rgqvu
# 5   ETXfDrENdPkmA9vUKxNFyhAGTbEAST7BXoaaw7GroJ9C
# 11  3ASUzT3SWbfxLd7en1oXRGa7Xx8sVczruH6fR4tYCniy
# 13  5xihFY98ZoGYoLFn5oEWf7NFTA5yRM8z8hHcbX6AYRxK
# 15  HazF6BXuDfAQQ5NV3M9yb57XHGfXZxKhXfYdUWiAfM1i
#
#                                              filename  votingCompletedAt
# 4   GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...       1.655802e+09
# 5   GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...       1.655782e+09
# 11  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...       1.655802e+09
# 13  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...       1.656198e+09
# 15  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9...       1.656132e+09

# %%
# * platform
# add platform column = 'realms'
df['platform'] = 'realms'
# * platform_deployment_id
# rename governance to platform_deployment_id
df = df.rename(columns={'filename': 'platform_deployment_id'})
# * proposal_id
# rename pubkey to proposal_id
df = df.rename(columns={'pubkey': 'proposal_id'})
# * author
df['author'] = None # FIXME: pull this
# * date -- this should be as a pandas date, not as an epoch
# rename voting completed at to date
df = df.rename(columns={'votingCompletedAt': 'date'})
# convert date to pandas date
df['date'] = pd.to_datetime(df['date'], unit='s')
# * votes_count
# make votes_count column nulls
df['votes_count'] = None
df.head()
# Out:
#                                      proposal_id  \
# 4   DEfrhqxXPKke3rzmg6hRMrokNhp4G91Ucossth9rgqvu
# 5   ETXfDrENdPkmA9vUKxNFyhAGTbEAST7BXoaaw7GroJ9C
# 11  3ASUzT3SWbfxLd7en1oXRGa7Xx8sVczruH6fR4tYCniy
# 13  5xihFY98ZoGYoLFn5oEWf7NFTA5yRM8z8hHcbX6AYRxK
# 15  HazF6BXuDfAQQ5NV3M9yb57XHGfXZxKhXfYdUWiAfM1i
#
#                                platform_deployment_id                date  \
# 4   GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9... 2022-06-21 08:57:51
# 5   GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9... 2022-06-21 03:27:03
# 11  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9... 2022-06-21 08:57:12
# 13  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9... 2022-06-25 23:04:33
# 15  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_9... 2022-06-25 04:38:19
#
#    platform author votes_count
# 4    realms   None        None
# 5    realms   None        None
# 11   realms   None        None
# 13   realms   None        None
# 15   realms   None        None

# %%
# reordenar columnas: platform, platform_deployment_id, proposal_id, author, date, votes_count
df = df[['platform', 'platform_deployment_id', 'proposal_id', 'author', 'date', 'votes_count']]

# %%
# let's save a list of all of the platform_deployment_ids to a json file to be used by the downloadVotes js script
proposal_ids = df['proposal_id'].unique().tolist()
with open('proposal_ids.json', 'w') as f:
    json.dump(proposal_ids, f)

# %%
# guardar como realms_proposals.csv
df.to_csv('realms_proposals.csv', index=False)

# %% [markdown]
# this workbook is here to get the count of votes on a per-proposal basis for the proposals table

# %%
import pandas as pd
df = pd.read_csv('realms_proposals.csv')
df.head()
# Out:
#   platform                        platform_deployment_id  \
# 0   realms  7cWnmakdFUUVrJNbY2Mm5riXWBKwb3rPrkTUgPboGcx1
# 1   realms  7cWnmakdFUUVrJNbY2Mm5riXWBKwb3rPrkTUgPboGcx1
# 2   realms  7LznoL3LEjkGPM89NoBGjQ9E7Bh71biS3F8b3DQwUbpt
# 3   realms  Dzpog9qdmW3Tfyxq1NCwC2q4v4PhcpJtTmQmZHsPGtFj
# 4   realms  Dzpog9qdmW3Tfyxq1NCwC2q4v4PhcpJtTmQmZHsPGtFj
#
#                                     proposal_id  author                 date  \
# 0  9KXakky9yScaqfk842xAnN5ukWq7bMig9gNsyPMeAFsL     NaN  2022-05-03 19:58:24
# 1   Z2FNZAc8EKTMQVZEvXXtnUbrMsFvrJXDXSih5rCeiS3     NaN  2022-05-03 19:57:14
# 2  7GPyFfPigUFG7Z4essQwxpX1tWd64Yd164ZCBfsALMKu     NaN  2022-11-02 00:30:14
# 3  A4LsZPHwFmZLLE15stN6PrtRwEKe5SPv1dd2b1NDYqCi     NaN  2022-06-10 22:19:03
# 4  5WHz1rszWGMKbhpmZrJcr1ttQZtBEtxjGGDSuEUpcPPS     NaN  2022-06-17 16:05:39
#
#    votes_count
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# if the votes_count column has any non-na values, quit the notebook
if df['votes_count'].notna().any():
    print('The votes_count column has non-na values. Quitting notebook.')
    quit()

# %%
import os
REALMS_NODE_DIR = '../../realms_node'
REALMS_NODE_DATA_DIR = os.path.join(REALMS_NODE_DIR, 'output_votes_2023_6_11')

import glob
import json

# %%
json_files = glob.glob(os.path.join(REALMS_NODE_DATA_DIR, 'proposal_votes_*.json'))
len(json_files)
# Out:
# 1087

# %%
# read all the json files like 'proposal_votes_*.json' and concat into votes_df
votes_df = pd.DataFrame()
for json_file in json_files:
    with open(json_file) as f:
        votes_df = pd.concat([votes_df, pd.DataFrame(json.load(f))])
votes_df.head()
# Out:
#                                          pubkey  \
# 0  5WYbwkuEuvRtfto18SLdX7Q11GKqFtPo6LaQJRLBe15r
# 1  5CGGj2DTDaRqKcEEhv7jh4yJ9FPNV8kuWmsxYfAW52oc
# 0  BjBiHZ6Lh6esUPEJfKHM3a6so2wfydkp2xcoMWN5QFpa
# 1  3MYVdrAzWRTFV3nzjkqNjrFi3TUJL9HheU3hThZToY9j
# 0  65LJr4p1vtF43CWLu4Aenf2oS4dajypkKQyEd1JTEUG3
#
#                                              account  \
# 0  {'accountType': 12, 'proposal': 'DsaGqF8tpiQqw...
# 1  {'accountType': 12, 'proposal': 'DsaGqF8tpiQqw...
# 0  {'accountType': 12, 'proposal': 'G6Btg2upfXJZQ...
# 1  {'accountType': 12, 'proposal': 'G6Btg2upfXJZQ...
# 0  {'accountType': 12, 'proposal': 'FsCC4tk3iW6AE...
#
#                                           owner
# 0  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 1  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 0  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 1  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw
# 0  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw

# %%
votes_df.shape
# Out:
# (3439, 3)

# %%
# expand the account column in the df
votes_df = pd.concat([votes_df.drop(['account'], axis=1), votes_df['account'].apply(pd.Series)], axis=1)
votes_df.head()
# Out:
#                                          pubkey  \
# 0  5WYbwkuEuvRtfto18SLdX7Q11GKqFtPo6LaQJRLBe15r
# 1  5CGGj2DTDaRqKcEEhv7jh4yJ9FPNV8kuWmsxYfAW52oc
# 0  BjBiHZ6Lh6esUPEJfKHM3a6so2wfydkp2xcoMWN5QFpa
# 1  3MYVdrAzWRTFV3nzjkqNjrFi3TUJL9HheU3hThZToY9j
# 0  65LJr4p1vtF43CWLu4Aenf2oS4dajypkKQyEd1JTEUG3
#
#                                           owner  accountType  \
# 0  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 1  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 0  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 1  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
# 0  GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw           12
#
#                                        proposal  \
# 0  DsaGqF8tpiQqwJGxGP6JXAWUo9L623jWBnexHuxEkrZ3
# 1  DsaGqF8tpiQqwJGxGP6JXAWUo9L623jWBnexHuxEkrZ3
# 0  G6Btg2upfXJZQrYngtA6auptprSsZVDXThxFd9ovSPqq
# 1  G6Btg2upfXJZQrYngtA6auptprSsZVDXThxFd9ovSPqq
# 0  FsCC4tk3iW6AEtbGNzi7bhtzahqA2NxENtWXPqpjkWb4
#
#                             governingTokenOwner  isRelinquished voterWeight  \
# 0  AHGCPfBJ1jm8xaoYjBQX1tQ8Qcevs3PQnXQrvgRhv1xd            True           1
# 1  AJTFfho8tPP4bsY665tjUyfKLsuCQsrJiCaGHY33Jwkp           False           1
# 0  DcLN5EYHBSexnKdipnSmiFAKevcxGijURonzaWfri8Cq           False       12000
# 1  DfCHMeHfRYMBQwMje5bLSqimMWXhArYoTomX2vRr6Ty9           False       12000
# 0  6rwjQTzepxgABYggM3CNAyjkbyaGiU7Kjtm2kbgyS3rG           False           1
#
#                                                 vote voteWeight
# 0  {'voteType': 0, 'approveChoices': [{'rank': 0,...        NaN
# 1  {'voteType': 0, 'approveChoices': [{'rank': 0,...        NaN
# 0  {'voteType': 0, 'approveChoices': [{'rank': 0,...        NaN
# 1  {'voteType': 0, 'approveChoices': [{'rank': 0,...        NaN
# 0  {'voteType': 0, 'approveChoices': [{'rank': 0,...        NaN

# %%
# group by proposal, count pubkey
votes_count_df = votes_df.groupby('proposal').agg({'pubkey': 'count'}).reset_index()
votes_count_df.head()
# Out:
#                                        proposal  pubkey
# 0  128MWNwvwjqAtU1ZqvwnrX3HMhY42rFSSvbyYzuSkpMi       1
# 1  12H1nCwEUaBpFoCkCGxxw614HMswTj5rawovi1bGRxDC       3
# 2  13SJRRAY3xYPDLS7FnegJsv83tvNeSWdeM4Gy28jrP9V       5
# 3   1rCbQsG63mi3KSy4yrUxxv31FHGwN5SsKbCS7E6j4VU       2
# 4  21EZ37bN2JsCEvDgbnHg5g3uTvk5S7fPCjpwPvzAvbi5       1

# %%
# rename pubkey to votes_count
votes_count_df = votes_count_df.rename(columns={'pubkey': 'votes_count'})
# rename proposal to platform_deployment_id
votes_count_df = votes_count_df.rename(columns={'proposal': 'proposal_id'})
votes_count_df.head()
# Out:
#                                     proposal_id  votes_count
# 0  128MWNwvwjqAtU1ZqvwnrX3HMhY42rFSSvbyYzuSkpMi            1
# 1  12H1nCwEUaBpFoCkCGxxw614HMswTj5rawovi1bGRxDC            3
# 2  13SJRRAY3xYPDLS7FnegJsv83tvNeSWdeM4Gy28jrP9V            5
# 3   1rCbQsG63mi3KSy4yrUxxv31FHGwN5SsKbCS7E6j4VU            2
# 4  21EZ37bN2JsCEvDgbnHg5g3uTvk5S7fPCjpwPvzAvbi5            1

# %%
# merge with df
df = df.merge(votes_count_df, on='proposal_id', how='left', validate='1:1', suffixes=('', '_new'))
df.head()
# Out:
#   platform                        platform_deployment_id  \
# 0   realms  7cWnmakdFUUVrJNbY2Mm5riXWBKwb3rPrkTUgPboGcx1
# 1   realms  7cWnmakdFUUVrJNbY2Mm5riXWBKwb3rPrkTUgPboGcx1
# 2   realms  7LznoL3LEjkGPM89NoBGjQ9E7Bh71biS3F8b3DQwUbpt
# 3   realms  Dzpog9qdmW3Tfyxq1NCwC2q4v4PhcpJtTmQmZHsPGtFj
# 4   realms  Dzpog9qdmW3Tfyxq1NCwC2q4v4PhcpJtTmQmZHsPGtFj
#
#                                     proposal_id  author                 date  \
# 0  9KXakky9yScaqfk842xAnN5ukWq7bMig9gNsyPMeAFsL     NaN  2022-05-03 19:58:24
# 1   Z2FNZAc8EKTMQVZEvXXtnUbrMsFvrJXDXSih5rCeiS3     NaN  2022-05-03 19:57:14
# 2  7GPyFfPigUFG7Z4essQwxpX1tWd64Yd164ZCBfsALMKu     NaN  2022-11-02 00:30:14
# 3  A4LsZPHwFmZLLE15stN6PrtRwEKe5SPv1dd2b1NDYqCi     NaN  2022-06-10 22:19:03
# 4  5WHz1rszWGMKbhpmZrJcr1ttQZtBEtxjGGDSuEUpcPPS     NaN  2022-06-17 16:05:39
#
#    votes_count  votes_count_new
# 0          NaN              3.0
# 1          NaN              2.0
# 2          NaN              1.0
# 3          NaN              2.0
# 4          NaN              5.0

# %%
# overwrite the old votes_count column with the new one
df['votes_count'] = df['votes_count_new']
df = df.drop('votes_count_new', axis=1)
df.head()
# Out:
#   platform                        platform_deployment_id  \
# 0   realms  7cWnmakdFUUVrJNbY2Mm5riXWBKwb3rPrkTUgPboGcx1
# 1   realms  7cWnmakdFUUVrJNbY2Mm5riXWBKwb3rPrkTUgPboGcx1
# 2   realms  7LznoL3LEjkGPM89NoBGjQ9E7Bh71biS3F8b3DQwUbpt
# 3   realms  Dzpog9qdmW3Tfyxq1NCwC2q4v4PhcpJtTmQmZHsPGtFj
# 4   realms  Dzpog9qdmW3Tfyxq1NCwC2q4v4PhcpJtTmQmZHsPGtFj
#
#                                     proposal_id  author                 date  \
# 0  9KXakky9yScaqfk842xAnN5ukWq7bMig9gNsyPMeAFsL     NaN  2022-05-03 19:58:24
# 1   Z2FNZAc8EKTMQVZEvXXtnUbrMsFvrJXDXSih5rCeiS3     NaN  2022-05-03 19:57:14
# 2  7GPyFfPigUFG7Z4essQwxpX1tWd64Yd164ZCBfsALMKu     NaN  2022-11-02 00:30:14
# 3  A4LsZPHwFmZLLE15stN6PrtRwEKe5SPv1dd2b1NDYqCi     NaN  2022-06-10 22:19:03
# 4  5WHz1rszWGMKbhpmZrJcr1ttQZtBEtxjGGDSuEUpcPPS     NaN  2022-06-17 16:05:39
#
#    votes_count
# 0          3.0
# 1          2.0
# 2          1.0
# 3          2.0
# 4          5.0

# %%
# save
df.to_csv('realms_proposals.csv', index=False)

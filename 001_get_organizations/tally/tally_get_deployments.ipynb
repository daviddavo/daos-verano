# %%
import requests

response = requests.get('https://www.tally.xyz/api/search-daos')

import pandas as pd
df = pd.DataFrame(response.json()['governances'])
df.head()
# Out:
#                                                   id  \
# 0  eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...
# 1  eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...
# 2  eip155:84531:0x6AB41b2646E8333e930c626Aa3C674d...
# 3  eip155:10:0xF8fBe44761844b26E848F10C831a0D6319...
# 4  eip155:1:0xDE80c40921b569ed1326Bb6e2c440c9ee18...
#
#                         slug                       name        kind  \
# 0          spore-engineering          Spore Engineering  SINGLE_GOV
# 1                       diva               Diva Staking  SINGLE_GOV
# 2                cbsatestdao                cbsatestdao  SINGLE_GOV
# 3  united-gabriel-nation-dao  United Gabriel Nation DAO  SINGLE_GOV
# 4                     thrust                     Thrust  SINGLE_GOV
#
#         chainId                                       organization
# 0    eip155:100  {'name': 'Spore Engineering', 'slug': 'dsfsdf'...
# 1      eip155:1  {'name': 'Diva Staking', 'slug': 'diva-staking...
# 2  eip155:84531  {'name': 'cbsatestdao', 'slug': 'cbsatestdao',...
# 3     eip155:10  {'name': 'United Gabriel Nation DAO', 'slug': ...
# 4      eip155:1  {'name': 'Thrust', 'slug': 'thrust-dao', 'visu...

# %%
df.columns
# Out:
# Index(['id', 'slug', 'name', 'kind', 'chainId', 'organization'], dtype='object')

# %%
# drop columns chainId, visual, and governances
df = df.drop(columns=['chainId', 'kind', 'organization'])
df.head()
# Out:
#                                                   id  \
# 0  eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...
# 1  eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...
# 2  eip155:84531:0x6AB41b2646E8333e930c626Aa3C674d...
# 3  eip155:10:0xF8fBe44761844b26E848F10C831a0D6319...
# 4  eip155:1:0xDE80c40921b569ed1326Bb6e2c440c9ee18...
#
#                         slug                       name
# 0          spore-engineering          Spore Engineering
# 1                       diva               Diva Staking
# 2                cbsatestdao                cbsatestdao
# 3  united-gabriel-nation-dao  United Gabriel Nation DAO
# 4                     thrust                     Thrust

# %%
# add platform column
df['platform'] = 'tally'
df = df.rename(columns={'id': 'platform_id'})
df
# Out:
#                                            platform_id  \
# 0    eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...
# 1    eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...
# 2    eip155:84531:0x6AB41b2646E8333e930c626Aa3C674d...
# 3    eip155:10:0xF8fBe44761844b26E848F10C831a0D6319...
# 4    eip155:1:0xDE80c40921b569ed1326Bb6e2c440c9ee18...
# ..                                                 ...
# 571  eip155:1:0x0BEF27FEB58e857046d630B2c03dFb7bae5...
# 572  eip155:137:0x9B3a9e3f289095A7E1117deb3bD29Fd7C...
# 573  eip155:137:0x89de859404FeAC5346f5a843Db6B5E136...
# 574  eip155:137:0x806713eAAAAFEBfb4F0f6d6ED54775f76...
# 575  eip155:137:0x010C5507C43a161240d4C0FA40043244c...
#
#                           slug                       name platform
# 0            spore-engineering          Spore Engineering    tally
# 1                         diva               Diva Staking    tally
# 2                  cbsatestdao                cbsatestdao    tally
# 3    united-gabriel-nation-dao  United Gabriel Nation DAO    tally
# 4                       thrust                     Thrust    tally
# ..                         ...                        ...      ...
# 571                        fei                        Fei    tally
# 572                     under3                     Under3    tally
# 573            harry-potter-82               Harry Potter    tally
# 574           allturn-space-83              AllTurn.Space    tally
# 575           immunity-dao-181               Immunity DAO    tally
#
# [576 rows x 4 columns]

# %%
# make website column from https://www.tally.xyz/gov/<platform_id>
df['website'] = 'https://www.tally.xyz/gov/' + df['platform_id']
df
# Out:
#                                            platform_id  \
# 0    eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...
# 1    eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...
# 2    eip155:84531:0x6AB41b2646E8333e930c626Aa3C674d...
# 3    eip155:10:0xF8fBe44761844b26E848F10C831a0D6319...
# 4    eip155:1:0xDE80c40921b569ed1326Bb6e2c440c9ee18...
# ..                                                 ...
# 571  eip155:1:0x0BEF27FEB58e857046d630B2c03dFb7bae5...
# 572  eip155:137:0x9B3a9e3f289095A7E1117deb3bD29Fd7C...
# 573  eip155:137:0x89de859404FeAC5346f5a843Db6B5E136...
# 574  eip155:137:0x806713eAAAAFEBfb4F0f6d6ED54775f76...
# 575  eip155:137:0x010C5507C43a161240d4C0FA40043244c...
#
#                           slug                       name platform  \
# 0            spore-engineering          Spore Engineering    tally
# 1                         diva               Diva Staking    tally
# 2                  cbsatestdao                cbsatestdao    tally
# 3    united-gabriel-nation-dao  United Gabriel Nation DAO    tally
# 4                       thrust                     Thrust    tally
# ..                         ...                        ...      ...
# 571                        fei                        Fei    tally
# 572                     under3                     Under3    tally
# 573            harry-potter-82               Harry Potter    tally
# 574           allturn-space-83              AllTurn.Space    tally
# 575           immunity-dao-181               Immunity DAO    tally
#
#                                                website
# 0    https://www.tally.xyz/gov/eip155:100:0x9685308...
# 1    https://www.tally.xyz/gov/eip155:1:0xFb6B7C11a...
# 2    https://www.tally.xyz/gov/eip155:84531:0x6AB41...
# 3    https://www.tally.xyz/gov/eip155:10:0xF8fBe447...
# 4    https://www.tally.xyz/gov/eip155:1:0xDE80c4092...
# ..                                                 ...
# 571  https://www.tally.xyz/gov/eip155:1:0x0BEF27FEB...
# 572  https://www.tally.xyz/gov/eip155:137:0x9B3a9e3...
# 573  https://www.tally.xyz/gov/eip155:137:0x89de859...
# 574  https://www.tally.xyz/gov/eip155:137:0x806713e...
# 575  https://www.tally.xyz/gov/eip155:137:0x010C550...
#
# [576 rows x 5 columns]

# %%
df = df[['platform', 'platform_id', 'name', 'website']]
df
# Out:
#     platform                                        platform_id  \
# 0      tally  eip155:100:0x96853087C9E364FE9554fD6FCFE13BcD9...
# 1      tally  eip155:1:0xFb6B7C11a55C57767643F1FF65c34C8693a...
# 2      tally  eip155:84531:0x6AB41b2646E8333e930c626Aa3C674d...
# 3      tally  eip155:10:0xF8fBe44761844b26E848F10C831a0D6319...
# 4      tally  eip155:1:0xDE80c40921b569ed1326Bb6e2c440c9ee18...
# ..       ...                                                ...
# 571    tally  eip155:1:0x0BEF27FEB58e857046d630B2c03dFb7bae5...
# 572    tally  eip155:137:0x9B3a9e3f289095A7E1117deb3bD29Fd7C...
# 573    tally  eip155:137:0x89de859404FeAC5346f5a843Db6B5E136...
# 574    tally  eip155:137:0x806713eAAAAFEBfb4F0f6d6ED54775f76...
# 575    tally  eip155:137:0x010C5507C43a161240d4C0FA40043244c...
#
#                           name  \
# 0            Spore Engineering
# 1                 Diva Staking
# 2                  cbsatestdao
# 3    United Gabriel Nation DAO
# 4                       Thrust
# ..                         ...
# 571                        Fei
# 572                     Under3
# 573               Harry Potter
# 574              AllTurn.Space
# 575               Immunity DAO
#
#                                                website
# 0    https://www.tally.xyz/gov/eip155:100:0x9685308...
# 1    https://www.tally.xyz/gov/eip155:1:0xFb6B7C11a...
# 2    https://www.tally.xyz/gov/eip155:84531:0x6AB41...
# 3    https://www.tally.xyz/gov/eip155:10:0xF8fBe447...
# 4    https://www.tally.xyz/gov/eip155:1:0xDE80c4092...
# ..                                                 ...
# 571  https://www.tally.xyz/gov/eip155:1:0x0BEF27FEB...
# 572  https://www.tally.xyz/gov/eip155:137:0x9B3a9e3...
# 573  https://www.tally.xyz/gov/eip155:137:0x89de859...
# 574  https://www.tally.xyz/gov/eip155:137:0x806713e...
# 575  https://www.tally.xyz/gov/eip155:137:0x010C550...
#
# [576 rows x 4 columns]

# %%
# save
df.to_csv('tally_deployments.csv', index=False)
